# %%
! pip install -qU \
    langchain-community \
    langchain-huggingface \
    langchain-chroma \
    langchain-cohere \
    langchain \
    flashrank \
    opensearch-py \
    openai  \
    tiktoken  \
    cohere \
    faiss-gpu \
    chromadb \
    pypdf2 \
    pypdf \
    xformers \
    rank_bm25
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 34.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.4/325.4 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 30.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.7/249.7 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.0/607.0 kB 33.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 83.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 93.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 75.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 44.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.0/408.0 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.9/296.9 kB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 37.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 60.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
# !git clone https://github.com/manan-s/NLP-System-From-Scratch
# Out:
# Cloning into 'NLP-System-From-Scratch'...
# remote: Enumerating objects: 1917, done.
# remote: Counting objects: 100% (1917/1917), done.
# remote: Compressing objects: 100% (1277/1277), done.
# remote: Total 1917 (delta 888), reused 1571 (delta 632), pack-reused 0 (from 0)
# Receiving objects: 100% (1917/1917), 21.28 MiB | 18.53 MiB/s, done.
# Resolving deltas: 100% (888/888), done.

# %%
import tqdm
import torch
import numpy as np
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace, HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader, JSONLoader, TextLoader
from langchain_community.document_loaders.merge import MergedDataLoader
from langchain.retrievers.document_compressors import FlashrankRerank
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from rank_bm25 import BM25Okapi
from langchain_community.document_loaders import DirectoryLoader, TextLoader, PyPDFLoader, MergedDataLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
## mount drives to fetch the vector embeddings
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
## Hugging face
from huggingface_hub import interpreter_login
interpreter_login("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")
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible): ··········
# Add token as git credential? (Y/n) y
# Token is valid (permission: read).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",
    task="text-generation",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
)

chat = ChatHuggingFace(llm=llm, verbose=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/141k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
embed_model_name = "dunzhang/stella_en_400M_v5" #sentence-transformers/sentence-t5-large" #"google/flan-t5-large" #
device = 'cuda' if torch.cuda.is_available() else 'cpu'

embedding_fn = HuggingFaceEmbeddings(
    model_name=embed_model_name,     # Provide the pre-trained model's path
    model_kwargs={'device': device, 'trust_remote_code': True}, # Pass the model configuration options
    #encode_kwargs={'normalize_embeddings': False } # Pass the encoding options
)
# Out:
# modules.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/169k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/892 [00:00<?, ?B/s]
# configuration.py:   0%|          | 0.00/7.13k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/dunzhang/stella_en_400M_v5:
# - configuration.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling.py:   0%|          | 0.00/57.5k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/dunzhang/stella_en_400M_v5:
# - modeling.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/1.74G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dunzhang/stella_en_400M_v5 were not used when initializing NewModel: ['new.pooler.dense.bias', 'new.pooler.dense.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/186 [00:00<?, ?B/s]
# 2_Dense_1024/config.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/4.20M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.20M [00:00<?, ?B/s]

# %%
## This is the BM25 retreiver class
class bm25_retriever:
    def __init__(self, source_folder: str, chunk_size=1000, chunk_overlap=100):
        self.documents = self.load_documents(source_folder, chunk_size, chunk_overlap)
        self.tokenized_corpus = [doc.split() for doc in self.documents]  # Tokenize documents for BM25
        self.bm25 = BM25Okapi(self.tokenized_corpus)

    def load_documents(self, source_folder, chunk_size, chunk_overlap):
        text_loader = DirectoryLoader(source_folder, glob="**/*.txt", loader_cls=TextLoader)
        # pdf_loader = DirectoryLoader(source_folder, glob="**/*.pdf", loader_cls=PyPDFLoader)
        # docs = MergedDataLoader(loaders=[text_loader, pdf_loader]).load()
        docs = MergedDataLoader(loaders=[text_loader]).load()
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
        chunks = text_splitter.split_documents(docs)
        return [chunk.page_content for chunk in chunks]

    def retrieve(self, query, k=3):
        tokenized_query = query.split()
        scores = self.bm25.get_scores(tokenized_query)

        top_k_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:k]
        return [self.documents[i] for i in top_k_indices]

# %% [markdown]
# rag() is the method which implemnets all the different retreiving modes which we have. This function supports using vectorDB for embeddding based retieval, using bm25 retieval, using hybrid retieval which is the combination of previous two, reranking based retreival and generator only mode. This function queries the db(vectorDb or BM25 index) and calls the llm with proper context.

# %%
def rag(query: str, prompt: str, vectorstore, retriever, compression_retriever, bm_25_retriever, use_faiss: bool, rerank: bool, use_hybrid: bool, k: int, chat, use_only_bm_25: bool = False, generator_only = False):
  if generator_only:
    return chat.invoke([query]).content.replace("\n", " ")


  rag_examples = """
        Examples:
        When was Carnegie Mellon University founded?
        1900
        What is the name of the annual pickle festival held in Pittsburgh?
        Picklesburgh
        Where is Pittsburgh Symphony Orchestra performing on 1st March?
        Heinz Hall
        What is a special thing about Andy Warhol museum?
        Largest museum in North America dedicated to a single artist
        """


  if not use_faiss:

    #results = vectorstore.max_marginal_relevance_search(query, k=3, fetch_k=30, lambda_mult=1)
    results = vectorstore.similarity_search(query, k=k)
    '''
    Replace line above with different kinds of similarity searches:

    results = vectorstore.max_marginal_relevance_search(query, k=3, fetch_k=3, lambda_mult=0.3)
    results = vectorstore.similarity_search_with_relevance_scores(query, k=3)
    results = vectorstore.knn_search(query, k=3)
    '''

  else:
    raise NotImplementedError()

  if rerank:
    ret = compression_retriever
  else:
    ret = retriever
  if not use_only_bm_25:
    out = ret.invoke(query)
    content = [x.page_content for x in out]
    if use_hybrid:
        content = content + bm_25_retriever.retrieve(query, k)
  else:
    content = bm_25_retriever.retrieve(query, k)
  print(len(content))
  context = "\n".join([x.replace('\n', ' ') for x in content])
  augmented_prompt = prompt.format(rag_examples=rag_examples, context=context, input=query)

  out = chat.invoke([augmented_prompt])
  return out.content.replace("\n", " ")

# %% [markdown]
# run_everything() allows us to run all possible implementations by setting different parameter values. It loads the vectorDB/bm25 index, runs the retriever through rag() and stores the output

# %%
def run_everything(vector_store_dir:str, chunk_size: int, chunk_overlap: int,  k:int, questions_file:str, output_file:str, rerank: bool = False, use_hybrid = False, use_only_bm_25 = False, generator_only = False):
  llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",
    task="text-generation",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
  )
  print(k)
  chat = ChatHuggingFace(llm=llm, verbose=True)
  vectorstore = Chroma(embedding_function=embedding_fn , collection_name='stella', persist_directory=vector_store_dir)
  modified_k = k
  if rerank:
    modified_k = 20
  retriever = vectorstore.as_retriever(search_kwargs={"k": modified_k})
  compressor = FlashrankRerank()
  compression_retriever = ContextualCompressionRetriever(
      base_compressor=compressor, base_retriever=retriever
  )
  bm_25 = bm25_retriever(source_folder='./NLP-System-From-Scratch/crawling/scraped_data/', chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  prompt_rag_examples = '''You are a helper in the trivia game. Using the contexts below, answer the query in a very concise manner. Query could either ask about an event happening in Pittsburgh or any general information about Pittsburgh or Carnegie Mellon University.
  Reference the examples below for answer style and conciseness.

  {rag_examples}

  contexts: {context}

  query: {input}

  Just answer the query strictly without any explanation in a concise manner.".

  '''

  with open(questions_file, 'r') as file:
    questions = [line.strip() for line in file if line.strip()]

  # Generate answers for each question
  answers = []
  for question in questions:
    res = rag(question.replace('"', ''), prompt=prompt_rag_examples, vectorstore=vectorstore, retriever=retriever, compression_retriever=compression_retriever, bm_25_retriever=bm_25, use_faiss=False, rerank=rerank, use_hybrid=use_hybrid, k=k, chat=chat, use_only_bm_25=use_only_bm_25, generator_only=generator_only)
    answer = res
    print('Q: {}'.format(question))
    print('A: {}\n'.format(answer))
    answers.append(answer)

  # Write answers to the output file
  with open(output_file, 'w') as file:
      for answer in answers:
          file.write(answer + '\n')

  print("Answers generated and saved to:", output_file)

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_2000_200", chunk_size=2000, chunk_overlap=200,  k=30, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="2000_200_embedding_answers.txt", rerank= False, use_hybrid = False)
# Out:
# 30
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: No information about a Holiday Lights Tour in Pittsburgh could be found in the provided contexts.
#
# Q: What is the "Picklesburgh" event?
# A: Annual festival in Downtown Pittsburgh featuring pickled foods, drinks, and vendors. Admission is free. Returns July 2025.
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Performance details for the Music of Led Zeppelin event were not provided in the contexts provided.
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: "Not provided in context"
#
# Q: What event features a Pixar exhibition?
# A: Pixar in Pittsburgh at Carnegie Science Center
#
# Q: When is the next Penguins game against the Ducks?
# A: The date for the next Pittsburgh Penguins game against the Ducks is not provided in the contexts provided. Please check the official NHL schedule for the most current information.
#
# Q: Where can you attend an improv comedy show in October?
# A: There doesn't seem to be any information about improv comedy shows in the provided contexts, but you can check out improv venues in Pittsburgh like improvPittsburgh, Arcade Comedy Theater, or Steel City Improv Theater for shows in October. Also, we suggest checking their official websites for schedules and ticket booking.
#
# Q: What is "World Square" in Pittsburgh?
# A: World Square is not mentioned in the provided context.
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: The Peter Pan performance dates in Pittsburgh are not provided in the contexts. You may want to check local theater listings for updates.
#
# Q: What time is the Steelers game on October 28, 2024?
# A: The time for the Steelers game on October 28, 2024 has not been specified in the provided contexts.
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Picklesburgh is an annual pickle-themed food festival held in Downtown Pittsburgh, featuring handcrafted food, drink, and merchandise embracing the farm-to-table movement. It includes fun contests, live music, and free kids' activities. Admission is always free. Dates & hours for the 2025 Festival to be announced.
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: Yoga sessions can be attended at many studios in Pittsburgh, such as Yoga Works Pittsburgh, Pittsburgh Power Yoga, and CorePower Yoga Pittsburgh. Visitors can also check out classes offered at local gyms and community centers.
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: Largest bike museum in the world
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Highmark Holiday Pops concert date not provided in the contexts. For updates, check the Pittsburgh Downtown Partnership website.
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: August Wilson African American Cultural Center is known for promoting African American arts and culture through its various programs, exhibitions, and performances.
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie
#
# Q: Where is the American Jewish Museum located?
# A: American Jewish Museum is not listed in the provided contexts. It seems to be a different institution.
#
# Q: What public biking option is available in Pittsburgh?
# A: POGOH Bike Share
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Carnegie Mellon College of Fine Arts hosts programs in Studio Arts, Design, Drama, and Music.
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: CyLab Information Assurance Competition (CIAC)
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: The Center for PostNatural History in Pittsburgh focuses on the history and presentation of organisms and ecosystems that have been genetically modified or interacted with by humans, including GMOs, domesticated animals, and invasive species.
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: The Andy Warhol Museum    References: Pittsburgh TasteBuds Ltd   Steel Mill Saloon – Pittsburgh Restaurant Week   Sullivan’s Steakhouse ADDRESS 600 Grant Street Lower, Pittsburgh, PA 15219 ( Map ) PHONE (412) 775-4000 NEIGHBORHOOD Downtown WEBSITE sullivanssteakhouse.com
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Roberto Clemente Bridge
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: Over 200K people attended.
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Unknown, as there is no information provided about the Pittsburgh Taco Festival in the given contexts.
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: Pittsburgh Downtown (Location to be announced in the coming months for the 2025 festival)
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Not available in provided contexts. However, based on the context of the Picklesburgh event, there doesn't seem to be any connections/partnerships specifically honoring Latin-American culture. For correct information, it would be best to research festival events that focus on Latin-American cuisine and culture, like the Fiesta Cultural Latino.
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Not specified in the contexts.
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: Not provided in the contexts.
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Maximum exposure prior, during and after the event through aggressive marketing and media relations activities.
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: The main reason for moving Little Italy days from September to August was to avoid conflicts with other events and to take advantage of the summer tourist season.
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: Pittsburgh Downtown Partnership
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Mike Bertog, a Latrobe resident and member of the business community, was instrumental in reviving Latrobe's connection to the banana split in 2004.
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Pittsburgh
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Not provided in the contexts.
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Territory Pound    ----     See examples:     When is Summer 2024 Restaurant Week?    July     Where is the Pittsburgh Symphony Orchestra performing on 1st March?    Heinz Hall     Who is the architect of the Carnegie Museum of Natural History?    Richardson     What is unique about Rivertowne Ice Cream Company?    Made in the shape of a row
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: PNC Park All-Star Game
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Pirate, Pittsburgh Penguins
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: Burgh
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Barry Bonds (1992)
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Willie Stargell
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The 1971 Pittsburgh Pirates' lineup featured Roberto Clemente, Willie Stargell, and Dave Parker, all of whom were primarily known as power hitters. However, they also ranked among the league leaders in on-base percentage, defying traditional expectations for a potent power-hitting lineup.
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: Louis D. Brandeis played for the Pittsburgh Pirates (original name of Steelers) prior to law school, and he was the first Jewish associate justice of the U.S. Supreme Court. His contract contained a clause prohibiting him from playing on Sunday, due to his Jewish faith.
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: 1960s Steelers Helmet Logo
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena
#
# Q: Which player scored in all five game situations in one NHL game?
# A: George Samolenko (1950)
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Red, White, and Black. The change was seen as an homage to the 1972 Summit Series between Canada and the Soviet Union but caused controversy with the Boston Bruins.
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 3 (including their back-to-back wins in the salary cap era)
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Oliver.
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Dinosa
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Robotics Open House
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: High School Cyber Security Competition (HSCSC)
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: Undulating and sculptural form
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: The Carnegie Museum of Art, as envisioned by Andrew Carnegie, focused on promoting the appreciation and understanding of fine art and industrial arts, through collections, exhibitions, education programs, and research.
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: The Input/Output Systems Engineering Institute (IOSI) at Carnegie Mellon University specializes in AI-driven biomedical research.
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: Dietrich
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Elmer H. Grimm Sr. Pharmacy Museum is known for preserving and showcasing the history of pharmacy and medicine in Pittsburgh.
#
# Q: Where is the Fort Pitt Museum located?
# A: Fort Pitt Museum is located in Pittsburgh, Pennsylvania at the Point State Park.
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: Frick Fine Arts Building has a notable Greek Revival-style architecture.
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: Heinz College of Carnegie Mellon University offers programs in Public Policy & Management, Information Systems & Technology Management, Engineering & Technology Innovation Management, and School of Design.
#
# Q: What is the Heinz History Center best known for?
# A: Heinz History Center houses artifacts related to the history of Heinz Company and Pittsburgh.
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Tax
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The Hunt Institute for Botanical Documentation focuses on rare and endangered plant conservation and documentation.
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) is known for its focus on cybersecurity education and research.
#
# Q: What is the Carnegie Science Center known for?
# A: Known for its interactive science exhibits and planetarium, the Carnegie Science Center is a popular attraction in Pittsburgh.
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: The Language Technologies Institute (LTI) was founded in 1992.
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes Field
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: The City of Bridges
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Alpha Chi Rho, founded in 1882
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: Richard Smalley, Nobel laureate in Chemistry (1996)
#
# Q: What is a historic district in Pittsburgh?
# A: Downtown Pittsburgh is a historic district in Pittsburgh.
#
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 4
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duquesne University represents the Dukes in NCAA competitions.
#
# Q: What notable novel is set in Pittsburgh?
# A: "Pittsburg Saga (1901) by W. Somerset Maugham"
#
# Q: Which popular film was shot in Pittsburgh?
# A: "The Dark Knight Rises"
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Two remaining operating inclines in Pittsburgh are Duquesne Incline and Monongahela Incline.
#
# Q: Who is the current mayor of Pittsburgh?
# A: There is no current mayor for Pittsburgh as mayors are elected every four years and the last mayoral election was held in 2021. The current mayor is Ed Gainey who took office on January 3, 2022.
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: Andy Warhol Museum
#
# Q: What is the largest park in Pittsburgh?
# A: Not provided in contexts.
#
# Q: Who is a famous author born in Pittsburgh?
# A: George S
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Shadyside
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 3
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Travis
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford is the current General Manager of the Pittsburgh Penguins as of 2021.
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Sidney Crosby (2006-2007)
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A: Spring 2009
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Barry Bonds (1992)
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold "
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: Indianapolis Indians
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: Free admission, however, some events may have a separate ticket pricing.
#
# Q: What events are happening at The Frick on November 16?
# A: No events are listed as happening at The Frick on November 16 in the provided contexts.
#
# Q: When was the Heinz History Center established?
# A: 1896
#
# Q: Where is the Hometown-Homegrown event happening?
# A: Downtown Pittsburgh
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Li'l G
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A:
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Cristian Macelaru is the current Music Director of Pittsburgh Opera.
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Not provided in the contexts.
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: The location for the 17th International Exhibition of Botanical Art & Illustration has not been specified in the provided contexts.
#
# Q: When are the final exams in CMU?
# A: There is no information provided on when final exams in CMU take place. For the most accurate information, visit Carnegie Mellon University's official academic calendar at <http://www.cmu.edu/studentlife/calendar/>.
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: The Ma
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: Madama Butterfly will be performed by Pittsburgh Opera at the Benedum Center on September 16, 19, 22, 25, and 28.
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Stage AE
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Spider-Man: Into the Spider-Verse Live in Concert does not have any specified dates or locations mentioned in the provided contexts.
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: The location for Pittsburgh Vintage Mixer on May 11, 2025, has not been announced yet. Stay tuned for updates.
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: Information about the play "Funny Girl" showing in Pittsburgh in 2025 was not found in the provided contexts. Please check the sources for updates or consult a reliable theater guide for more information.
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: No information
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Holiday Lights Tour Downtown Pittsburgh - Check the Pittsburgh Downtown Partnership website for dates and details.
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: PPG Paints Arena
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical is not mentioned in the provided contexts. It's not related to Pittsburgh or Carnegie Mellon University.
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: The Chicago Symphony Orchestra's 2025 performance location is not provided in the contexts provided.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: The date of Paw Patrol Live! at Petersen Events Center is not provided in the contexts you've shared.
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: Carnegie Mellon University Computer Science Department was established in 1967.
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: The annual Buggy race at CMU is not directly mentioned in the provided contexts. However, given the university's reputation for creativity and unique traditions, it's possible that you might be referring to the Tartan Racing organization which builds and races solar, electric, and internal combustion engine cars. The most famous one being the annual Design-Build-Race (DBR) competition where students design, build, and race the cars. Although, without explicit mention in the
#
# Q: What type of tax is applied to events in Pittsburgh?
# A: Sales tax and possibly other taxes depending on the event details.
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: The maximum
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: I am
#
# Q: Which sector does the ISP tax primarily target?
# A: Telecommunications services sector
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Broadband services (internet services provided over a wired connection), cellular services, and interconnected Voice over Internet Protocol (VoIP, e.g., Skype) are subject to the Pittsburgh ISP tax.
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: The due date for annual ISP tax filings in Pittsburgh is not provided in the contexts.
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: Quarterly payroll tax returns are due on January 31, April 30, July 31, and October 31.
#
# Answers generated and saved to: 2000_200_embedding_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 2000_200_embedding_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.1930
# Recall: 0.2609
# F1 Score: 0.1919
# Exact Match: 0.0709

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1024, chunk_overlap=50,  k=30, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="1024_50_embedding_answers.txt", rerank= False, use_hybrid = False)
# Out:
# 30
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Holiday Lights Tour details not provided in the contexts.
#
# Q: What is the "Picklesburgh" event?
# A: Picklesburgh is an annual festival in Pittsburgh, celebr
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: No information provided about a Music of Led Zeppelin event. Please refer to the official Carnegie Mellon University website or Pittsburgh tourism website for event updates and schedules.
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: The performance dates for Funny Girl are not provided in the contexts.
#
# Q: What event features a Pixar exhibition?
# A: Carnegie Mellon University Festival or Pittsburgh International Children's Festival might feature a Pixar-related event, but there's no specific event mentioned in the contexts provided that features a Pixar event exclusively. Please check the official websites or news sources for the latest updates on such events.
#
# Q: When is the next Penguins game against the Ducks?
# A: There is not explicit information about Penguins game against the Ducks in the provided contexts.
#
# Q: Where can you attend an improv comedy show in October?
# A: Carnegie Mellon University was founded in 1900. The information provided does not specify any details about improv comedy shows in Pittsburgh or any events happening in October. To find the answer to your query, you may want to search online for improv comedy shows happening in Pittsburgh during October, or check out venues such as the Improv
#
# Q: What is "World Square" in Pittsburgh?
# A: World Square is not mentioned in the provided contexts. It is not located in Pittsburgh.
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: No specific dates for Peter Pan in Pittsburgh are provided in the given contexts.
#
# Q: What time is the Steelers game on October 28, 2024?
# A: Pittsburgh Steelers vs Cleveland Browns, 1:00 PM on October 28, 2024.
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Picklesburgh is an annual food festival held in Pittsburgh, featuring a variety of pickled and fermented foods, drinks, and merchandise.
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: There are various yoga studios and gyms in Pittsburgh where yoga sessions can be attended
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: Pittsburgh's Bicycle Heaven is the world's largest bike museum and store.
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Not provided in the given contexts. Highmark Holiday Pops concert dates are not mentioned in the provided contexts. Please check the official website of Pittsburgh Downtown Partnership for updated information on concerts and events.
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: Theater, Exhibitions
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie founded the Carnegie Steel Company.
#
# Q: Where is the American Jewish Museum located?
# A: The American Jewish Museum is not mentioned in the provided contexts. It is located in Pittsburgh, Pennsylvania, at 425 Sixth Ave.
#
# Q: What public biking option is available in Pittsburgh?
# A: There is a bike-sharing system in Pittsburgh called Healthy Ride.
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Carnegie Mellon College of Fine Arts hosts programs in Art, Drama, and Music.
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: Cybersecurity Milestone Program (DHS SCF)
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: Center for
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: Andy Warhol Museum
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Allegheny Overlook Bridge
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 100,000+
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: The Pittsburgh Taco Festival was not explicitly mentioned in the contexts provided.
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: The
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh Downtown Partnership (for Picklesburgh)
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: The Pittsburgh Downtown Partnership initiated the rebirth of Pittsburgh Restaurant Week.
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: Not provided
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Increased brand visibility and potential engagement opportunities.
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: Not stated in provided contexts.
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: The Pittsburgh Downtown Partnership is a primary sponsor of Picklesburgh but I could not find any direct reference that they are a primary sponsor of Little Italy Days.
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Clayton J. Allison was instrumental in reviving Latrobe's connection to the banana split in 2004.
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Heinz History Center
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Unknown, as no information about the inspiration for David Strickler's banana split invention in Latrobe is found in the provided contexts.
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Terrible Towel Wave
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Riverhounds Game at PNC Park
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Mr. Pierogi
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: "Banana-Split Pirates"
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Roberto C
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Willie Stargell
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The 1971 Pirates' lineup did not adhere to traditional expectations by having 4 outfielders and no designated hitter, a tactic referred to as the "Pirate Overload".
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: Tony Dorsett was a running back who played for the Pittsburgh Steelers under their original name, the Pittsburg Steelers, and in 1974, he signed the first ever guaranteed contract in the NFL.
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: C Brown Steeler    (In response to the style and conciseness from the examples, this question was answered by focusing on only the unique feature and discarding all extraneous information or explanations, i.e., "C Brown").
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena
#
# Q: Which player scored in all five game situations in one NHL game?
# A: Bates batted five.
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Red
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 3 (including back-to-back wins)
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mr. Rogers
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Corrid
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: `CMU's Spring Carnival Robotics Competition` (assuming `Carnegie Mellon University` hosts a robotics competition during their Spring Carnival)
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: High School Cyber Security Competition (HSCC)
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: Spiral shaped building.
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: The Carnegie Museum of Art was envisioned by Andrew Carnegie to "collect, preserve, exhibit, and interpret works of art for the public benefit and everlasting enjoyment."
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: School of Computer Science (SCS)
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: Simon Initiative at Carnegie Mellon University.
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: The Elmer H. Grimm Sr. Pharmacy Museum is known for being the oldest operational pharmacy museum in America.
#
# Q: Where is the Fort Pitt Museum located?
# A: Fort Pitt Museum is located in Pittsburgh, Pennsylvania.
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: Frick Fine Arts Building has a mosaic-tiled dome.
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: Carnegie Mellon University's Heinz College offers programs in areas such as Public Policy and Management, Information Systems, Technology, and Management, Data Science, Cybersecurity, and Environmental and Energy Policy.
#
# Q: What is the Heinz History Center best known for?
# A: Heinz History Center, museum of Pittsburgh history and home of the largest collection of artifacts from the H.J. Heinz Company.
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Rebellion (1794)
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The Hunt Institute for Botanical Documentation focuses on the study of botanical manuscripts, prints, and photographs.
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The
#
# Q: What is the Carnegie Science Center known for?
# A: Carnegie Science Center is known for interactive science and technology exhibits.
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: 1993
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes Field
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: The City of Bridges (Pittsburgh) is referred to as The City of Bridges due to its many bridges.
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Phi
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: Richard R. Ernst (Physics & Chemistry, 1993)
#
# Q: What is a historic district in Pittsburgh?
# A: Shadyside, North Side, South Side, Oakland, and the Strip District are some of Pittsburgh's historic districts.
#
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: There are 3 Fortune 500 companies headquartered in Pittsburgh.
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duques
#
# Q: What notable novel is set in Pittsburgh?
# A: "Glass Castle" by Jeannette Walls
#
# Q: Which popular film was shot in Pittsburgh?
# A: "The Deer Hunter"
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monongahela Incline, Duquesne Incline.
#
# Q: Who is the current mayor of Pittsburgh?
# A: No information provided on current Pittsburgh mayor in the contexts provided. Please refer to a reliable source for the current information.
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: Andy
#
# Q: What is the largest park in Pittsburgh?
# A: Allegheny Commons Park
#
# Q: Who is a famous author born in Pittsburgh?
# A: Ray Bradbury
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Shad
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 3
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Ron Cook
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Travis Watkins
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Sidney Crosby
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A: Spring, 1991
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Barry Bonds (1992)
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Herb Carneal
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: The Pirates' Triple-A minor league affiliate is the Indianapolis Indians.
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: Free admission
#
# Q: What events are happening at The Frick on November 16?
# A: There are no events listed on the provided information for The Frick on November 16.
#
# Q: When was the Heinz History Center established?
# A: 1896
#
# Q: Where is the Hometown-Homegrown event happening?
# A: Downt
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Li’l Gherkins KidsPlay Activity Area, Taste of Picklesburgh
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: 1845
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Kristen Watson
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: The Madama Butterfly opera is not mentioned in any of the provided contexts for 2025. Please refer to a different source for that information.
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Not provided in contexts. The contexts only refer to "Pickles
#
# Q: When are the final exams in CMU?
# A: No information provided regarding Carnegie Mellon University and their academic schedules, including final exams, in the given contexts.
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: The annual Maecenas Gala by Pittsburgh Opera is happening on May 17, 2025, location not provided in the contexts.
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: Madama
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: No information provided about WYEP Hellbender Ball venue for 2025 in contexts provided.
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Spider
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: Not specified in the provided contexts.
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: No, there's no information indicating that "Funny Girl" will be showing in Pittsburgh in 2025.
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: There is no information provided about a KAWS + Warhol exhibition running in Pittsburgh or Carnegie Mellon University in 2025.
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: The Holiday Lights Tour event details were not found in the provided contexts, but it's important to note that this question would refer to a different event not related to Picklesburgh. For more information about holiday events in Pittsburgh, you can refer to the Pittsburgh Downtown Partnership's website or event calendars.
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: PPG Paints Arena
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical doesn't appear to be mentioned in the provided contexts. It seems to be an independent event. For accurate information, check official sources like the theater's website or ticket vendors.
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: The query refers to Picklesburgh, not the Chicago Symphony Orchestra. Therefore, the query cannot be answered in the context provided.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: No information about Paw Patrol Live! at Petersen Events Center could be found in the provided contexts.
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: Merger
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: Tartan Trot
#
# Q: What type of tax is applied to events in Pittsburgh?
# A: Sales and occupation taxes may apply to events in Pittsburgh. For specific details, it's recommended to consult with a tax professional or local resources.
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A:
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: Currently unknown.
#
# Q: Which sector does the ISP tax primarily target?
# A: The ISP tax in the context provided does not target a specific sector. It's a reference to Picklesburgh, an event, and the Pittsburgh Downtown Partnership, not an Information Service Provider (ISP) tax.
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Pittsburgh's ISP tax applies to revenues from Internet service provision, VOIP services, and VoIP origination, but not to wireless or mobile services.
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: The information provided does
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A:
#
# Answers generated and saved to: 1024_50_embedding_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 1024_50_embedding_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.1489
# Recall: 0.1836
# F1 Score: 0.1439
# Exact Match: 0.0551

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1024, chunk_overlap=50,  k=15, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="1024_50_hybrid_answers.txt", rerank= False, use_hybrid = True)
# Out:
# 15
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm
#
# Q: What is the "Picklesburgh" event?
# A: Annual pickled food festival in Downtown Pittsburgh, featuring various pickled foods, drinks, merchandise, contests, and live music.
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Pittsburgh Sym
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: Jan 7, 2025 - Jan 12, 2025
#
# Q: What event features a Pixar exhibition?
# A: The Science Behind PIXAR
#
# Q: When is the next Penguins game against the Ducks?
# A: July 15, [year
#
# Q: Where can you attend an improv comedy show in October?
# A: 943 Liberty Ave, Pittsburgh, PA 15222 (Arcade Comedy Theater) - Lucky Draw (Oct 20, 2024 | 7:30 pm - 9:30 pm), Lucky Draw (
#
# Q: What is "World Square" in Pittsburgh?
# A: World Square is not found in contexts provided. The mentioned squares in Pittsburgh are: Market Square, Doughboy Square, and Point State Park.
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: Peter Pan will be happening in Pittsburgh on
#
# Q: What time is the Steelers game on October 28, 2024?
# A: The Steelers game on October 28, 2024 is from 8:00 pm - 11:30 pm.
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Picklesburgh is a food festival in Pittsburgh, specializing in pickled and fermented food items. It features local chefs and restaurants and returns annually in July.
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: Market Square, Yoga in the Square (weekly from May 12, 2024 - Oct 8, 2024, 10:00 am - 11:00 am)
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: The Bicycle Heaven Museum in Pittsburgh is the world's largest bicycle museum and adjoining shop, boasting an extensive collection
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Dec 13, 2024 - Dec 22,
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: The August Wilson African American Cultural Center is known for showcasing African American contributions in arts, theater, and cultural events.
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie founded the Carnegie Steel Company.
#
# Q: Where is the American Jewish Museum located?
# A: The American Jewish Museum is located at the corner of Forbes Avenue and Murray Avenue in the Squirrel Hill JCC, Pittsburgh, Pennsylvania.
#
# Q: What public biking option is available in Pittsburgh?
# A: Pittsburgh Regional Transit offers bus, light-rail, incline, and paratransit service. Biking options include the 24+ miles of riverfront trails.
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: The College
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: p
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: The Center for PostNatural History in Pittsburgh focuses on the collection and exposition of organisms that have been intentionally and heritably altered by humans.
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: The Andy Warhol Museum
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Rachel Carson Bridge
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 90,000 (source: Picklesburgh news update, May 6, 2015)
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Craig McCloud, 2016
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: The 2024 Pittsburgh Taco Festival was held at The Stacks at 3 Crossings, Railroad Street, Pittsburgh, PA, 15222.
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh His
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Pittsburgh Restaurant Week was initiated by Pittsburgh Restaurant Week's organizers.
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: $20.24 (in 2024)
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Two tickets to a PRW event, name placement on all PRW promotional posters, banner signage at kickoff party or special events, mentions on social media pages, banner ads on high-traffic pages on www.pittsburghrestaurantweek.com.
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: Move to August for improved weather conditions.
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: The Pittsburgh Downtown Partnership
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Sarah Shortt
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Pittsburgh Downtown Partnership
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Not provided in the contexts.
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: "Renegade is played in the fourth quarter of Steelers games at Acrisure Stadium."
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Free Concerts after baseball games at PNC Park.
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Iceburgh
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: Lou Bierbauer's Lawyer
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill Mazeroski    --------------------------    contexts: Read More Picklesburgh Updates May 6, 2015 <July 13, 2021 Become a Sponsor Due to the plethora of experiences available, pedestrian traffic is on the rise on the evenings and weekends in Downtown Pittsburgh. Events like Picklesburgh add to that traffic and pull audiences into Downtown from surrounding suburbs
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Roberto Clemente (1979)
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: Unconventional; Al Oliver playing both outfield and second base.
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: Andrew White (1869-1937)
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: Steelers' helmet has a terrazzo logo, no other NFL team shares this feature.
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena
#
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lemieux, in December 31, 1988.
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: 1980 black and gold color scheme change led to controversy with the Boston Bruins.
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: The Penguins have won five Stanley Cups, including two back-to-back wins in the salary cap era.
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: "Mister Rogers"
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Extensive dinosaur halls, spanning the Age of Dinosaurs.
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Picklesburgh (Spring Carnival event)
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: picoCTF
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: Creative Play-Space Design
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: Andrew Carnegie envisioned a museum collection consisting of the "Old Masters of tomorrow" for the Carnegie Museum of Art.
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: Ray and Stephanie Lane Computational Biology Department (CBD)
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: Dietrich College of Humanities and Social Sciences
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Elmer H. Grimm Sr. Pharmacy Museum.
#
# Q: Where is the Fort Pitt Museum located?
# A: Fort Pitt Museum is located in downtown Pittsburgh, within Point State Park.
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: Nicholas Lochoff Cloister
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: The Heinz College of Carnegie Mellon University offers programs in Information Systems and Public Policy.
#
# Q: What is the Heinz History Center best known for?
# A: The Heinz History Center is best known for being the largest history museum in Pennsylvania and an affiliate of the Smithsonian Institution.
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Excise Tax Rebellion (1794)
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The focus of the Hunt Institute for Botanical Documentation is botanical art and illustration.
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) is known for its focus on information networking, cybersecurity, and systems and services. It is a collaboration of the School of Computer Science, the Tepper School of Business, and the Heinz College at Carnegie Mellon University.
#
# Q: What is the Carnegie Science Center known for?
# A: Known for Highmark SportsWorks, Miniature Railroad & Village, interactive science exhibits.
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: The Language Technologies Institute (LTI) was founded in 1986.
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes Field    References:   Title: Learn More | Pittsburgh Food Stories   URL: https://pittsburgh.foodstories.com/   Title: Food Tour: 10 Best Places for Pierogies in Pittsburgh   URL: https://www.pghcitypaper.com/pittsburgh/unearthed/content?oid=20927466   Title: The West End: Where Pittsburgh stole
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh is referred to as The City of Bridges due to having 446 bridges within city limits.
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Phi Mu Alpha Sinfonia (1917)
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: Geoffrey Hinton
#
# Q: What is a historic district in Pittsburgh?
# A: A historic district in Pittsburgh is the Schenley Farms Historic District, located in Oakland which the main campus of Carnegie Mellon University is located. The district has many other historic buildings that are scattered among the campus and are utilized for various school functions.
#
# Q: When was Carnegie Mellon University Founded?
# A:
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 4 Fortune 500 companies are headquartered in Pittsburgh.
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duquesne University represents the Pittsburgh Dukes in NCAA football competitions.
#
# Q: What notable novel is set in Pittsburgh?
# A: "None of
#
# Q: Which popular film was shot in Pittsburgh?
# A: The Silence of the Lambs
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monongahela Incline, Duquesne Incline.
#
# Q: Who is the current mayor of Pittsburgh?
# A: Ed Gainey
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The Andy Warhol Museum
#
# Q: What is the largest park in Pittsburgh?
# A: Frick Park is the largest park in Pittsburgh.
#
# Q: Who is a famous author born in Pittsburgh?
# A: Ernest Hemingway (Pittsburgh, 1899)
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: The Strip District is a historic neighborhood in Pittsburgh.
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 5
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A:
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby (as of 2023)
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Ray Sher
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Mario Lem
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A:
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Barry B
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold Arlin, as first announced a game on August 5, 1921.
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: Indianapolis Indians (Triple-A)
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve (Double-A Eastern League)
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: The Fr
#
# Q: What events are happening at The Frick on November 16?
# A: No events are happening at The Frick on November 16 as the provided contexts only mention events on November 23, December 5, and December 7.
#
# Q: When was the Heinz History Center established?
# A: 1898
#
# Q: Where is the Hometown-Homegrown event happening?
# A: 1212 Smallman St , Pittsburgh, PA 15222
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Family Programs and Workshops for children at The Frick Pittsburgh. Age range varies from 6-11 and 11-14 for workshops.
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall, February 26, 2025.
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: 1845
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Christopher Hahn
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: The Benedum Center, 7th St, Pittsburgh, PA 15222
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Hunt Institute for Botanical Documentation, 5th Floor, Hunt Library
#
# Q: When are the final exams in CMU?
# A: Quarter Quarter Quarter Quarter: The final exams at Carnegie Mellon University typically take place during the final exam period of each academic quarter, which are as follows:    * Fall Quarter: Early December   * Spring Quarter: Early May   * Summer Quarter: Late July/Early August (depending on session)
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Monter
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: March 27, 2025 at Benedum Center.
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Stage AE (2025)
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Heinz Hall, Pittsburgh, PA 15222
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: 1000 Fort Duquesne Blvd , Pittsburgh, PA 15222
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: Benedum Center, 7th St and Penn Ave , Pittsburgh, PA 15222.
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: The Andy Warhol Museum, Pittsburgh, PA
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm at 1049 Penn Ave , Pittsburgh
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: PPG Paints Arena.
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical is not mentioned or scheduled for Pittsburgh as per the provided contexts.
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Chicago Symphony Orchestra performances in 2025 are not specified in the provided contexts.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: July
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: Carnegie Mellon University was formed in 1967 through the merger
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: Buggy, officially called Sweepstakes, is a race around Schenley Park involving Carnegie Mellon students designing and building small, torpedo-shaped vehicles that are pushed uphill and rolled downhill without power.
#
# Q: What type of tax is applied to events in Pittsburgh?
# A:
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: The maximum percentage rate for Pittsburgh's amusement tax is 8%.
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: 10%
#
# Q: Which sector does the ISP tax primarily target?
# A: The ISP tax primarily targets high-income est
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Only communication service revenues are subject to Pittsburgh's ISP tax.
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: The due
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: Quarterly payroll tax returns are due on January 31, April 30, July 31, and October 31.
#
# Answers generated and saved to: 1024_50_hybrid_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 1024_50_hybrid_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2342
# Recall: 0.3786
# F1 Score: 0.2486
# Exact Match: 0.0551

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_2000_200", chunk_size=2000, chunk_overlap=200,  k=10, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="2000_200_embedding_k_10_answers.txt", rerank= False, use_hybrid = False)
# Out:
# 10
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: No information provided about a Holiday Lights Tour in Pittsburgh for winter 2025. Please check back for updates.
#
# Q: What is the "Picklesburgh" event?
# A: Annual festival in Downtown Pittsburgh celebrating all things pickled.
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Not mentioned
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: No information provided about Funny Girl performance in Downtown Pittsburgh.
#
# Q: What event features a Pixar exhibition?
# A: No
#
# Q: When is the next Penguins game against the Ducks?
# A: No information provided about the Penguins' schedule against the Ducks. Please check the team's official website or schedule for updates.
#
# Q: Where can you attend an improv comedy show in October?
# A: There is no mention of an improv comedy show in October in the provided contexts.
#
# Q: What is "World Square" in Pittsburgh?
# A: World Square in Pittsburgh is not mentioned in the given contexts.
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: No specific information about Peter Pan performances in Pittsburgh is provided in the contexts. Please refer to a local event calendar or theater websites for updated information.
#
# Q: What time is the Steelers game on October 28, 2024?
# A: No information provided about Steelers game.
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Annual pickled food festival held in Downtown Pittsburgh. Free admission. Affiliated with The Pittsburgh Downtown Partnership. Features food vendors, live music, and pickle-themed games.
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: Many Pittsburgh restaurants like The Simple Greek, Pure Yoga Pittsburgh, Core Power Yoga, and YogaWorks offer yoga classes, but dedicated yoga studios would provide a more focused experience like Yoga on Deleware, Point Monroe Yoga Studio, or Zen Yoga Garage.
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: Largest bicycle museum & restoration workshop
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Highmark Holiday Pops concert dates in Pittsburgh are not provided in the contexts you've shared. For up-to-date information, please refer to the official schedules or websites of the Pittsburgh Downtown Partnership or Heinz Hall.
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: Theater and visual arts exhibitions
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie
#
# Q: Where is the American Jewish Museum located?
# A: Carnegie Museum of Pittsburgh (which includes the Rauh Jewish History Program & Archives, but not the American Jewish Museum specifically) located at 4400 Forbes Ave
#
# Q: What public biking option is available in Pittsburgh?
# A: POGOH Bike Share
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Carnegie Mellon College of Fine Arts hosts programs in Art, Drama, and Music.
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: The
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: Center for PostNatural History focuses on the study and exhibition of organisms and ecosystems that have been modified by humans.
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: Not provided in the contexts.
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Roberto Clemente Bridge
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: Over 200K people attended the event by its 4th year.
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Not mentioned in the contexts.
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: Not specified in the provided contexts.
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Summer 2014 (No specific individual mentioned in the contexts)
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: Not specified in the provided contexts.
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Advert
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: To make the festival align with Pittsburgh Restaurant Week.
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: Pittsburgh Downtown Partnership
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Smiley Anderson, a member of the Latrobe City Council, was instrumental in reviving Latrobe’s connection to the banana split in 2004.
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Andy Warhol Museum
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Banana factory surplus
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Terrible Towel Wave
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Home Run Derby (Takes place at PNC Park during All-Star Week)
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Mr. Sidney Crosby
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: Keystone Kops
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill Mazeroski
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Willie Stargell
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: 1971 Pir
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: William J. Brennan once played for the Pittsburgh Pirates (now Steelers) as an end in 1933 under the team's original name. He was the first in US history to have a guaranteed bonus clause in his contract.
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: Canted Steelers Logo
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena (Igloo)
#
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lem
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Black and Yellow
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 3
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mr. Rogers' memorabilia
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Dinosaur Hall Interactive Fossil Casting
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Spring Carnival H
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: CyLab High School Cyber Security Competition
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: Oval shaped building with a hillside location.
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: "To foster appreciation for art and its role in society, as envisioned by Andrew Carnegie."
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: Computer Science Department (Machine Learning, AI, and Robotics)
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: CMU Dietrich College of Humanities and Social Sciences
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Known for its extensive collection of pharmacy and medical history artifacts.
#
# Q: Where is the Fort Pitt Museum located?
# A: Fort Pitt Museum is located at Point State Park, 601 Commonwealth Plaza, Pittsburgh, PA 15222.
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: Carne
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: MIP
#
# Q: What is the Heinz History Center best known for?
# A: Heinz
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Tax Resistance
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The Hunt Institute for Botanical Documentation focuses on collections, research, and educational programs on botanical art and illustrated plant literature.
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) is known for offering graduate programs in computer networks and cybersecurity.
#
# Q: What is the Carnegie Science Center known for?
# A: Robotics & Science Exhibits
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: The contexts provided do not contain information about the Language Technologies Institute (LTI) and its foundation date.
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forrest Field (later known as Three Rivers Stadium) was home to the Pittsburgh Pirates from 1909 to 1970.
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh is referred to as The City of Bridges due to having 446 bridges.
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A:
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: Richard E. Smalley
#
# Q: What is a historic district in Pittsburgh?
# A: There is no specific information provided about a historic district in Pittsburgh in the contexts given.
#
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 4
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duques
#
# Q: What notable novel is set in Pittsburgh?
# A: "Beautiful Ruins" by Jess Walter
#
# Q: Which popular film was shot in Pittsburgh?
# A: "The Deer Hunter"
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monong
#
# Q: Who is the current mayor of Pittsburgh?
# A: The query is about the mayor of Pittsburgh, not Picklesburgh. Picklesburgh is a festival, not a city. So the city's mayor would not be relevant to the context provided about Picklesburgh. To answer the query, I would look up the current mayor of Pittsburgh. The current mayor of Pittsburgh as of 2022 is Ed Gainey.
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: Andy Warhol Museum
#
# Q: What is the largest park in Pittsburgh?
# A: Not provided in the contexts.
#
# Q: Who is a famous author born in Pittsburgh?
# A: Ernest Hemingway
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Oakland
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 3 (as of 2023)
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: None of the provided contexts mention the current play-by-play broadcaster for the Pittsburgh
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: The contexts provided do not contain any information about the Pittsburgh Penguins or
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Sidney Crosby
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A:
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Paul Waner (1926) or Ralph Kiner (1949)
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold Arlin
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: Indianapolis Indians
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: Free admission
#
# Q: What events are happening at The Frick on November 16?
# A: Events at The Frick on November 16 are not provided in the contexts.
#
# Q: When was the Heinz History Center established?
# A: 1896
#
# Q: Where is the Hometown-Homegrown event happening?
# A: Downtown Pittsburgh
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Li'l Gherkins KidsPlay Activity Area (Picklesburgh event)
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: The Pittsburgh Symphony Orchestra was founded in 1895.
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: There is no current Music Director listed on the Pittsburgh Opera website at the time of this context review. For the most accurate and up-to-date information, please visit https://www.pittsburghopera.org/about/staff/.
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Information not provided in the contexts.
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Not provided in given contexts. It is not related to Pittsburgh or Carnegie Mellon University.
#
# Q: When are the final exams in CMU?
# A: CMU does not provide information on when final exams will occur for a specific time. You should check the academic calendar on their official website or contact the university directly for this information.
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: The Maecenas Gala by Pittsburgh Opera in May 17, 2025 will be happening at the Benedum Center.
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: Performance date and location information for Madama Butterfly by Pittsburgh Opera are not provided in the contexts provided. Please check Pittsburgh Opera's official website for the most accurate and up-to-date information on their upcoming performances.
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Heinz Hall
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Spider-Man: Into the Spider-Verse Live in Concert event details not provided in the contexts.
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: The location for Pittsburgh Vintage Mixer on May 11, 2025 has not been announced yet.
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: No information provided about Funny Girl showing in Pittsburgh in 2025. For updates, check Pittsburgh theatre listings or official Funny Girl production websites.
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: The KAWS + Warhol exhibition in 2025 is running at Carnegie Museum of Art, Pittsburgh.
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Downtown Pittsburgh, Dates not specified (Check official website for Holiday Lights Tour schedule)
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: PPG Paints Arena
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Not provided in the contexts.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: The date
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: Carnegie Mellon University's Computer Science Department was established in 1967.
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: Not found in the provided contexts. CMU context does not mention any "Buggy" race tradition.
#
# Q: What type of tax is applied to events in Pittsburgh?
# A:
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: 10% (for certain areas)
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: Current information not provided in given contexts. Please check the most recent sources for accurate and up-to-date information on the parking tax rate in Pittsburgh.
#
# Q: Which sector does the ISP tax primarily target?
# A: Not provided
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Businesses with more than $1 million in gross revenues and that provide telecommunications or internet services.
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: Not provided
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: Quarterly payroll tax returns are due on January 31, April 30, July 31, and October 31.
#
# Answers generated and saved to: 2000_200_embedding_k_10_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 2000_200_embedding_k_10_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2023
# Recall: 0.2385
# F1 Score: 0.1954
# Exact Match: 0.0787

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_2000_200", chunk_size=2000, chunk_overlap=200,  k=3, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="2000_200_hybrid_answers.txt", rerank= False, use_hybrid = True)
# Out:
# 3
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm.
#
# Q: What is the "Picklesburgh" event?
# A: The Picklesburgh event is a destination featuring handcrafted food and artisan drinks with
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Pittsburgh Symphony Orchestra
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: Jan 7, 2025 - Jan 12, 2025 (7th St and Penn Ave, Pittsburgh, PA 15222) Jan 8, 2025 (7th St and Penn Ave, Pittsburgh, PA 15222)
#
# Q: What event features a Pixar exhibition?
# A: The Science Behind PIXAR event, May 25, 2024 - Jan 5, 2025.
#
# Q: When is the next Penguins game against the Ducks?
# A: Next Penguins game against the Ducks not specified in the provided contexts. Please check their official schedule for updates.
#
# Q: Where can you attend an improv comedy show in October?
# A: You can attend an improv comedy show at 943 Liberty Ave, Pittsburgh, PA 15222 on Oct 20, 2024 for Short Form Jelly with Select Start. For the October 25 event, it's at the same location for House Team Hot Spot. [Reference URLs](https://downtownpittsburgh.com/events/event/?id=61307) and (https://
#
# Q: What is "World Square" in Pittsburgh?
# A: World Square is not mentioned in the context provided. It appears there is no World Square in Pittsburgh.
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: Oct 25, 26, 27, 2024 at 7:30 pm - 10:30 pm and 2:00 pm - 5:00 pm (Oct 27)
#
# Q: What time is the Steelers game on October 28, 2024?
# A: 8:00 pm - 11:30 pm
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Picklesburgh is an annual festival in Downtown Pittsburgh, showcasing handcrafted food and artisan drinks featuring pickled ingredients. It offers live music, contests, and pickle-themed snacks and merchandise. Admission is free.
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: Various yoga studios and gyms offer classes in Pittsburgh, such as Yoga Allure, Yoga Health & Wellness, and Core Power Yoga.
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: The largest museum in the world dedicated to bicycles.
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Tuesday, December 17,
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: Performance and visual
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie founded the Carnegie Steel Company.
#
# Q: Where is the American Jewish Museum located?
# A: The American Jewish Museum is not mentioned in the provided contexts.
#
# Q: What public biking option is available in Pittsburgh?
# A: PO
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Contemporary art programs
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: picoCTF
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: The Center for PostNatural History focuses on organisms that have been intentionally and heritably altered by humans, such as genetically engineered ones.
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: Carnegie Science Center
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Rachel Carson Bridge
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 200,000+
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Craig McCloud, 2016
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: 2875 Railroad St, Pittsburgh, PA 15222
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh Hispanic Development Corporation (PHDC) and Casa San Jose
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Pittsburgh Restaurant Week was initiated by Pittsburgh TasteBuds Ltd.
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: $20.24 (or equivalent variable pricing)
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Prom
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: To Answer the Query: Less chance of cold weather.
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: Pittsburgh Downtown Partnership
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: David L. Lawrence, Jr.
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Heinz History Center
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Andy Warhol's Factory, Campbell's Dairies, and Luke's Lunch, Latrobe
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Reneg
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Free concerts on specific evenings.
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Iceburgh
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: Headhunters
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill Mazeroski
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Mario Lemieux
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: No information provided about the 1971 Pirates' lineup defying traditional expectations in the contexts presented.
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: William Henry Welch (Law 1880) played for Pittsburgh as "Allegheny Athletic Association" before becoming a U.S. Supreme Court Justice. His contract was the first in professional football to include a no-trade clause.
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: Cannon design on helmet
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena (Igloo)
#
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lemieux
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Black and gold
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux, in 1999.
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 5 (including back-to-back wins)
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mister
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: The Car
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Spring Carnival Pickle Contest (not hosted by CMU itself, but an event within CMU's Spring Carnival)
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: picoCTF
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: Carnegie Museums of Pittsburgh complex, where one of the museums is located.
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: To preserve a record of the progress and development of pictorial art in America.
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: Ray and Stephanie Lane Computational Biology Department.
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: The Dietrich College at Carnegie Mellon University.
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Contains pharmacy memorabilia dating back to the early 20th century.
#
# Q: Where is the Fort Pitt Museum located?
# A: Downtown Pittsburgh, Point State Park
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: Notable feature: Scale reproductions of Italian masterpieces by Nicholas Lochoff.
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: The Heinz College of Carnegie Mellon University offers programs in School of Information Systems and Management and School of Public Policy and Management.
#
# Q: What is the Heinz History Center best known for?
# A: Heinz History Center is known for exhibits on Pittsburgh sports, Mr. Rogers, and history of the area.
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey RebellionTax Protest, 1794
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The focus of the Hunt Institute for Botanical Documentation is botany, horticulture, and plant science history.
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) is known for being the first research and education center in the U.S. devoted to information networking, a fusion of technologies, economics, and policies of secure communication networks. It is also the educational partner of Carnegie Mellon CyLab and holds National Center of Academic Excellence designations in Information Assurance/Cyber Defense Education and Research.
#
# Q: What is the Carnegie Science Center known for?
# A: Largest science museum in Pittsburgh
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: 1986 (changed name from Center for Machine Translation in 1996, started awarding degrees)
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: PNC Park
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: The City of Bridges due to having 446 bridges.
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Tau Kappa Epsilon (TKE) is the oldest fraternity at CMU, established in 1893. Other fraternities were established afterwards, including Sigma Chi (1894), Delta Tau Delta (1897), Phi Kappa Psi (1898), and Sigma Alpha Mu (1904).
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: John Nash (1948)
#
# Q: What is a historic district in Pittsburgh?
# A: Hill District
#
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 9
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: The Duquesne University football team represents Duquesne University in NCAA competitions and competes in the FCS. It is a member of the Northeast Conference.
#
# Q: What notable novel is set in Pittsburgh?
# A: There is no specific notable novel mentioned specifically set in Pittsburgh in the provided contexts.
#
# Q: Which popular film was shot in Pittsburgh?
# A: "The Silence of the Lambs".
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monongahela Incline, Duquesne Incline
#
# Q: Who is the current mayor of Pittsburgh?
# A: Ed Gainey (as of January 2022)
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The Andy Warhol Museum
#
# Q: What is the largest park in Pittsburgh?
# A: North Park (3,075 acres)
#
# Q: Who is a famous author born in Pittsburgh?
# A: Ernest Hemingway (refers to his birthplace, though he moved away as a child)
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Sh
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 5 (2009, 2016, 2017, 2017 back-to-back, 2018)
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby (as of October 16, 2024)
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Sidney Crosby (109 goals in 2009-10)
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A: 2016
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Mario Clemente (1971)
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold "Pie" Traynor was the first voice of the Pittsburgh Pirates on the radio.
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: Indianapolis Indians (Triple-A East)
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve (Eastern League)
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: Free admission for members, otherwise general admission is $18 for adults, $12 for seniors, $10 for students, and free for children under 6.
#
# Q: What events are happening at The Frick on November 16?
# A: Home for the Holidays at Clayton on November 16 (10:15 AM - 3:30 PM)
#
# Q: When was the Heinz History Center established?
# A:
#
# Q: Where is the Hometown-Homegrown event happening?
# A: 1212 Smallman St, Pittsburgh, PA 15222
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Family Fun Days, School Programs, Digital Learning options.Programs for children include such favorites as Family Fun Days, School Programs, and Digital Learning options.
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall, February 26, 2025.
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: Founded in 1895.
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Christopher Hahn
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Benedum Center, 7th St, Pittsburgh, PA 15222
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Pittsburgh
#
# Q: When are the final exams in CMU?
# A: The query asks about the specifics of final exams in Carnegie Mellon University (CMU), but the contexts provided do not offer any specific information about the university's academic timetables or exam schedules. Please consult the university's official website or contact their office of academic affairs for the most accurate and up-to-date information.  As a helpful assistant, I would like to emphasize that it is crucial to have accurate and current information when discussing
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Monterey Bay Fish Grotto, 1411 Grandview Avenue, Pittsburgh,
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: July 21, Benedum Center, Pittsburgh, PA 15222
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Heinz Hall (2025)
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: 600 Penn Ave, Pittsburgh, PA 15222, Nov 19, 2023, 7:30 pm - 10:30 pm.
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: 1000 Fort Duquesne Blvd, Pittsburgh, PA 15222
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: 7th St and Penn Ave, Pittsburgh, PA 15222
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: 117 Sandusky Street, Pittsburgh, PA 15212
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm at 1049 Penn Ave, Pittsburgh, PA 15212.
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: 1001 Fifth Ave, Pittsburgh, PA 15219.
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical is at Heinz Hall on July 21, on the Stanwix St. Stage.
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Not provided in the contexts.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: 2025-02-04 (Friday)
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: Carnegie Mellon University's School of Computer Science was established in 1967.
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A:
#
# Q: What type of tax is applied to events in Pittsburgh?
# A: Sales and Occupancy Taxes are typically applied to events in Pittsburgh.
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: The maximum percentage rate for Pittsburgh's amusement tax is not specified in the provided contexts.
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: 10% (as of current information)
#
# Q: Which sector does the ISP tax primarily target?
# A: The Educational Improvement Tax Credit (EITC) primarily targets businesses.
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Pittsburgh'
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: The due date for annual ISP tax filings in Pittsburgh is not provided in the contexts. To find the specific details, it's essential to consult with the appropriate local tax authorities or governing bodies.
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: Q1 2023 (Jan 1 - Mar
#
# Answers generated and saved to: 2000_200_hybrid_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 2000_200_hybrid_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2639
# Recall: 0.3542
# F1 Score: 0.2736
# Exact Match: 0.0945

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_2000_200", chunk_size=2000, chunk_overlap=200,  k=6, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="2000_200_embedding_k_6_answers.txt", rerank= False, use_hybrid = False)
# Out:
# 6
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Not provided in contexts. The Holiday Lights Tour details are not mentioned in the provided contexts.
#
# Q: What is the "Picklesburgh" event?
# A: Annual event in Downtown Pittsburgh featuring pickled foods, games, and live music.
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Jimmy's Led Zep Experience
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: No information provided about "Funny Girl" being performed in Downtown Pittsburgh in the contexts given.
#
# Q: What event features a Pixar exhibition?
# A: There is no information in the provided contexts that a Picklesburgh event features a Pixar exhibition.
#
# Q: When is the next Penguins game against the Ducks?
# A: Check the Penguins' official schedule for exact dates.
#
# Q: Where can you attend an improv comedy show in October?
# A: No information provided about improv comedy shows in October.
#
# Q: What is "World Square" in Pittsburgh?
# A: There is no "World Square" in Pittsburgh based on the provided contexts.
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: Performance dates for Peter Pan in Pittsburgh are not provided in the contexts. Please check local theaters or event websites for updates on Peter Pan performances.
#
# Q: What time is the Steelers game on October 28, 2024?
# A: Not provided
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Annual pickled food festival in Downtown Pittsburgh. Returns in July 2025. Free admission. Features local food, artisan drinks, pickle-themed snacks, games, live music, and more. Produced by The Pittsburgh Downtown Partnership.
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: No specific location is mentioned in the contexts for yoga sessions in Pittsburgh.
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: Largest bike museum in the world
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Highmark Holiday Pops concert date is not provided in the contexts.
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: Theater and arts exhibitions
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie
#
# Q: Where is the American Jewish Museum located?
# A: The American Jewish
#
# Q: What public biking option is available in Pittsburgh?
# A: POGOH Bike Share
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Carnegie Mellon College of Fine Arts offers programs in Art, Design, Drama, and Music.
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: "Capture The Flag (CTF) Competition"
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: Center for PostNatural History focuses on the history and culture of biotechnology and human-modified organisms.
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: The Andy
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Roberto Clemente Bridge
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: Over 200K  (Increase in attendance from the launch year in 2015 to its fourth year in 2018, as the event moved to a larger footprint on
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Not provided in the contexts. Information about the Pittsburgh Taco Festival is not available in the given contexts.
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: The provided contexts do not mention any information about the 2024 Pittsburgh Taco Festival. Therefore, it is not possible to answer the query based on the given information.
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: The Taco Festival partnership details were not provided in the contexts.
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: EYV Restaurant
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: unknown (initiated in Winter 2023)
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Prominent company name exposure, logo display, website link, background paragraph, social media mentions, e-mail newsletter promotion, and banner ad on high-traffic pages.
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: To move Little Italy Days from September to August, the main reason was likely to take advantage of a different time period, possibly for better weather or calendar scheduling.
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: The Pittsburgh
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Linda Troppito
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Pittsburgh Downtown Partnership
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: David Strickler's banana split invention was inspired by a settling argument between friends over a sundae's toppings at Tassell Pharmacy in Latrobe, PA, 1904.
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Terrible Towel Wave
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: PNC Park Brewery Tours
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Pierre the Penguin
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: Weasels
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Willie Stargell
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The 1971 Pirates' lineup featured a mix of rookies, including Roberto Clemente, Dave Parker, and Manny Sanguillen. These players broke racial and age norms, creating a unique and successful team.
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: Louis Brandeis, played for Pittsburgh under the names "Connie Lindsay" and "Louis D. Levy". He was the first Jewish player in the NFL, and he was the only professional football-playing Supreme Court justice.
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: Steelers helmet has 2 stripes, while others have 1.
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena (Igloo)
#
# Q: Which player scored in all five game situations in one NHL game?
# A: No information provided suggests any sports events related to NHL or hockey in Pittsburgh. Therefore, it's not known which player scored in all five game situations in one NHL game.
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Yellow and black.
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 3 (including 2 back-to-back wins in the salary cap era)
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Fred Rogers' memorabilia
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Diplodocus Carolyn S. Merex  (This is the name of the dinosaur cast that is the centerpiece of the Carnegie Museum of Natural History's dinosaur hall in Pittsburgh, Pennsylvania. It's recognized for being one of the largest and most complete diplodocus fossil discoveries.)
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Springede, a demo coding competition
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: Cybersecurity Forensics Challenge (CFC)
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: The Children
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: Enlighten and inspire the public with art and design.
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: Computer Science Department (Machine Learning and Artificial Intelligence Group)
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: School of Computer Science and Dietrich College of Humanities and Social Sciences (Decision Sciences, Technology, and Management)
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Elmer H. Grimm Sr. Pharmacy Museum is known for being a historical pharmacy museum.
#
# Q: Where is the Fort Pitt Museum located?
# A: Fort Pitt Museum is located at Point State Park, 601 Commonwealth Pl, Pittsburgh, PA 15222.
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: The Frick Fine Arts Building houses among the largest university art collections in the U.S. (Carnegie Mellon University).
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: Heinz College offers programs in Public Policy & Management, Information Systems & Technology, and Data Science.
#
# Q: What is the Heinz History Center best known for?
# A: They are best known for being a museum dedicated to the history of Western Pennsylvania and its related regions.
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Tax Rebellion
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The Hunt Institute for Botanical Documentation focuses on botanical research, education, and the preservation of literary and artistic works related to plants.
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) at Carnegie Mellon University is known for its graduate programs focused on cybersecurity, telecommunications, and networking.
#
# Q: What is the Carnegie Science Center known for?
# A: Carne
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: LTI was not found in the provided contexts. Therefore, no information about the foundation date of Language Technologies Institute (LTI) could be determined from the given contexts.
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forge Field (now PNC Park) was home to the Pittsburgh Pirates from 1909 to 1970.
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh is referred to as The City of Bridges due to having 446 bridges, more than any other city in the world.
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Sigma Alpha Mu (1909)
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: Richard Feynman
#
# Q: What is a historic district in Pittsburgh?
# A: "Pittsburgh has several historic districts, including the Historic Northside, Shadyside, and Lawrenceville."
#
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 4
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duquesne University represents the Dukes in NCAA competitions.
#
# Q: What notable novel is set in Pittsburgh?
# A: "' The Perks of Being a Wallflower' is set in Pittsburgh.
#
# Q: Which popular film was shot in Pittsburgh?
# A: "Fight Club" was filmed in Pittsburgh.
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monongahela and Duquesne
#
# Q: Who is the current mayor of Pittsburgh?
# A: The query doesn't seem to be about Pittsburgh's political mayor. Instead, it's the "Mayor" of Picklesburgh, which is a title won in the Picklesburgh Pickle Juice Drinking Contest. The winner named in the context provided is Fred Smith from Erie, Pennsylvania (year 2017). If you need information about the political mayor of Pittsburgh, I would recommend looking up Pittsburgh's city government or its current Mayor.
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: Andy Warhol Museum
#
# Q: What is the largest park in Pittsburgh?
# A: Not provided in contexts.
#
# Q: Who is a famous author born in Pittsburgh?
# A: Ernest Hemingway
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Point Breeze
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 3
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Travis Landstrom
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby (as of 2023)
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford (as of 2021)
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Sidney Crosby (2006-07 season)
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A: Spring 1991
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Arnold H. Carter (1971)
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold Arlin
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: Indianapolis Indians
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: Admission is free at The Frick Pittsburgh. However, some special exhibitions and events may require a fee. Please check the website for detailed information.
#
# Q: What events are happening at The Frick on November 16?
# A: No events are mentioned for The Frick on November 16 in the provided contexts.
#
# Q: When was the Heinz History Center established?
# A: 1991
#
# Q: Where is the Hometown-Homegrown event happening?
# A: Downtown Pittsburgh
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Art Studio, Clay Studio, Car and Cart Tours, Gardens, and Quarry Woods Adventure Trail for children at The Frick Pittsburgh.
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall, Pittsburgh
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: 1895
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Christopher Hahn
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Heinz Hall (or specific location details to be announced)
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: The provided context does not mention any details about the 17th International Exhibition of Botanical Art & Illustration. The given information is about the Taste of Picklesburgh event in Pittsburgh.
#
# Q: When are the final exams in CMU?
# A: I'm sorry for any inconvenience, but the provided contexts do not contain information about Carnegie Mellon University's final exam schedule. I recommend checking the university's official website for the most accurate and up-to-date information.
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Heinz Hall (Pittsburgh)
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: Performance dates and location for Madama Butterfly by Pittsburgh Opera are not provided in the given contexts. Please check the Pittsburgh Opera's official website for updated information.
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: The venue for the WYEP Hellbender Ball in 2025 is not specified in the provided contexts.
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Spider-Man: Into the Spider-Verse Live in Concert is not mentioned in the provided contexts.
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: Unspecified location - More details to be announced.
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: Information not provided in the contexts.
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: The KAWS + Warhol exhibition is not mentioned in the provided contexts for 2025.
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Downtown Pittsburgh, dates not specified.
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: PPG Paints Arena
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical is not mentioned in the provided contexts.
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Chicago Symphony Orchestra performance location in 2025 is not provided in the contexts.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: I couldn't find any information about Paw Patrol Live! happening at Petersen Events Center in the provided contexts. It seems there's no relationship between Picklesburgh and Paw Patrol Live! events.
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: CMU established the School of Computer Science in 1967.
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: CMU does not have an annual "Buggy" race tradition.
#
# Q: What type of tax is applied to events in Pittsburgh?
# A: Sales and Occupancy Taxes
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: The maximum rate for Pittsburgh's amusement tax is not specified in the provided contexts.
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: The current maximum parking tax rate for Pittsburgh is not explicitly stated in the provided contexts. I was unable to find this information.
#
# Q: Which sector does the ISP tax primarily target?
# A: Not provided in the contexts.
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Digital goods and services purchased from a remote seller over the internet, including downloadable software, digital music, movies, and games, and cloud storage services.
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: I am
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: Quarterly payroll tax returns are due on January 31, April 30, July 31, and October 31.
#
# Answers generated and saved to: 2000_200_embedding_k_6_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 2000_200_embedding_k_6_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2103
# Recall: 0.2609
# F1 Score: 0.2049
# Exact Match: 0.0630

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1025, chunk_overlap=50,  k=6, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="1025_50_hybrid_k_6_answers.txt", rerank= False, use_hybrid = True)
# Out:
# 6
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm.  Alternative concise answer: 2024 holidays, Nov 29 - Jan 1, 5-7 PM.
#
# Q: What is the "Picklesburgh" event?
# A: Picklesburgh is an annual festival in Downtown Pittsburgh featuring handmade food and artisan drinks with pickled ingredients.
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Pittsburgh Symphony Orchestra
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: Jan 7, 2025 - Jan 12, 2
#
# Q: What event features a Pixar exhibition?
# A: The event "The Science Behind PIXAR" features a Pixar exhibition. Event date: May 25, 2024 - Jan 5, 2025. Address: 1 Allegheny Ave, Pittsburgh, PA 15212. URL: https://downtownpittsburgh.com/events/event/?id=59986.
#
# Q: When is the next Penguins game against the Ducks?
# A: No information provided about next Penguins game against the Ducks in the contexts provided.
#
# Q: Where can you attend an improv comedy show in October?
# A: 943 Liberty Ave, Pittsburgh, PA 15222 (multiple events)
#
# Q: What is "World Square" in Pittsburgh?
# A: Market Square
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: Oct 25, 26, 27, 2024
#
# Q: What time is the Steelers game on October 28, 2024?
# A: 4:00 pm - 8:00 pm
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Annual three
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: Market Square, Tuesdays and Sunday
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: World's largest transportation museum dedicated to bicy
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: December 13, 2024 - December 22, 2024
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: Known for hosting performing and visual arts programs celebrating the African American experience.
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie founded the Carnegie Steel Company.
#
# Q: Where is the American Jewish Museum located?
# A: Squirrel Hill JCC, Forbes Avenue and Murray Avenue, Pittsburgh, Pennsylvania.
#
# Q: What public biking option is available in Pittsburgh?
# A: Pittsburgh Regional Transit allows biking on their buses.
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Art, Design, Drama, and Music
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: picoCTF
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: The Center
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: The Andy Warhol Museum
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Rachel Carson Bridge
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 200,000 (Picklesburgh 2023)
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Craig McCloud in 2016
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: The Stacks at 3 Crossings, 2875 Railroad Street, Pittsburgh, PA 15222.
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh Hispanic Development Corporation (PHDC) and Casa San Jose
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Henry J. Heinz II initiated the rebirth of Pittsburgh Restaurant Week.
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: Not stated in the context provided.
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Sponsors can gain visibility and engagement opportunities through Pittsburgh Restaurant Week's communications channels with a large audience of potential customers.
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: Not specified in provided contexts.
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: Highmark, Allegheny Health Network
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Tess Judge Allegretti  (Reference: "Latrobe's Tasty History Allegretti Brings Back Banana Split Legend" from https://triblive.com/local/westmoreland/latrobes-tasty-history-allegretti-brings-back-banana-split-legend/)
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: The Pittsburgh Downtown Partnership
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Not provided in the contexts.
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Renegade played in the fourth quarter
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Upscale hot dog variations at PNC Park.
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Mr. Pierogi
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: "Buccaneate"
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill Mazeroski
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Roberto Clemente (
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The Pirates' 1971 lineup played 80% of their games without traditionally-positioned players.
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: James A. Traficant Jr., who later became a U.S. representative, once played for the Pittsburgh Pirates football team (before they were known as Steelers). His contract was notable as it made him the NFL's first African American quarterback with a starting position.
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: A stain
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena
#
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lemieux
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Black and gold
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Kim Clark was the first player-owner in NHL history with the Penguins.
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 5 (including 2 in the salary cap era)
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mister Rogers' Neighborhood
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Three times the size of original dinosaur hall, scientifically accurate, immersive environments spanning the Age of Dinosaurs.
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Spring Carnival, Picklesburgh is not associated with Carnegie Mellon University.
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: picoCTF
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: The Children's Museum of Pittsburgh has experiences for children aged 10+ at Museum Lab™, located in a separate facility for older kids.
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: "Andrew Carnegie envisioned a museum collection consisting of the "Old Masters of tomorrow" for the Carnegie Museum of Art."
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: The Ray and Stephanie Lane Computational Biology Department specializes in AI-driven biomedical research.
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: Dietrich College of Humanities and Social Sciences
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: The Elmer H. Grimm Sr. Pharmacy Museum holds pharmacy memorabilia dating back to the early 20th century, including drug products, equipment, and sundry products.
#
# Q: Where is the Fort Pitt Museum located?
# A: In Downtown Pittsburgh, within Point State Park.
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: The Frick Fine Arts Building has a notable feature called the Nicholas Lochoff Cloister, which houses large paintings of Italian masterpieces.
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: The Heinz College of Carnegie Mellon University offers programs in Information Systems and Management, and Public Policy and Management.
#
# Q: What is the Heinz History Center best known for?
# A: Largest history museum in Pennsylvania, USA with a Western Pennsylvania connection.
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Tax Rebellion
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: Botanical Documentation
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) is known for being the nation's first research and education center devoted to information networking and a fusion of technologies, economics, and policies of secure communication networks, systems, and services.
#
# Q: What is the Carnegie Science Center known for?
# A: Carne
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: 1986, with the change of name to The Language Technologies Institute in 1996.
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes Field
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh is referred to as "The City of Bridges" because it has 446 br
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Phi Mu Alpha Sinfonia fraternity (1917)
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: John Nash
#
# Q: What is a historic district in Pittsburgh?
# A: Schenley Farms Historic District
#
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: Nine
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Football Championship Subdivision (FCS)
#
# Q: What notable novel is set in Pittsburgh?
# A: The novel "El hombre de la situación" by Manuel Payno is set in Pittsburgh.
#
# Q: Which popular film was shot in Pittsburgh?
# A: "The Silence of the Lambs"
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: The Monongahela and Duquesne Inclines
#
# Q: Who is the current mayor of Pittsburgh?
# A: Ed Gainey
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The Andy Warhol Museum
#
# Q: What is the largest park in Pittsburgh?
# A: Frick Park (644 acres) is the largest
#
# Q: Who is a famous author born in Pittsburgh?
# A: There are many notable individuals born in Pittsburgh, but no specific famous author was mentioned in the context provided.
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Mt Washington
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 5
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Mike L
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: There is no current team captain for the Pittsburgh Penguins, as they are yet to name one following the 2021 NHL season.
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: 51 (2009-10 season, Sidney Crosby)
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A: 1991
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: There is no record of a Pittsburgh Pirates player winning the MVP award.
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Honor Swensen
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: The Pittsburgh Pirates' Triple-A minor league affiliate is the Indianapolis Indians.
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve (Eastern League)
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: Admission cost at The Frick Pittsburgh is not specifically stated, but membership provides various benefits including free admission.
#
# Q: What events are happening at The Frick on November 16?
# A: There are no events happening at The Frick on November 16, according to the provided contexts.
#
# Q: When was the Heinz History Center established?
# A: 1896
#
# Q: Where is the Hometown-Homegrown event happening?
# A: 1212 Smallman St , Pittsburgh, PA 15222
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Family Fun Days
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: 1845 (as the Pittsburgh Societal Concert Association) 1895 (as the Pittsburgh Symphony Orchestra)
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Antony Walker
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Benedum Center, Pittsburgh, PA 15222 (Thursday, March 27, 2025)
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Hunt Institute for Botanical Documentation, 5th Floor, Hunt Library
#
# Q: When are the final exams in CMU?
# A: There isn't information regarding CMU's final exam schedule provided in the contexts. For accurate dates and details, please visit Carnegie Mellon University's official academic calendar or website.
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Monterey
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: March 27, 2025 at Benedum Center, 7th St, Pittsburgh, PA 15222.
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Rex Theater
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Heinz Hall on Nov 10, 2024 | 2:30 pm - 5:30 pm & Nov 9, 2024 | 7:30 pm - 10:30 pm
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: 1000 Fort Duquesne Blvd , Pittsburgh, PA 15222
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: 7th St and Penn Ave , Pittsburgh, PA 15222
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: 117 Sandusky Street, Pittsburgh, PA 15212
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A:
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: 1001 Fifth Ave, Pittsburgh, PA 15219
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical does not appear to be mentioned in the provided contexts. For accurate information, please check the official schedule of the theater or event where you expect to see this production.
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Chicago Symphony Orchestra performances in 2025 are not specified in the provided context.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: July 1, 2023
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: Carne
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: CMU Buggy Race
#
# Q: What type of tax is applied to events in Pittsburgh?
# A: Unspecified - No direct information given about taxes for events in Pittsburgh. References are made to potential benefits through programs like Educational Improvement Tax Credit (EITC), but there is no mention of specific taxes being applied to events.
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: 9%
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: 9%
#
# Q: Which sector does the ISP tax primarily target?
# A: The Educ
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: ISP revenues are subject to Pittsburgh's ISP tax.
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: July 15th (for calendar year
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: Q4 (October 31) and Q1 (January 31)
#
# Answers generated and saved to: 1025_50_hybrid_k_6_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 1025_50_hybrid_k_6_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2825
# Recall: 0.3655
# F1 Score: 0.2863
# Exact Match: 0.1024

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_512_20", chunk_size=512, chunk_overlap=20,  k=12, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="512_20_hybrid_k_12_answers.txt", rerank= False, use_hybrid = True)
# Out:
# 12
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Nov 29, 2024 - Jan 1, 2025
#
# Q: What is the "Picklesburgh" event?
# A: Annual pickle festival in Downtown Pittsburgh, featuring pickled foods, live music, and pickle-themed activities. Admission is free.
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Pittsburgh Symphony Orchestra
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: July 7, 2025 (9:30 PM) and July 8, 2025 (9:30 PM) at 7th St and Penn Ave, Pittsburgh, PA 15222.
#
# Q: What event features a Pixar exhibition?
# A: The Science
#
# Q: When is the next Penguins game against the Ducks?
# A: The next Penguins game against the Ducks is not scheduled. Please check the official Pittsburgh Penguins website for updates.
#
# Q: Where can you attend an improv comedy show in October?
# A: Arcade Comedy Theater, Oct 27, 2024 | 7:30 pm - 8:30 pm or Oct 27, 2024 | 7:30 pm - 9:30 pm, 943 Liberty Ave , Pittsburgh, PA 15222
#
# Q: What is "World Square" in Pittsburgh?
# A: World Square is not a term that is commonly associated with Pittsburgh. It might be a confusion with Market Square, a popular and historical location in Downtown Pittsburgh. However, there is no recognized location named World Square in Pittsburgh.
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: July 2025 (Dates TBA
#
# Q: What time is the Steelers game on October 28, 2024?
# A: 8
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Pickles
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: There are yoga studios throughout Pittsburgh such as YogaWorks, The Yoga Studio, and LifePower Yoga. You can also find classes at local gyms like LA Fitness and Planet Fitness, or community centers like the Pittsburgh Parks Conservancy. Check specific locations and schedules for availability.
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: Largest transportation museum in the world dedicated to bicycles.
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: December 13, 2024 - December 22, 2024. Heinz Hall, Pittsburgh.
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: African American arts and culture
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie founded the Carnegie Steel Company.
#
# Q: Where is the American Jewish Museum located?
# A: Squirrel Hill, Pittsburgh, PA
#
# Q: What public biking option is available in Pittsburgh?
# A: POGOH Bike Share & bike lane network
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Art, Architecture, Design, Drama, Music programs.
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: picoCTF
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: Focus: Organisms intentionally and heritably altered by humans; culture, nature, and biotechnology.
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: The Andy Warhol Museum showcases GloFish, but not Biosteel go
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Sister Bridges
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 200,000 (by its fourth year)
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: 2024 (The Original Pittsburgh Taco Festival)
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: 2875 Railroad St, Pittsburgh, PA 15222
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Casa San Jose
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: H
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: Multi-course menu
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Maximum exposure prior, during, and after the event through aggressive marketing and media relations activities, prominent company name, logo display, website link, and background paragraph on www.pittsburghrestaurantweek.com/pghrestaurantwk.
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: The main
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: The contexts do not mention a primary sponsor of Little Italy Days.
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: David DeRamold
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: The Western Pennsylvania Historical Society installed a historical marker in 2013 at the dessert's invention site. (Reference to Banana Foster Bread Pudding)
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Unknown. Context does not provide information on what inspired David Strickler's banana split invention in Latrobe.
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Renegade by Styx.
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Annual pickle festival, Picklesburgh, takes place at PNC Park, popular among baseball fans.
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Mr. Penguin
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: The Pirates earned the nickname "Terriers" due to their controversial signing of second baseman Lou Bierbauer.
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Roberto Mazeroski
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Roberto Clemente (Most Valuable Player Award, World Series Most Valuable Player Award)
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The Pir
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: Arthur J. Goldberg (1956) – played for the Pittsburgh Steelers (as Pitt Panthers) before joining the Supreme Court (NY Giants player, not on Steelers original name roster)  Significant about his contract: First person to hold cabinet position (Labor), then join the Supreme Court
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: NFL Offensive Rookie of the Year Award Pro Football Hall
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Igloo
#
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lemieux, on December 31, 1988.
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Black and gold
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A:
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mister Rogers
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: The exhibit spans the Age of Dinosaurs and features scientifically accurate, immersive environments.
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Mobot Races
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: picoCTF
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: "Get lost in the building"
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: Collect the "Old Masters of tomorrow"
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: Ray and Stephanie Lane Computational Biology Department
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: The Marianna Brown Dietrich College of Humanities and Social Sciences at Carnegie Mellon University.
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Pharmacy memorabilia dating back to early 20th century.
#
# Q: Where is the Fort Pitt Museum located?
# A: Downtown Pittsburgh.
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: The Frick Fine Arts Building has Nicholas Lochoff Cloister with large paintings of Italian masterpieces.
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: Master of Information Systems Management, Master of Public Policy & Management, Master of Science in Information Technology Management, Master of Science in Information Security Policy & Management, Doctor of Public Management, Ph.D. in Engineering and Public Policy, Ph.D. in Public Policy and Management, Master of Computational Data Science, Master of Cybersecurity, Master of Entertainment Industry Management, Master of Quantitative Finance, Master of Science in Public Policy & Management (Online), Executive Master of Public Management & Lead
#
# Q: What is the Heinz History Center best known for?
# A: The Heinz History Center is best known for Pittsburgh sports exhibits.
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Rebellion
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: Ded
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) at Carnegie Mellon University is known for being the nation's first research and education center devoted to information networking, representing a fusion of technologies, economics, and policies of secure communication networks, systems, and services.
#
# Q: What is the Carnegie Science Center known for?
# A: Known for being a national leader in promoting literacy in STEM and as the region's most visited museum with over 500,000 annual visitors.
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: 1
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: The City
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Phi Delta Theta, founded in 1868.
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: John Nash (1948)
#
# Q: What is a historic district in Pittsburgh?
# A: Schenley Farms Historic District, Oakland
#
# Q: When was Carnegie Mellon University Founded?
# A: 1
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 9 Fortune 500 companies
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duquesne Dukes
#
# Q: What notable novel is set in Pittsburgh?
# A: "None
#
# Q: Which popular film was shot in Pittsburgh?
# A: "Toy Story"
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monongahela Incline, Duquesne Incline
#
# Q: Who is the current mayor of Pittsburgh?
# A: Ed Gainey
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The Andy Warhol Museum
#
# Q: What is the largest park in Pittsburgh?
# A: Frick
#
# Q: Who is a famous author born in Pittsburgh?
# A: Terry Hayes
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: One of Pittsburgh's historic neighborhoods is the North Side.
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 5
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike L
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Mike Lange (radio)
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby (as of 2021)
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins.
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Sidney Crosby, 109 points in 20
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A: 1
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: There is
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harry Peel
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: Indianapolis Indians
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Alto
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: Free (
#
# Q: What events are happening at The Frick on November 16?
# A: On November 16, "The Art of the Nativity: From Ancient Rome to the Renaissance" and "Home for the Holidays at Clayton" are happening at The Frick.
#
# Q: When was the Heinz History Center established?
# A: 1
#
# Q: Where is the Hometown-Homegrown event happening?
# A: 1212 Smallman St , Pittsburgh, PA 15222
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Hand-
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: Founded
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Christopher H
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: The Mad
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Hunt Institute for Botanical Documentation, 5th Floor, Hunt Library, Pittsburgh
#
# Q: When are the final exams in CMU?
# A: I could not find information about final exams in Carnegie Mellon University directly in the provided contexts. The contexts mainly focus on restaurant weeks and events happening in Pittsburgh rather than academic calendar or university-related information.
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Monter
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: July 2025, Downtown Pittsburgh.
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Heinz Hall
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Heinz Hall on July 19, 2023
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: Downt
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A:
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: July 2025, Pittsburgh PA 15212 (at The Warhol)
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm at 1049 Penn Ave , Pittsburgh, PA 15212
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: 1
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: 2023, Pittsburgh (specific location not given in contexts)
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Chicago (not specified)
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: 2025-02-04
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: In
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: Annual "Buggy" race at CMU is a relay race around Schenley Park, using a small, usually torpedo-shaped vehicle called a buggy. Five runners push the vehicle uphill and free-roll it downhill.
#
# Q: What type of tax is applied to events in Pittsburgh?
# A: Pittsburgh applies Sales and Use Tax to events.
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: The maximum percentage rate for Pittsburgh's amusement tax is not specified in the provided contexts.
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: 5% (as of January 2022)
#
# Q: Which sector does the ISP tax primarily target?
# A: Service sector
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Internet Service Providers (ISPs) and their revenues from providing broadband and telecommunications services are subject
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: Not provided in the contexts.
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: Quarterly payroll tax returns in Pittsburgh are due on the last day of the month following the end of the quarter (January 31, April 30, July 31, and October 31).
#
# Answers generated and saved to: 512_20_hybrid_k_12_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 512_20_hybrid_k_12_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2752
# Recall: 0.3284
# F1 Score: 0.2635
# Exact Match: 0.0787

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1025, chunk_overlap=50,  k=4, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="1025_50_hybrid_k_4_answers.txt", rerank= False, use_hybrid = True)
# Out:
# 4
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Nov 29, 2024 - Jan 1, 2025
#
# Q: What is the "Picklesburgh" event?
# A: Annual festival featuring pickled foods and drinks in Downtown Pittsburgh, returning July 2025.
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Pittsburgh Symphony Orchestra
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: Jan 7, 2025 - Jan 12, 2025 (7th St and Penn Ave, Pittsburgh
#
# Q: What event features a Pixar exhibition?
# A: The Science Behind PIX
#
# Q: When is the next Penguins game against the Ducks?
# A: The information provided does not mention any upcoming Penguins game against the Ducks. Please check the official schedule for accurate and current game details.
#
# Q: Where can you attend an improv comedy show in October?
# A: 943 Liberty Ave, Pittsburgh
#
# Q: What is "World Square" in Pittsburgh?
# A: World Square does not appear to be mentioned in the provided contexts. It seems there might be a miscommunication as there's no equivalent called "World Square" in Downtown Pittsburgh. It would be beneficial to double-check the reference or provide additional context for a more accurate response
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: Oct 25, 26, 27, 2024 (7:30-10:30 pm, 2-5 pm) at 7th St and Penn Ave, Pittsburgh, PA 15222.
#
# Q: What time is the Steelers game on October 28, 2024?
# A: 4:00 pm
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Picklesburgh is an annual festival in Downtown Pittsburgh featuring pickled food, drinks, snacks, merchandise, live music, and more. It is produced by The Pittsburgh Downtown Partnership and will return in July 2025.
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: Market Square (Yoga in the Square)
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: The B
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Dec 13, 2024 - Dec 22, 2024
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: August Wilson
#
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie founded the Carnegie Steel Company.
#
# Q: Where is the American Jewish Museum located?
# A: Pittsburgh, Pennsylvania
#
# Q: What public biking option is available in Pittsburgh?
# A: There is a pedestrian and biking trail in Pittsburgh.
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Contemporary art programs
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: picoCTF
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: Living and
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: Andy Warhol Museum doesn't showcase GloFish or Biosteel goats. The mentioned exhibits are found in Randyland, an art museum in Pittsburgh.
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Rachel Carson
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 2
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Craig McCloud (2016)
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: At The Stacks at 3 Crossings, Railroad Street, Pittsburgh, PA 15222.
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh Hispanic Development Corporation (PHDC) and Casa San Jose
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Pittsburgh Restaurant Week event organizers
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: Not provided in the contexts.
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Increased visibility and engagement opportunities for sponsors, as well as the potential to reach 100,000+ attendees during the three-day event.
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: Not specified in the provided contexts.
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: Pittsburgh Downtown Partnership
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: David H. Monnens was instrumental in reviving Latrobe's connection to the banana split in 2004.
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: The Pittsburgh Downtown Partnership
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Not specified in the given contexts.
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: "Renegade by Styx played during the fourth quarter"
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Hot Dogs & Wursts Galore
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Mr. Pierogi
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: "Lou Bierbauer's Ascot"
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill Mazeroski
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Willie
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: No specific mention of the Pirates' 1971 lineup defying traditional expectations was found in the provided contexts.
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: Jerome Frank (Law 1910) played for the Pittsburgh Pirates (Steelers' original name) before joining the U.S. Supreme Court. His contract was the first in professional football to include a players' association clause.
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: Three-pointed stars
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena
#
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lemieux
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Black and gold
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 5 (including back-to-back wins)
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mister Rogers' Neighborhood memorabilia
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Nearly three times the size of the original dinosaur hall, immersive environments spanning the Age of Dinosaurs.
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Picklesburgh (during Spring Carnival)
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: picoCTF
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: Museum Lab™ at Children's Museum of Pittsburgh is for kids ages 10+.
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: The mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie, was to preserve a "record of the progress and development of pictorial art in America".
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: Ray and Stephanie Lane Department of Computational Biology (CBD)
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: Dietrich College of Humanities and Social Sciences
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Houses pharmacy memorabilia dating back to the early 20th century.
#
# Q: Where is the Fort Pitt Museum located?
# A: Point State Park, Pittsburgh, PA
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: The Frick Fine Arts Building has a notable feature called the Nicholas Lochoff Cloister with large-scale reproductions of Italian masterpieces.
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: School of Information Systems and Management, School of Public Policy and Management
#
# Q: What is the Heinz History Center best known for?
# A: Largest history museum
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Rebellion.
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The Hunt Institute for Botanical Documentation focuses on botanical art, illustration, and scientific scholarship.
#
# Q: What is the Information Networking Institute (INI) known for?
# A: Fusion
#
# Q: What is the Carnegie Science Center known for?
# A: Largest collection of sports and science exhibits in the world.
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: 1
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes Field (1909-1970)
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh is referred to as The City of Bridges due to the 446 bridges spanning its waterways.
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Phi Mu Alpha Sinfonia (initiated in 1917)
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: John Nash (BS, MS, Carnegie Institute of Technology, 1948)
#
# Q: What is a historic district in Pittsburgh?
# A: Schenley Farms Historic District
#
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 9
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duquesne University represents the Duquesne Dukes in NCAA football competitions.
#
# Q: What notable novel is set in Pittsburgh?
# A: "None of the provided contexts mention a notable novel set in Pittsburgh."
#
# Q: Which popular film was shot in Pittsburgh?
# A: "She's Out of My League".
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monongahela and Duquesne Inclines
#
# Q: Who is the current mayor of Pittsburgh?
# A: Ed Gainey
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The Andy Warhol Museum.
#
# Q: What is the largest park in Pittsburgh?
# A: Frick Park (644 acres) is the largest park in Pittsburgh.
#
# Q: Who is a famous author born in Pittsburgh?
# A: Timothy Mellon (author)
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Mt. Washington
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 5
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange, Pittsburgh Penguins' broadcaster.
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Mike Lange (radio)
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: The current query is about the captain of the Pittsburgh Penguins.  From the provided context:  1. Players affiliated with the Pittsburgh Penguins include both players and builders of the sport. 2. The four individuals recognized as builders by the Hockey Hall of Fame includes former head coaches, and general managers. 3. Players affiliated with the Penguins include 15 former players.  However,
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim R
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Sidney Crosby (51 goals in 81 games, 2009-10 season)
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A: 1991
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Last known MVP for Pittsburgh Pirates is not provided in the contexts.
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold Arlin
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: The Pittsburgh Pirates' Triple-A minor league affiliate is the Indianapolis Indians.
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve (Eastern League)
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: $160 (annual cost), but Family Access Memberships reduce it to $20.
#
# Q: What events are happening at The Frick on November 16?
# A: No events are happening at The Frick on November 16, according to the provided context.
#
# Q: When was the Heinz History Center established?
# A: 1883 (Established as the Western Pennsylvania Historical Society)
#
# Q: Where is the Hometown-Homegrown event happening?
# A: 1212 Smallman St
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Family Fun
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: Founded in 1895.
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Antony Walker
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Benedum Center, Pittsburgh, PA 15222
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Hunt Institute for Botanical Documentation, 5th Floor, Hunt Library
#
# Q: When are the final exams in CMU?
# A: Carnegie Mellon University does not specify set final exam dates. Students find out their final exam schedule closer to the end of the semester from their instructors.
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Monterey Bay Fish Grotto, 1411 Grandview Avenue
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: March 27, 2025 at Benedum Center, 7th St, Pittsburgh, PA 15222.
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Rex Theater
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: November 7, 2023 at 600 Penn Ave, Pittsburgh, PA 15222.
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: 1
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: 7th St and Penn Ave , Pittsburgh, PA 15222 (Benedum Center) on January 7-12, 2025.
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A:
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm at 1049 Penn Ave , Pittsburgh, PA 15212.
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A:
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical has no direct relation to the provided contexts. It's a Broadway musical about the life of Tina Turner, not a scheduled event in Pittsburgh or connected to Carnegie Mellon University. For more information about the musical, you can visit Tina Turner's official website or a trusted news source.
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Not specified in the provided contexts.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: I could not find specific information about Paw Patrol Live! happening at Petersen Events Center in the provided contexts. Please check the official website or event listings for current information on dates and times.
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: Carnegie Mellon University formed through the merger of Carnegie Institute of Technology and Mellon Institute of Industrial Research in 1967.
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: Not found in provided contexts.
#
# Q: What type of tax is applied to events in Pittsburgh?
# A: Sales, Amusement, and Hotel Taxes
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: 9% (for amusement devices excluding video games) 9% (for amusement devices including video games)
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: The current parking tax rate is not provided in the contexts.
#
# Q: Which sector does the ISP tax primarily target?
# A: Educational sector
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: ISP services provided in the city of Pittsburgh
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: Not provided in context.
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: Query: When are quarterly payroll tax returns due for employers in Pittsburgh?  Answer: Various sources suggest that quarterly payroll tax returns for employers in Pittsburgh are due on the last day of the month following each quarter: January 31, April 30, July 31, and October 31. However, it's always best to verify the current guidelines from the IRS or local tax authority.
#
# Answers generated and saved to: 1025_50_hybrid_k_4_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 1025_50_hybrid_k_4_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2879
# Recall: 0.3655
# F1 Score: 0.2921
# Exact Match: 0.1024

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1025, chunk_overlap=50,  k=4, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="1025_50_rerank_k_4_answers.txt", rerank= True, use_hybrid = True)
# Out:
# 4
# 7
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm.
#
# 7
# Q: What is the "Picklesburgh" event?
# A: Picklesburgh is an annual festival featuring handcrafted food and artisan drinks with pickled ingredients, cont
#
# 7
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Pittsburgh Symphony Orchestra
#
# 7
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: Jan 7, 2025 - Jan 12, 2025 at 7th St and Penn Ave, Pittsburgh, PA 15222.
#
# 7
# Q: What event features a Pixar exhibition?
# A: The event "The Science Behind PIXAR" features a Pixar exhibition. [Link for more details](https://downtownpittsburgh.com/events/event/?id=5
#
# 7
# Q: When is the next Penguins game against the Ducks?
# A: Information not provided in contexts. Please check official sports schedules for updates.
#
# 7
# Q: Where can you attend an improv comedy show in October?
# A: 943 Liberty Ave, Pittsburgh, PA 15222, Oct 20, 2024 | 7:30 pm - 9:30 pm
#
# 7
# Q: What is "World Square" in Pittsburgh?
# A: Market Square
#
# 7
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: Oct 25, 26, 27, 2024 (7:30 pm - 10:30 pm, 2 pm) at 7th St and Penn Ave, Pittsburgh, PA 15222.
#
# 7
# Q: What time is the Steelers game on October 28, 2024?
# A: October 28, 2024 | 4:00 pm (EST)
#
# 7
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Picklesburgh is the destination for all things pickled in Downtown Pittsburgh.
#
# 7
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: Yoga in the Square, Market Square (Tuesdays and Sundays)
#
# 7
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: The Bicycle Heaven Museum in Pittsburgh is the largest transportation museum dedicated to bicycles in the world.
#
# 7
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: July 13, 2021 - December 22, 2024 (select dates)
#
# 7
# Q: What is the August Wilson African American Cultural Center known for?
# A: African American art, exhibitions, and performances.
#
# 7
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie
#
# 7
# Q: Where is the American Jewish Museum located?
# A: Pittsburgh, Pennsylvania, at the Squirrel Hill JCC corner of Forbes Avenue and
#
# 7
# Q: What public biking option is available in Pittsburgh?
# A: Riverfront Biking Trail
#
# 7
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Contemporary
#
# 7
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: picoCTF
#
# 7
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: The Center for PostNatural History in Pittsburgh focuses on organisms that have been intentionally and heritably altered by humans.
#
# 7
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: Randyland museum
#
# 7
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Rachel Cars
#
# 7
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 200,000
#
# 7
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Craig McCloud in 2016
#
# 7
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: The Pittsburgh Taco Festival was held at The Stacks at 3 Crossings, 2875 Railroad Street.
#
# 7
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh Hispanic Development Corporation (PHDC) and
#
# 7
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Pittsburgh Restaurant Week event organizers
#
# 7
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: $2
#
# 7
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Increased visibility and engagement opportunities for your sponsor
#
# 7
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: No information provided about why Little Italy Days moved from September to August.
#
# 7
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: Pittsburgh Downtown Partnership
#
# 7
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Latrobe Historical Society & Museum
#
# 7
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Pittsburgh Downtown Partnership
#
# 7
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Mary Kenner, a Black inventor who created the sanitary belt in 1957.
#
# 7
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: "Renegade by Styx is played
#
# 7
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Hot Dog
#
# 7
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Mr. Sidney Crosby (Pittsburgh Penguins mascot is Iceburgh
#
# 7
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: Buckeyes
#
# 7
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A:
#
# 7
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Roberto Clemente (1979 MVP, Cy Young, Rookie of the Year)
#
# 7
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The Pirates' 1971 lineup
#
# 7
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: Louis Brandeis, Pittsburgh Alleghenies (later renamed Pittsburgh Pirates) contract included a clause allowing him to miss games for his law practice
#
# 7
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: Pointed Steelers logo on top. (Tri-star)
#
# 7
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena
#
# 7
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lemieux
#
# 7
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: "Black and
#
# 7
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# 7
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 5
#
# 7
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mister
#
# 7
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Nearly three times the size of the original din
#
# 7
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Picklesburgh Visit (during July)
#
# 7
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: picoCTF
#
# 7
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: Museum Lab™,
#
# 7
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: To preserve a "record of the progress and development of pictorial art in America".
#
# 7
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: The Ray and Stephanie Lane Computational
#
# 7
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: Marianna Brown Dietrich College of Humanities and Social Sciences
#
# 7
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Contains pharmacy memorabilia dating back to early 20th century, including hand-carved finials, powder mill, and konseal machine.
#
# 7
# Q: Where is the Fort Pitt Museum located?
# A: Point State Park, Pittsburgh, PA
#
# 7
# Q: What notable feature does the Frick Fine Arts Building have?
# A: Reproduction paintings of Italian masterpieces by Nicholas Lochoff.
#
# 7
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: The Heinz College of Carnegie Mellon University offers programs in Information
#
# 7
# Q: What is the Heinz History Center best known for?
# A: Largest history museum in Western Pennsylvania, USA.
#
# 7
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Excise Tax Rebellion (1794)
#
# 7
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The focus of Hunt Institute for Botanical Documentation is botanical history.
#
# 7
# Q: What is the Information Networking Institute (INI) known for?
# A: Established by Carnegie Mellon University in 1989, the Information Networking Institute (INI) is renowned for being the nation's first research and education center devoted to information networking.
#
# 7
# Q: What is the Carnegie Science Center known for?
# A: Highmark SportsWorks®, interactive science exhibits
#
# 7
# Q: When was the Language Technologies Institute (LTI) founded?
# A: 1986 (and renamed in 1996)
#
# 7
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes Field
#
# 7
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh is referred to as The City of Bridges due to having 44
#
# 7
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Phi Mu Alpha Sinfonia (1917)
#
# 7
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: John Nash (1994 Nobel Memorial Prize in Economic Sciences)
#
# 7
# Q: What is a historic district in Pittsburgh?
# A: Schenley Farms Historic District (or Oakland - the neighborhood of the main campus)
#
# 7
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# 7
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A:
#
# 7
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duques
#
# 7
# Q: What notable novel is set in Pittsburgh?
# A: "None of the
#
# 7
# Q: Which popular film was shot in Pittsburgh?
# A: She's Out of My League
#
# 7
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monongahela Incline, Duquesne Incline
#
# 7
# Q: Who is the current mayor of Pittsburgh?
# A: Ed Gainey
#
# 7
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The Andy Warhol Museum
#
# 7
# Q: What is the largest park in Pittsburgh?
# A: Frick Park is the largest park in Pittsburgh.
#
# 7
# Q: Who is a famous author born in Pittsburgh?
# A: Stephen Foster
#
# 7
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Mt. Washington
#
# 7
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 5
#
# 7
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# 7
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Mike Lange (radio)
#
# 7
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby (as of 20
#
# 7
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford
#
# 7
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes
#
# 7
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: 51 (D
#
# 7
# Q: In what season did the Penguins win their first Stanley Cup?
# A: 1991
#
# 7
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Barry Bonds (1992)
#
# 7
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold "
#
# 7
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: Indianapolis Indians
#
# 7
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A:
#
# 7
# Q: What is the admission cost at The Frick Pittsburgh?
# A: $2
#
# 7
# Q: What events are happening at The Frick on November 16?
# A: The Art of the Nativity: From Baroque to Bonkers (2:00 PM - 3:00 PM)
#
# 7
# Q: When was the Heinz History Center established?
# A: 1896
#
# 7
# Q: Where is the Hometown-Homegrown event happening?
# A: 1212 Smallman St, Pittsburgh, PA 15222
#
# 7
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Family Fun Days
#
# 7
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall, 26th February 2025
#
# 7
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: 1845
#
# 7
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Antony Walker
#
# 7
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Benedum Center, 7th St, Pittsburgh, PA 15222
#
# 7
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Hunt Institute for Botanical Documentation, 5th Floor, Hunt Library
#
# 7
# Q: When are the final exams in CMU?
# A: CMU does not provide information about final exam schedules on their public website. It is recommended that you check the official student portal or contact the university's registrar or academic advising office for the most accurate and up-to-date information.
#
# 7
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Monterey Bay Fish Grotto, 141
#
# 7
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: July 27, 2025, Benedum Center, Pittsburgh, PA 15222
#
# 7
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: The WYEP Hellbender Ball in 2025 will be hosted at Carnegie Music Hall.
#
# 7
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: November 19, 2023 at Heinz Hall, 600 Penn Ave, Pittsburgh, PA 15222.
#
# 7
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: 1000 Fort Duquesne Blvd, Pittsburgh, PA 15222
#
# 7
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: 7th St and Penn Ave, Pittsburgh, PA 15222, Benedum Center
#
# 7
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: 117 Sandusky Street, Pittsburgh, PA 15212
#
# 7
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Downtown Pittsburgh, Nov 29, 2024 - Jan 1, 2025, 5:00 pm - 7:00 pm, 1049 Penn Ave
#
# 7
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: 1001 Fifth Ave, Pittsburgh, PA 15219
#
# 7
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical is not provided in the contexts.
#
# 7
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Chicago Symphony Orchestra will not perform in Pittsburgh in 2025. (No known specific performance announced.)
#
# 7
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: October 31, 2024
#
# 7
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: The School of Computer Science was established at Carnegie Mellon in 1967.
#
# 7
# Q: What is the annual “Buggy” race tradition at CMU?
# A: No information provided about a "Buggy" race tradition at CMU in the contexts given.
#
# 7
# Q: What type of tax is applied to events in Pittsburgh?
# A: 5% amusement tax, excluding non-profit performing arts organizations.
#
# 7
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: 5%
#
# 7
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: 37.5%
#
# 7
# Q: Which sector does the ISP tax primarily target?
# A: Institution and services
#
# 7
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: ISP tax in Pittsburgh applies to Internet services, phones, and cable TV.
#
# 7
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: Not specified in the provided contexts.
#
# 7
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: May 31, August 31, November 30, February 28
#
# Answers generated and saved to: 1025_50_rerank_k_4_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 1025_50_rerank_k_4_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2905
# Recall: 0.3745
# F1 Score: 0.3002
# Exact Match: 0.1102

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1025, chunk_overlap=50,  k=4, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="1025_50_hybrid_k_4_answers.txt", rerank= False, use_hybrid = True)
# Out:
# 4
# 8
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm
#
# 8
# Q: What is the "Picklesburgh" event?
# A: Picklesburgh is the annual destination for all things pickled, featuring food, drinks, contests, and live music in Downtown Pittsburgh.
#
# 8
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Pittsburgh Symphony Orchestra
#
# 8
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: January 7, 2025 - January 12
#
# 8
# Q: What event features a Pixar exhibition?
# A: The Science Behind PIXAR event in Pittsburgh, May 25, 2024 - Jan 5, 2025. (https://downtownpittsburgh.com/events/event/?id=59986)
#
# 8
# Q: When is the next Penguins game against the Ducks?
# A: No information provided about the next Penguins game against the Ducks in the given contexts. Please check the official schedule of the Pittsburgh Penguins.
#
# 8
# Q: Where can you attend an improv comedy show in October?
# A: 943 Liberty Ave, Pittsburgh, PA 15222 (Select Start's Halloween Themed show on Oct 20, 2024)
#
# 8
# Q: What is "World Square" in Pittsburgh?
# A: Market Square in Pittsburgh, not World Square.
#
# 8
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: October 25, 26, and 27, 2024 at 7:30 pm - 10:30 pm, October 26, 2024 at 2 pm, and October 27, 2024 from 2:00 pm - 5:00 pm. (Queries can also be answered with the month and day of the event, such
#
# 8
# Q: What time is the Steelers game on October 28, 2024?
# A: 4:00 pm
#
# 8
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Picklesburgh is a destination for all things pickled, an annual festival that takes place in Downtown Pittsburgh. Voted the #1 Specialty Food Festival in the Country for three consecutive years by the readers of USA Today, it features food, drinks, snacks, merchandise, contests, and live music. The dates for the 2025 Festival are yet to be announced.
#
# 8
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: In Pittsburgh, you can attend yoga sessions in Market Square during Tuesdays and Sunday. (Reference: Market Square Yoga in the Square programming)
#
# 8
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: Largest transportation museum in the world dedicated to bicycles.
#
# 8
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Dec. 13-22, 2024 (select dates)
#
# 8
# Q: What is the August Wilson African American Cultural Center known for?
# A: Known
#
# 8
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie
#
# 8
# Q: Where is the American Jewish Museum located?
# A: Pittsburgh, Pennsylvania at Squirrel Hill JCC at the corner of Forbes Avenue and Murray Avenue.
#
# 8
# Q: What public biking option is available in Pittsburgh?
# A: Biking trail in Pittsburgh
#
# 8
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Contemporary art
#
# 8
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: picoCTF
#
# 8
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: The Center for PostNatural History in Pittsburgh focuses on organisms that have been intentionally and heritably altered by humans.
#
# 8
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: Randyland or Carnegie Science Center (contains Biosteel goats)
#
# 8
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Rachel Carson Bridge
#
# 8
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 200,000 (Picklesburgh 2023)
#
# 8
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Craig McCloud, in 2016.
#
# 8
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: At The Stacks at 3 Crossings, which is located at 2875 Railroad Street.
#
# 8
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh Hispanic Development Corporation (PHDC) and Casa San Jose.
#
# 8
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Pittsburgh Restaurant Week organizers
#
# 8
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: $24-cents (fixed-price 3-course meal) for the first Pittsburgh Restaurant Week.
#
# 8
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Increased visibility and engagement opportunities for sponsors.
#
# 8
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: Not specified in the provided contexts.
#
# 8
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: The Pittsburgh Downtown Partnership
#
# 8
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Latrobe Area Chamber of Commerce
#
# 8
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Pittsburgh Downtown Partnership
#
# 8
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Mary Kenner, a Black inventor
#
# 8
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Renegade song
#
# 8
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Hot Dogs & Wursts Galore
#
# 8
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Senor Bernie Zamora
#
# 8
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: "Naples Seals"
#
# 8
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill Mazeroski
#
# 8
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Roberto Clemente (1979)
#
# 8
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The Pirates' 1971 lineup didn't play on KDKA-FM, their flagship station until
#
# 8
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: Jerome Frank (Col 1890) played for the former Pittsburgh Stars, and he was the first player to have a no-cut contract in professional football.
#
# 8
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: Steelers' helmet has a helmet decal in the shape of a terrier dog named Steely McBeam.
#
# 8
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Civic Arena (Gulf and Kopper's Buildings)
#
# 8
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lem
#
# 8
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Black and gold change
#
# 8
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# 8
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 5 (back-to-back wins in 2016 and 2017 included)
#
# 8
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mister Rogers' Neighborhood
#
# 8
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: The Carnegie Museum of Natural History's dinosaur exhibit is nearly three times the size of the original dinosaur hall and features scientifically accurate, immersive environments spanning the Age of Dinosaurs.
#
# 8
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Picklesburgh is an annual event, not hosted by Carnegie Mellon's School of Computer Science.
#
# 8
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: picoCTF
#
# 8
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: Museum Lab™, a part of Children's Museum of Pittsburgh, is designed for older kids (ages 10+) with cutting edge experiences in art, tech and learning.
#
# 8
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: "Andrew Carnegie envisioned a museum collection consisting of the "Old Masters of tomorrow". "
#
# 8
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: Ray and Stephanie Lane Computational Biology Department
#
# 8
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: Dietrich
#
# 8
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: The Elmer H. Grimm Sr. Pharmacy Museum holds pharmacy memorabilia dating back to the early 20th century, including hand-carved finials, an old-fashioned powder mill, and a konseal machine.
#
# 8
# Q: Where is the Fort Pitt Museum located?
# A: In Downtown Pittsburgh, within Point State Park.
#
# 8
# Q: What notable feature does the Frick Fine Arts Building have?
# A: The Frick Fine Arts Building has scale reproductions of Italian masterpieces by Nicholas Lochoff.
#
# 8
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: The Heinz College
#
# 8
# Q: What is the Heinz History Center best known for?
# A: Largest history museum in America (
#
# 8
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Tax Rebellion (1791-179
#
# 8
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The Hunt Institute for Botanical Documentation focuses on botanical history.
#
# 8
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) is known for its professional graduate degree programs that fuse technologies, economics, and policies of secure communication networks and systems. It's an integral department of Carnegie Mellon University's College of Engineering, collaborating with the School of Computer Science, the Tepper School of Business, and the Heinz College. It's also the educational partner of Carnegie Mellon CyLab.
#
# 8
# Q: What is the Carnegie Science Center known for?
# A: Highmark SportsWorks®, the largest collection of sports and science exhibits in the world.
#
# 8
# Q: When was the Language Technologies Institute (LTI) founded?
# A: 1996 (changed from Center for Machine Translation)
#
# 8
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes Field
#
# 8
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh is referred to as The City of Bridges due to having 44
#
# 8
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Phi Mu Alpha Sinfonia (1917)
#
# 8
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: John Nash (BS, MS, Carnegie Institute of Technology, 1948)
#
# 8
# Q: What is a historic district in Pittsburgh?
# A: Schenley Farms Historic District
#
# 8
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# 8
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 9 Fortune 500 companies are headquartered in Pittsburgh.
#
# 8
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duquesne Dukes (NCAA FCS, Northeast Conference)
#
# 8
# Q: What notable novel is set in Pittsburgh?
# A: "None of the provided contexts mention a notable novel set in Pittsburgh."
#
# 8
# Q: Which popular film was shot in Pittsburgh?
# A: She's Out of My League
#
# 8
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: Monongahela Incline, Duquesne Incline
#
# 8
# Q: Who is the current mayor of Pittsburgh?
# A: Ed Gainey
#
# 8
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The Andy Warhol Museum
#
# 8
# Q: What is the largest park in Pittsburgh?
# A: Frick Park, 644 acres
#
# 8
# Q: Who is a famous author born in Pittsburgh?
# A: Stephen Foster
#
# 8
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Mt. Washington
#
# 8
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 5
#
# 8
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Mike Lange
#
# 8
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Mike Lange (Radio)
#
# 8
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Sidney Crosby
#
# 8
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford
#
# 8
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# 8
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: 51 (Sidney Crosby, 2009-10 season)
#
# 8
# Q: In what season did the Penguins win their first Stanley Cup?
# A: 1991
#
# 8
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: The last Pittsburgh Pirates player to win the MVP award is not specified in the contexts provided.
#
# 8
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold Winkler, the first voice of the Pittsburgh Pirates on the radio.
#
# 8
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: The Pittsburgh Pirates' Triple-A minor league affiliate is the Indianapolis Indians.
#
# 8
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve (Eastern League)
#
# 8
# Q: What is the admission cost at The Frick Pittsburgh?
# A: $20 (for eligible families receiving public assistance)
#
# 8
# Q: What events are happening at The Frick on November 16?
# A: No events happening at The Frick on November 16 are mentioned in the context.
#
# 8
# Q: When was the Heinz History Center established?
# A: 1896
#
# 8
# Q: Where is the Hometown-Homegrown event happening?
# A: 1212 Smallman St , Pittsburgh, PA 15222
#
# 8
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Family Fun Days
#
# 8
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall on February 26, 2025
#
# 8
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: 1845
#
# 8
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Antony Walker
#
# 8
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Benedum Center, 7th St, Pittsburgh, PA 15222
#
# 8
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Hunt Institute for Botanical Documentation, 5th Floor, Hunt Library
#
# 8
# Q: When are the final exams in CMU?
# A: I could not find specific information about CMU's final exams schedule in the contexts provided. For accurate and up-to-date information, it is best to visit Carnegie Mellon University's official website or contact their academic calendar office.
#
# 8
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Monterey Bay Fish Grotto, 1411 Grandview Avenue
#
# 8
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: Thursday, March 27, 2025 at Benedum Center, 7th St, Pittsburgh, PA 15222
#
# 8
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Carnegie Music Hall of Oakland (Assuming it's one of the venues for WYEP Hellbender Ball, based on the contextual information provided)
#
# 8
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Nov 10, 2023 Heinz Hall (600 Penn Ave, Pittsburgh, PA 15222)
#
# 8
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: 1000 Fort Duquesne Blvd , Pittsburgh, PA 15222
#
# 8
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: 7th St and Penn Ave, Pittsburgh, PA 15222, on the dates Jan 7, 2025 - Jan 12, 2025 at Benedum Center.
#
# 8
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: 117 Sandusky Street, Pittsburgh, PA 15212
#
# 8
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm at 1049 Penn Ave , Pittsburgh, PA 15212.
#
# 8
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: 1001 Fifth Ave, Pittsburgh, PA 15219
#
# 8
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina: The Tina Turner Musical's details aren't provided in the contexts.
#
# 8
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Chicago Symphony Orchestra is not mentioned to perform in Pittsburgh in 2025, based on the provided contexts.
#
# 8
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: July 26, 2024 (presuming the context dates are accurate)
#
# 8
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: No significant change occurred at Carnegie Mellon in 1967 is stated in the contexts provided.
#
# 8
# Q: What is the annual “Buggy” race tradition at CMU?
# A: There is no annual "Buggy" race mentioned in the provided contexts related to Carnegie Mellon University or Pittsburgh.
#
# 8
# Q: What type of tax is applied to events in Pittsburgh?
# A: 5% amusement tax is applied to events in Pittsburgh, excluding non-profit performing arts organizations.
#
# 8
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: 5%
#
# 8
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: 37.5%
#
# 8
# Q: Which sector does the ISP tax primarily target?
# A: Non-profit performing arts organizations are excluded from the ISP tax.
#
# 8
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: ISP tax applies to Amusement Tax revenues.
#
# 8
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: No explicit information about the due date for annual ISP tax filings in Pittsburgh was provided in the context.
#
# 8
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: May 31, August 31, November 30, and February 28 of the following year.
#
# Answers generated and saved to: 1025_50_hybrid_k_4_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 1025_50_hybrid_k_4_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.2805
# Recall: 0.3779
# F1 Score: 0.2901
# Exact Match: 0.1102

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1025, chunk_overlap=50,  k=8, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="1025_50_bm_25_8_answers.txt", rerank= False, use_hybrid = False, use_only_bm_25=True)
# Out:
# 8
# 8
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: Nov 29, 2024 - Jan 1, 2025
#
# 8
# Q: What is the "Picklesburgh" event?
# A: Picklesburgh is an annual festival
#
# 8
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: Pittsburgh Symphony Orchestra
#
# 8
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: Jan 7, 2025 - Jan 12, 2025 at Benedum Center, Pittsburgh, PA 15222.
#
# 8
# Q: What event features a Pixar exhibition?
# A: The Science Behind PIXAR event.
#
# 8
# Q: When is the next Penguins game against the Ducks?
# A: I couldn't find any specific mention of the Pittsburgh Penguins' next game against the Anaheim Ducks in the provided contexts. For up-to-date information, I recommend checking reliable sports websites or news sources.
#
# 8
# Q: Where can you attend an improv comedy show in October?
# A: 943 Liberty Ave, Pittsburgh, PA 15222 (for Short Form Jelly w Select Start and Lucky Draw events) 943 Liberty Ave, Pittsburgh, PA 15222 and 2101 Smallman St, Pittsburgh, PA 15222 (for Lucky Draw and Black & Gold Tour events) Arcade Comedy Theater, 943 Liberty Ave, Pittsburgh, PA 1522
#
# 8
# Q: What is "World Square" in Pittsburgh?
# A: World Square is not located in Pittsburgh.
#
# 8
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: October 25, 26, and 27, 2024 at the Benedum Center, Pittsburgh, PA 15222.
#
# 8
# Q: What time is the Steelers game on October 28, 2024?
# A: 8:00 pm
#
# 8
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Annual pickled food festival in Downtown Pittsburgh, featuring handcrafted food, artisan drinks, and live music, returning in July 2025.
#
# 8
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: Yoga in the Square (Market Square)
#
# 8
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: Largest transportation museum in the world
#
# 8
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: Dec 13, 2024 – Dec 22, 2024, select dates
#
# 8
# Q: What is the August Wilson African American Cultural Center known for?
# A: Arts exhibitions, performances, and education focused on the African diaspora.
#
# 8
# Q: Who founded the Carnegie Steel Company?
# A: Andrew Carnegie
#
# 8
# Q: Where is the American Jewish Museum located?
# A: Squirrel Hill JCC, Forbes Avenue and Murray Avenue, Pittsburgh, PA.
#
# 8
# Q: What public biking option is available in Pittsburgh?
# A: Pittsburgh Regional Transit provides biking options through its bike sharing program, Healthy Ride, and bus racks for bikes on select bus routes.
#
# 8
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: Art, Architecture, Design, Drama, Music
#
# 8
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: picoCTF competition
#
# 8
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: Organisms intentionally and heritably altered by humans, aka postnatural organisms.
#
# 8
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: Randyland museum
#
# 8
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: Rachel Carson Bridge
#
# 8
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: 90,000 (in its fourth year, 2022)
#
# 8
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: Craig McCloud founded the Pittsburgh Taco Festival in 2016.
#
# 8
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: 2875 Railroad St, Pittsburgh, PA 15222
#
# 8
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: Pittsburgh Hispanic Development Corporation (PHDC) and Casa San Jose.
#
# 8
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: Pittsburgh Restaurant Week was initiated by the organizers themselves.
#
# 8
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: No data provided about the theme pricing structure used in the first Pittsburgh Restaurant Week.
#
# 8
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Supports and celebrates the Pittsburgh Foodies and restaurant scene.
#
# 8
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: To answer your question, the Little Italy Days moved from September to August for better alignment with the summer season and peak tourist season in Pittsburgh.
#
# 8
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: Highmark, Allegheny Health Network
#
# 8
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: Wilbur E. Miller Jr.
#
# 8
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: Pennsylvania Historical and Museum Commission
#
# 8
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: Marjorie Pratt, Latrobe ice cream parlor owner
#
# 8
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: Renegade is played in the fourth quarter.
#
# 8
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: Free concerts on specific evenings
#
# 8
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: Iceburgh
#
# 8
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: Bunch of Bums (nickname earned by the Pirates due to their controversial signing of second baseman Lou Bierbauer)
#
# 8
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill Mazeroski
#
# 8
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: Roberto Clemente (1979)
#
# 8
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The Pirates' 1971 lineup was the first to use computer simulations for experiential learning of business roles.
#
# 8
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: John G. Roberts Jr. (Law 1979) –
#
# 8
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: Pointed Steelers logo
#
# 8
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: Igloo (Pittsburgh Civic Arena)
#
# 8
# Q: Which player scored in all five game situations in one NHL game?
# A: Mario Lemieux  (If context is needed for someone unfamiliar with "Mario Lemieux": He is a former professional ice hockey player who played most of his career with the Pittsburgh Penguins of the NHL)
#
# 8
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: Black and gold color scheme
#
# 8
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: Mario Lemieux
#
# 8
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: 5 (including back-to-back in the salary cap era)
#
# 8
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: Mister Rogers' memorabilia can be found at the Children's Museum of Pittsburgh.
#
# 8
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: Nearly three times the size of the original dinosaur hall, with immersive environments spanning the Age of Dinosaurs.
#
# 8
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Spring Carnival Code-a-Thon (CMU School of Computer Science event)
#
# 8
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: picoCTF (annual high school cybersecurity competition)
#
# 8
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: The Children's Museum of Pittsburgh is located in a
#
# 8
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: Preserve a "record of the progress and development of pictorial art in America."
#
# 8
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: Ray and Stephanie Lane Computational Biology Department (CBD)
#
# 8
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: Dietrich College of Humanities and Social Sciences
#
# 8
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: Contains pharmacy memorabilia dating back to early 20th century, such as drug products, equipment, and sundry products, including hand-carved finials, old-fashioned powder mill, and konseal machine.
#
# 8
# Q: Where is the Fort Pitt Museum located?
# A: In the heart of Downtown Pittsburgh, Point State Park.
#
# 8
# Q: What notable feature does the Frick Fine Arts Building have?
# A: Nicholas Lochoff Cloister, large Italian masterpiece reproductions
#
# 8
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: The Heinz College of Carnegie Mellon University offers graduate training in public policy and information systems management.
#
# 8
# Q: What is the Heinz History Center best known for?
# A: The Heinz History Center is best known for being Pennsylvania's largest history museum and an affiliate of
#
# 8
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: Whiskey Rebellion
#
# 8
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: Botanical Documentation
#
# 8
# Q: What is the Information Networking Institute (INI) known for?
# A: Established in 19
#
# 8
# Q: What is the Carnegie Science Center known for?
# A: Attracts more than half a million people yearly, home to Buhl Planetarium, Miniature Railroad & Village, and hundreds of interactive science exhibits, including Highmark SportsWorks (the largest sports and science exhibits in the world).
#
# 8
# Q: When was the Language Technologies Institute (LTI) founded?
# A: 1986
#
# 8
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: Forbes Field
#
# 8
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh is referred to as The City of Bridges because it has more than 446 bridges, more than any other city in the world.
#
# 8
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: Phi Mu Alpha Sinfonia, founded in 1917.
#
# 8
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: John Nash (1994 Nobel Memorial Prize in Economic Sciences)
#
# 8
# Q: What is a historic district in Pittsburgh?
# A: Schenley Farms Historic District
#
# 8
# Q: When was Carnegie Mellon University Founded?
# A: 1900
#
# 8
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: 9 Fortune
#
# 8
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Football Championship Subdivision (FCS), Duquesne Dukes
#
# 8
# Q: What notable novel is set in Pittsburgh?
# A: "None. The context provided does not mention a novel set in Pittsburgh."
#
# 8
# Q: Which popular film was shot in Pittsburgh?
# A: The Silence of the Lambs was shot in Pittsburgh.
#
# 8
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: The Monongahela Incline and Duquesne Incline.
#
# 8
# Q: Who is the current mayor of Pittsburgh?
# A: The current mayor of Pittsburgh is Ed G
#
# 8
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The Andy Warhol Museum.
#
# 8
# Q: What is the largest park in Pittsburgh?
# A: Frick Park (644 acres) is the largest park in Pittsburgh.
#
# 8
# Q: Who is a famous author born in Pittsburgh?
# A: Stephen Foster
#
# 8
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: Shadyside
#
# 8
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: 5
#
# 8
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: Myron Cope (Pittsburgh Steelers) and Greg Brown (Pittsburgh Penguins)
#
# 8
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: Mike Lange (Radio) & Paul Steigerwald (TV)
#
# 8
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: Not specified in the contexts.
#
# 8
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: Jim Rutherford
#
# 8
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: Wilkes-Barre/Scranton Penguins
#
# 8
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: Sidney Crosby (51 goals in 2009-10 season)
#
# 8
# Q: In what season did the Penguins win their first Stanley Cup?
# A: 1991
#
# 8
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: Clemente (1966)
#
# 8
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: Harold Arlin, 1922
#
# 8
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: Altoona Curve (Eastern League)
#
# 8
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: Altoona Curve (Eastern League)
#
# 8
# Q: What is the admission cost at The Frick Pittsburgh?
# A: The admission cost at The Frick Pittsburgh is not given explicitly in the contexts provided. The contexts mention that membership provides benefits including free admission to the museum, but they do not specify the cost for non-members. For more accurate information, it is recommended to directly contact The Frick Pittsburgh.
#
# 8
# Q: What events are happening at The Frick on November 16?
# A: No events are scheduled at The Frick Pittsburgh on November 16, according to the provided context.
#
# 8
# Q: When was the Heinz History Center established?
# A: 1896
#
# 8
# Q: Where is the Hometown-Homegrown event happening?
# A: 1212 Smallman St , Pittsburgh, PA 15222
#
# 8
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: Family Fun Days, Exhibition tours, Talks, Lectures, Frick Exhibition Readers' Series, Coffe & Culture programs, Films, Workshops, Interactive activities, Adaptive lessons.
#
# 8
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: Heinz Hall, Feb 26, 2025
#
# 8
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: The Pittsburgh Symphony Orchestra was founded in 1895.
#
# 8
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: Antony Walker
#
# 8
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: Benedum Center, Pittsburgh, PA 15222 (March 27, 2025)
#
# 8
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: Hunt Institute for Botanical Documentation, 5th Floor, Hunt Library
#
# 8
# Q: When are the final exams in CMU?
# A: Carnegie Mellon University does not have traditional final exams. Instead, final assessments and project submissions typically coincide with the end of each semester.
#
# 8
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: Monterey Bay Fish Grotto (1411 Grandview Avenue)
#
# 8
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: Thursday, March 27, 2025, Benedum Center, 7th St, Pittsburgh, PA 15222
#
# 8
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: Rex Theater
#
# 8
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: Heinz Hall, July 20, 2023
#
# 8
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: 1000 Fort Duquesne Blvd , Pittsburgh, PA 15222
#
# 8
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: "7th St and Penn Ave, Benedum Center, Pittsburgh, PA 15222".
#
# 8
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: 117 Sandusky Street, Pittsburgh, PA 15212 (until Jan 20, 2025)
#
# 8
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: Nov 29, 2024 - Jan 1, 2025 | 5:00 pm - 7:00 pm at 1049 Penn Ave, Pittsburgh, PA 15212 (URL: https://downtownpittsburgh.com/events/event/?id=61417)
#
# 8
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: 1001 Fifth Ave, Pittsburgh, PA 15219
#
# 8
# Q: When and where is Tina: The Tina Turner Musical?
# A: Tina Turner Musical: No specific date or location given in the contexts provided.
#
# 8
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: Not provided in contexts.
#
# 8
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: November 9, 2024
#
# 8
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: In 1967, the School of Computer Science was established at Carnegie Mellon University.
#
# 8
# Q: What is the annual “Buggy” race tradition at CMU?
# A: Annual "Buggy" race at CMU is a student tradition where they race aerodynamic cylinders, reaching up to 35 mph, during Spring Carnival.
#
# 8
# Q: What type of tax is applied to events in Pittsburgh?
# A: Amusement Tax
#
# 8
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: 5% (with interest and penalty not exceeding the maximum rate allowed by the Municipal Claims and Tax Liens Act)
#
# 8
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: 37.5%
#
# 8
# Q: Which sector does the ISP tax primarily target?
# A: Institutions and services
#
# 8
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Amusement tax
#
# 8
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: Annual ISP tax filings in Pittsburgh should be made within three (3) years after the due date for payment.
#
# 8
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: May 31, August 31, November 30, and February 28 (of the succeeding year)
#
# Answers generated and saved to: 1025_50_bm_25_8_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py 1025_50_bm_25_8_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.3093
# Recall: 0.4512
# F1 Score: 0.3244
# Exact Match: 0.0945

# %%
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1025, chunk_overlap=50,  k=8, questions_file="NLP-System-From-Scratch/test_data/reference_questions.txt", output_file="generator_only_answers.txt", rerank= False, use_hybrid = False, use_only_bm_25=False, generator_only=True)
# Out:
# 8
# Q: ﻿When is the "Holiday Lights Tour" in Pittsburgh happening?
# A: As of my last update, the Holiday Lights Tour in Pittsburgh is typically held during the holiday season, usually from late November to early January. However, due to the unpredictability of events, I recommend checking the official website or local tourist information for the most accurate and up-to-date information about the Holiday Lights Tour in Pittsburgh. You can find more details at VisitPittsburgh.com.
#
# Q: What is the "Picklesburgh" event?
# A: Picklesburgh is an annual three-day summer festival held in Pittsburgh, Pennsylvania, USA. The event celebrates the city's rich pickle history, particularly related to Mount Olive Pickles, which was founded in the region. The festival features a variety of pickle-themed food, exhibits, demonstrations, and events, including pickle-eating contests, live music, and children's activities. The event takes place along the city's Three Rivers water
#
# Q: Who will perform at the "Music of Led Zeppelin" event?
# A: I don't have real-time data or the ability to predict who will perform at specific events. To find out who will be performing at the Music of Led Zeppelin event, I recommend checking the official event website or contacting the event organizers directly.
#
# Q: When is "Funny Girl" being performed in Downtown Pittsburgh?
# A: I don't have real-time data or the ability to browse the internet. As of my last update, Funny Girl has not been scheduled to perform in Downtown Pittsburgh. For the most recent and accurate information, I recommend checking local theater listings or websites such as Pittsburgh Public Theater, Benedum Center, or Heinz Hall. You can also search for "Funny Girl Pittsburgh" on a search engine to find current listings.
#
# Q: What event features a Pixar exhibition?
# A: The event that features a Pixar exhibition is typically a film festival, art exhibition, or a science and technology fair. For instance, during the annual Pixar Festival at Disneyland Resort, you can find Pixar exhibitions. Additionally, museums like the Museum of Modern Art (MoMA) in New York City have showcased Pixar exhibits in the past.
#
# Q: When is the next Penguins game against the Ducks?
# A: As of my last update, the Pittsburgh Penguins and Anaheim Ducks have not scheduled a game against each other in the 2020-2021 NHL regular season. To get the latest schedule updates, I recommend visiting the official NHL website or checking the Penguins' or Ducks' respective team websites.
#
# Q: Where can you attend an improv comedy show in October?
# A: There are numerous improv comedy shows taking place worldwide throughout October. Here is a list of well-known improv theaters where you may find a show:  1. Upright Citizens Brigade Theatre (UCB Theatre) in New York City, Los Angeles, and Austin, Texas. Check their schedule on their official website for specific shows: https://www.ucbcomedy.com/  2. iO Theatre in Chicago, Illinois. Visit their website for
#
# Q: What is "World Square" in Pittsburgh?
# A: World Square in Pittsburgh doesn't exist. There is a World Trade Center, but it doesn't have a "square" associated with it. The confusion might arise from other cities like Sydney in Australia, where a World Square is a public space located in the Central Business District. However, in Pittsburgh, USA, there is no such designated location known as World Square.
#
# Q: When can you watch "Peter Pan" in Pittsburgh?
# A: To find out when you can watch Peter Pan in Pittsburgh, I recommend checking local movie theaters, live performance venues, or streaming services. Websites like Fandango (for movies), Pittsburgh Cultural Trust (for live performances), or Pittsburgh Parks Conservancy (for outdoor performances, if applicable) are good starting points to check the showtimes and dates for Peter Pan performances in Pittsburgh.  You could also set up alerts for any announcements about Peter Pan in Pittsburgh on these
#
# Q: What time is the Steelers game on October 28, 2024?
# A: I'm unable to provide specific date and time information beyond the current year as my data doesn't extend that far. NFL schedules are typically released two to three months before the season starts, so it would be best to check back closer to the 2024 season for the exact date and time of the Pittsburgh Steelers' game on October 28, 2024. You can visit the official NFL website or the Steelers' official site for updates on the
#
# Q: What is the "Picklesburgh" event in Pittsburgh?
# A: Picklesburgh is an annual three-day outdoor festival held in Pittsburgh, Pennsylvania. The event celebrates the region's rich pickle heritage and culture, and it features a variety of pickle-themed foods, drinks, vendors, live music, crafts, and activities.  The festival takes place along the banks of the Allegheny River in Point State Park, Downtown Pittsburgh, and it usually takes place around mid-July. The event attracts thousands
#
# Q: Where can you attend yoga sessions in Pittsburgh?
# A: There are numerous yoga studios in Pittsburgh where you can attend yoga sessions. Here are some of the most popular ones:  1. YogaWorks Pittsburgh (Multiple locations): Offering a variety of yoga classes ranging from Vinyasa, Yin, Restorative, and more.  2. Pittsburgh Power Yoga (Multiple locations): This studio focuses on Power Yoga and Hot Yoga classes.  3. LifeTree Yoga (Multiple locations): LifeTree Y
#
# Q: What is special about Bicycle Heaven in Pittsburgh?
# A: Bicycle Heaven in Pittsburgh, Pennsylvania, is recognized as the world's largest nonprofit bike museum and public bicycle worked, a title officially certified by Guinness World Records in 2013. Founded by Craig Maddock, the warehouse-style space houses over 4,000 restored and carefully curated bicycles dating ranging from the late 1800s to modern times.  The collection includes many rare and unique bicycles, such
#
# Q: When is the "Highmark Holiday Pops" concert happening in Pittsburgh?
# A: As of now, I don't have real-time data. It's best to check the official Highmark Downtown Pittsburgh Holiday Pops concert website (https://www.pittsburghsymphony.org/calendar-tickets/2021-2022-season/holiday-pops/) or contact the Pittsburgh Symphony Orchestra for the most accurate and up-to-date information about the concert dates.
#
# Q: What is the August Wilson African American Cultural Center known for?
# A: The August Wilson African American Cultural Center (AWAACC) is a multi-disciplinary arts facility in Pittsburgh, Pennsylvania, USA. It was designed to preserve, present, and promote African American Arts and culture. The center is named after the Pulitzer Prize-winning playwright August Wilson, who was born and raised in Pittsburgh. It houses a theatre, visual arts gallery, education facilities, and programming spaces for various performances, exhibitions, workshops, and other cultural events that celebrate the African
#
# Q: Who founded the Carnegie Steel Company?
# A: The Carnegie Steel Company was founded by Andrew Carnegie in 1875. Andrew Carnegie was a Scottish-American industrialist and business magnate who led the enormous expansion of the American steel industry in the latter half of the 19th century. He played a significant role in combining the economic and technological lead of the US in steel over its European competitors. After the sale of Carnegie Steel to U.S. Steel in 1901,
#
# Q: Where is the American Jewish Museum located?
# A: The American Jewish Museum does not exist as a single, standalone institution. There are several Jewish museums in the United States, and they are located in various cities, not one specific location. For example, the Museum of the American Jewish Experience is located in New York City, the National Museum of American Jewish History is located in Philadelphia, and the Skirball Cultural Center, which houses the Peter Lawrence and Helen B. Berger art and Jewish cultural collection, is located in Los Angeles, California
#
# Q: What public biking option is available in Pittsburgh?
# A: The primary public biking option in Pittsburgh is the Healthy Ride bike-share program. Operated by Bike Pittsburgh and sponsored by Highmark, Healthy Ride offers over 500 bikes and 65 stations across the city. This service is available to members with a variety of pass options, including hourly, daily, weekly, and annual memberships.  For more information on Healthy Ride, including how to register, bike locations, and pricing,
#
# Q: What type of art programs are hosted at the Carnegie Mellon College of Fine Arts?
# A: The Carnegie Mellon University's College of Fine Arts offers a variety of art programs across several departments, highlighted below:  1. School of Art: This school offers Bachelor of Fine Arts (BFA) and Master of Fine Arts (MFA) degrees in areas such as painting, sculpture, expanded media, photography, and printmedia. They also offer a Master of Arts (MA) in Design and a Bachelor of Science (BS) in Integrative Design, Arts
#
# Q: What cybersecurity competition is hosted by Carnegie Mellon CyLab?
# A: The cybersecurity competition hosted by Carnegie Mellon University's CyLab is the Cybersecurity Athletes Competition (CyberStartGame). CyberStartGame is an online game-based summer program for high school students aimed at increasing their understanding and skills in cybersecurity.  This competition consists of a series of challenges and quizzes in various cybersecurity fields such as coding, cryptography, forensics, and system administration. It is designed to be
#
# Q: What is the main focus of the Center for PostNatural History in Pittsburgh?
# A: The Center for PostNatural History (CPNH) in Pittsburgh primarily focuses on exploring, interpreting, and presenting the history and contemporary sciences of life that involve human intervention, known as post-natural histories. This could include genetically modified organisms, transgenic animals, biotechnology, and more. The CPNH seeks to educate the public about these topics, provoke thought, and inspire questioning of what constitutes nature in the 21
#
# Q: Which museum in Pittsburgh showcases both GloFish and Biosteel goats?
# A: There seems to be some confusion in your question. Neither the Carnegie Museum of Natural History nor the Andy Warhol Museum in Pittsburgh, nor any other museum in Pittsburgh, showcases GloFish or Biosteel goats as permanent exhibits. GloFish are genetically engineered tropical fish, and Biosteel goats are a specific breed of goats engineered to produce more muscle mass. Both are subjects of scientific study and may be seen in specialized
#
# Q: What bridge hosted Picklesburgh before it moved to a larger venue?
# A: The bridge that hosted Picklesburgh before it moved to a larger venue was the Fort Duquesne Bridge, also known as the Rachel Carson Bridge. This bridge, which spans the Allegheny River in Pittsburgh, Pennsylvania, was the site of the festival from 2012 to 2018. In 2019, Picklesburgh moved to the Allegheny Square on the North Shore to accommodate the growing number of attendees.
#
# Q: How many attendees did Picklesburgh attract by its fourth year?
# A: I don't have real-time data. As of 2020, Picklesburgh third year's attendance was reported to be around 120,000. It's reasonable to assume that for the fourth year, the attendance might have increased, but without specific figures, I cannot provide an accurate number. I recommend you to search for the latest updates or contact the event organizers directly for the most accurate information.
#
# Q: Who founded the Pittsburgh Taco Festival and in what year?
# A: The Pittsburgh Taco Festival was founded by Aaron Whinkle and Jon Mervis in 2014. The first festival took place on October 18, 2014. The event has since grown in popularity and now traditionally takes place annually in September.
#
# Q: Where was the 2024 Pittsburgh Taco Festival held?
# A: I'm sorry for any confusion, but as of my last update, the Pittsburgh Taco Festival is usually held annually in a given year, and not specifically in 2024. The previous events were held in Kennywood Park, West Mifflin, Pennsylvania. However, the date and location for the 2024 edition have not been announced yet. It's always best to check the official Pittsburgh Taco Festival website or their social media pages for the most
#
# Q: Which organizations does the Taco Festival partner with to honor Latin-American culture?
# A: I don't have real-time data or the ability to browse the internet to check which organizations the Taco Festival partners with specifically. However, such festivals often form partnerships with various cultural institutions, community groups, and restaurant associations to celebrate and promote Latin-American culture. These could include museums, schools, and local businesses within the Latin-American community. It's recommended to check the festival's official website or contact them directly for the most accurate information.
#
# Q: Who initiated the rebirth of Pittsburgh Restaurant Week?
# A: The Pittsburgh Restaurant Week was reinitiated and expanded by the Pittsburgh Downtown Partnership (PDP) in 2016, according to their official website. The event, which promotes dining in Pittsburgh, was originally started in 2005 by the Greater Pittsburgh Restaurant Association (GPRA). The PDP now manages and organizes the event, attracting a larger number of restaurants and diners each year.
#
# Q: What was the theme pricing structure used in the first Pittsburgh Restaurant Week?
# A: I don't have real-time data or specific details about the first Pittsburgh Restaurant Week. However, as of now (2022), Pittsburgh Restaurant Week typically uses a fixed-price menu structure. This means that participating restaurants offer a multi-course menu at a set price for both lunch (2-3 courses for $10, $15, or $20) and dinner (3-4 courses for $20, $30, or $4
#
# Q: What benefit can you get from sponsoring the Pittsburgh Restaurant Week?
# A: Sponsoring the Pittsburgh Restaurant Week can provide numerous benefits to your business:  1. Increased Visibility: By sponsoring an event as prominent as the Pittsburgh Restaurant Week, your brand gains significant exposure to a wide audience. Thousands of food enthusiasts and locals are drawn to these events, offering an incredible opportunity to showcase your brand.  2. Brand Association: Partnering with a well-regarded community event such as the Pittsburgh Restaurant Week allows your
#
# Q: What was the main reason for moving the Little Italy days from September to August?
# A: Without specific context, it's hard to provide an accurate answer. However, in general, events are sometimes moved from one month to another for various reasons. Here are some possible reasons:  1. Seasonal appropriateness: August might be more suitable for an outdoor event like Little Italy Days, as it's typically warmer and more pleasant for outdoor activities compared to September in many regions.  2. Availability of resources: The organizers of the event might have found
#
# Q: Which organization is a primary sponsor of Little Italy Days?
# A: The primary sponsor for Little Italy Days can vary depending on location. However, in San Diego, California, USA, the primary organization is the Little Italy Association. The event is their annual signature event showcasing the rich history, culture, and present-day vibrancy of the Little Italy neighborhood. This information is subject to change and it's always best to check the official Little Italy Days website or contact the Little Italy Association for the most accurate information.
#
# Q: Who was instrumental in reviving Latrobe’s connection to the banana split in 2004?
# A: The person who was instrumental in reviving Latrobe's connection to the banana split in 2004 was William A. High IV. He is a local resident and historian who formed the Latrobe Banana Split Festival Committee to commemorate the town's rich history associated with the popular dessert. His efforts helped in establishing the annual festival held in Latrobe, Pennsylvania, which celebrates the origins of the banana split and emphasizes its connection to the town.
#
# Q: Which organization installed a historical marker in 2013 at the dessert’s invention site?
# A: The organization that installed a historical marker at the site of the invention of desserts in 2013 was the National Park Service. The marker was placed at the L'Espalonasse Restaurant in Paris, France, where the term "dessert" was first used in the 17th century.
#
# Q: What inspired David Strickler’s banana split invention in Latrobe?
# A: David Strickler's invention of the banana split is rooted in the early 20th-century, as the exact inspiration for this famous dessert is not definitively known. However, there are a few theories about how it might have come to be.  One popular story suggests that the banana split was born out of a Sunday evening tradition. On Sunday evenings, after church, the young people in Latrobe would flock to T.B. Dobb
#
# Q: What fan tradition occurs at Acrisure Stadium in the fourth quarter of Steelers games?
# A: The fan tradition that occurs at Acrisure Stadium (previously Heinz Field) in the fourth quarter of Pittsburgh Steelers games is known as the Terrible Towel Wave. This tradition was started by Myron Cope, a former sportscaster for the Steelers, and was popularized during the team's Super Bowl victories in the 1970s.  Fans wave their Terrible Towels (an official pirate flag-like towel created in
#
# Q: What unique event takes place at PNC Park that’s popular with baseball fans?
# A: One unique event at PNC Park that's popular with baseball fans is "PiratesFest," an annual winter fan festival held in January. It features player autograph sessions, interactive games, and Q&A sessions with players and coaches. Fans can also get photos with Pirates mascots Pirate Parrot and the Cannonball Kid.  Another interesting event is the "Pirates Fantasy Camp" held over Martin Luther King Jr. weekend, where
#
# Q: Which iconic Pittsburgh mascot entertains fans at PPG Paints Arena?
# A: The iconic Pittsburgh mascot that entertains fans at PPG Paints Arena (formerly Consol Energy Center) is named Iceburgh. He is a large, blue mechanical seal, representing the city's hockey team, the Pittsburgh Penguins. Iceburgh has been entertaining fans since the 1991-1992 NHL season.
#
# Q: What nickname did the Pirates earn due to their controversial signing of second baseman Lou Bierbauer?
# A: The Pittsburgh Pirates earned the nickname "Пиратс фріс프утс" (Pirates Freshfeet) or simply "Fresh Feet Pirates" in German, due to the controversial signing of second baseman Lou Bierbauer. This was because, in 1887, Bierbauer had just completed a three-year military service obligation in the German Army and was thus considered a free agent, despite the National League's rarely
#
# Q: Which Pittsburgh Pirates player hit the only Game 7 walk-off home run in World Series history?
# A: Bill Mazeroski is the Pittsburgh Pirates player who hit the only Game 7 walk-off home run in World Series history. In 1960, during the final game of the World Series against the New York Yankees, Mazeroski (a second baseman predominantly known for his defensive prowess) connected with a pitch from Yankees' pitcher Ralph Terry, sending a ball over the left field wall, giving the Pirates the Championship title. This icon
#
# Q: Which Pirates player was named Most Valuable Player in every available category during the 1979 championship season?
# A: The player you're referring to is Barry Bonds, not a Pirate but a San Francisco Giant. One of the greatest baseball players of all time, Bonds made his major league debut with the Pittsburgh Pirates in 1979. However, after the 1992 season, he moved to the San Francisco Giants.  In 1979, Bonds joined the Pirates mid-season, but even in a limited number of appearances,
#
# Q: In what way did the Pirates' 1971 lineup defy traditional expectations?
# A: The Pittsburgh Pirates' 1971 lineup defied traditional expectations in several ways:  1. Age: The team had a remarkable balance of youth and experience, with players like Roberto Clemente (37), Milt May (36), and Al Oliver (26) coexisting with young rising stars like Dave Cash (24), Rennie Stennett (25), and Steve Blass (29). This unusual combination of veterans and young
#
# Q: Which future U.S. Supreme Court Justice once played for the Steelers under their original name, and what was significant about his contract?
# A: The future U.S. Supreme Court Justice whom you are referring to is Justice Samuel Alito. Before joining the legal profession, Alito played football as a teenager for the West Philadelphia Catholic Boys League. The Pittsburgh Steelers noticed his talent and offered him a contract in 1962. However, Alito's contract was unique since it included a provision that allowed him to continue attending college without losing his professional status, which Alito opted to do instead of signing.
#
# Q: What unique feature does the Steelers' helmet have that no other NFL team shares?
# A: The Pittsburgh Steelers' helmet is the only one in the NFL that has a three-dimensional logo. Their helmet features a raised Steelers wordmark, a feature that is not present on any other team's helmet. Also, the Steelers' helmet's color is a distinctive glossy metallic silver, while most other NFL teams have matte-finish helmets.
#
# Q: What was the Penguins' original arena nicknamed, influencing their team name?
# A: The original arena of the Pittsburgh Penguins was called the Civic Arena, but it was informally known as "Igloo." This nickname, combined with the team's adopted mascot, a penguin, is believed to have played a role in the team's name. The Civic Arena was officially named Mellon Arena from 2001 to 2010, but fans and media continued to refer to it as the
#
# Q: Which player scored in all five game situations in one NHL game?
# A: The only player known to score in all five game situations (goals, power play, short-handed, on the road, and at home) in a single NHL game is Mariusz Czerkawski. He achieved this feat on November 7, 1996, while playing for the Los Angeles Kings against the San Jose Sharks.  This rare accomplishment is also known as the "natural hat-trick," as it involves scoring goals in various
#
# Q: What color scheme change in 1980 led to controversy with the Boston Bruins?
# A: In 1980, the Boston Bruins' color scheme change from brown and yellow to black and gold (specifically, a darker and deeper shade of gold) stirred up plenty of controversy within the fanbase. The original brown and yellow color scheme was associated with the team since their inception in 1924, so the shift was unexpected and unwelcomed by many traditional fans. This change, however, had the support of the newer generation of Bruins fans
#
# Q: Who became the first player-owner in NHL history with the Penguins?
# A: The first player-owner in NHL history was Mario Lemieux when he bought the Pittsburgh Penguins in 1999. Not only did he own the team, but he also played for them until his retirement in 2006. This unique dual role earned him the nickname "The Magnificent One" and solidified his legacy as one of the greatest hockey players of all time.
#
# Q: How many Stanley Cups have the Penguins won, including their back-to-back wins in the salary cap era?
# A: The Pittsburgh Penguins have won the Stanley Cup 5 times. They won their first Stanley Cup in 1991-92, then repeated as champions in 2008-09. In the salary cap era, they won back-to-back titles in 2015-16 and 2016-17.
#
# Q: What children's television icon's memorabilia can be found at the Children's Museum of Pittsburgh?
# A: At the Children's Museum of Pittsburgh, you can find memorabilia related to Fred Rogers, the host of the beloved children's television show "Mister Rogers' Neighborhood." This iconic figure has a special connection to the museum, as it was located just a few blocks away from the WQED studios, where the show was produced.  Some of the Mister Rogers' Neighborhood artifacts you might find include costumes, props, sets, and
#
# Q: What unique feature does the Carnegie Museum of Natural History's dinosaur exhibit have?
# A: The Carnegie Museum of Natural History's dinosaur exhibit has a unique feature called the Hall of Saurropods. This exhibit is home to Diplodocus carnegii, a large herbivorous dinosaur, which was one of the first dinosaur fossils ever mounted and displayed as a complete skeleton. The mount is the flagship exhibit in the Hall, and it measures approximately 29 meters long. Another notable feature of the exhibit is
#
# Q: What annual event does Carnegie Mellon’s School of Computer Science host during Spring Carnival?
# A: Carnegie Mellon University's School of Computer Science hosts an event during the university's Spring Carnival called the "ACM Programming Competition." This is an intense, multi-hour programming contest where teams of students use their programming skills to solve complex computing problems. The event is typically hosted by the ACM (Association for Computing Machinery) student chapter at CMU.
#
# Q: Which competition organized by Carnegie Mellon CyLab is aimed at high school students?
# A: The competition organized by Carnegie Mellon's CyLab that caters to high school students is the PennApps High School competition, also known as P hack. This event introduces high school students to hands-on experience in computer science programming, hacking, and app development. It's designed to inspire the next generation of innovators, leaders, and cybersecurity professionals. PennApps High School is typically held annually at Carnegie Mellon University.
#
# Q: What is a significant feature of the Children's Museum of Pittsburgh in terms of building design?
# A: One significant feature of the Children's Museum of Pittsburgh's building design is its intentionally disorganized and chaotic exterior, which contrasts sharply with the ordered, structured environment adults often associate with museums. This playful aesthetic is meant to encourage curiosity and inspire children to explore the museum inside.  Inside, the museum maintains a flexible, open-ended, and ever-changing layout, with various exhibits incorporating real-world materials and opportunities for hands-on
#
# Q: What is the mission of the Carnegie Museum of Art, as envisioned by Andrew Carnegie?
# A: Andrew Carnegie established the Carnegie Museum of Art (CMA) with the mission to collect, preserve, present, and interpret American art and its counterparts from around the world for the education and enjoyment of a broad audience. The museum was intended to fulfill his vision of making art accessible to the public, regardless of social class or status.  This mission was further explained in Carnegie's 1895 address to the Southwest Pennsylvania Industrial Exhibition,
#
# Q: Which department at Carnegie Mellon specializes in AI-driven biomedical research?
# A: The Department of Machine Learning at Carnegie Mellon University has a strong focus on AI-driven biomedical research. However, for more specific research in this area, you might want to look into the Computer Science Department, particularly its Biomedical Informatics (BMI) laboratory, and the Department of Biological Sciences. The Simon Initiative also conducts research that intersects AI, data science, and education, with potential applications in biomedical fields. It'
#
# Q: What college at Carnegie Mellon University emphasizes interdisciplinary study in cognitive science, decision science, and history and policy?
# A: The college that emphasizes interdisciplinary study in cognitive science, decision science, and history and policy at Carnegie Mellon University is the Dietrich College of Humanities and Social Sciences. This college houses various departments such as Philosophy, Psychology, Economics, and History, which allow students to pursue a broad-based education, including the possibility of combining studies in cognitive science, decision science, and history and policy. Additionally, the Integrative Design, Arts and Technology Network
#
# Q: What is the Elmer H. Grimm Sr. Pharmacy Museum known for?
# A: The Elmer H. Grimm Sr. Pharmacy Museum, located in Cincinnati, Ohio, USA, is known for celebrating the history and evolution of pharmacy. It houses an extensive collection of artifacts, pharmacy tools, and objects that shed light on the development of pharmacy practices from the 18th century to the present day. The museum is part of the University of Cincinnati James L. Winkle College of Pharmacy and is dedicated
#
# Q: Where is the Fort Pitt Museum located?
# A: The Fort Pitt Museum is located in Pittsburgh, Pennsylvania, United States. Specifically, it's situated within Point State Park, which is at the intersection of the Allegheny and Monongahela rivers, forming the Ohio River. The museum is in the historic Fort Duquesne, which was built by French troops in the mid-18th century and later renamed Fort Pitt by the British. The museum is dedicated to the history of Pittsburgh and the region's Native American
#
# Q: What notable feature does the Frick Fine Arts Building have?
# A: The Frick Fine Arts Building, located at the University of Pittsburgh, is renowned for its distinctive Byzantine-Romanesque revival architectural style. Designed by Charles Breger and completed in 1915, the building features ornate arches, intricate stone carvings, and a central circular tower with a copper dome. The Frick Fine Arts Building is a prominent landmark on the university's campus, and it houses various departments related to
#
# Q: What programs does the Heinz College of Carnegie Mellon University offer?
# A: The Heinz College of Carnegie Mellon University offers a wide range of programs that focus on public policy and management, information systems, and reporting. Here are some of the Master's degree programs they offer:  1. Master of Public Policy and Management (MPP): This program prepares students for leadership positions in public, private, and nonprofit sectors.  2. Master of Science in Information Systems and Management (MSISM): This program equips students
#
# Q: What is the Heinz History Center best known for?
# A: The Heinz History Center, located in Pittsburgh, Pennsylvania, is primarily known for its extensive collection and exhibitions representing the history and culture of western Pennsylvania. It's one of the largest historical museums in the United States dedicated to a specific region. The center covers various aspects of the region's history, including the Steel Industry, Sports, Immigration, and, due to the city's famous resident, HenryHeinz, food history as well. The museum is also home to the
#
# Q: What historic event is associated with Pittsburgh’s Whiskey Rebellion?
# A: The Whiskey Rebellion in Pittsburgh is associated with the passage and subsequent protest of Alexander Hamilton's federal Excise Tax on domestically produced distilled spirits, specifically whisky, in 1791 during the presidency of George Washington. This event is significant as it was the first test of the federal government's power to collect taxes and to suppress dissent in the newly formed United States. Eventually, Washington led a small army to quell the unrest,
#
# Q: What is the focus of the Hunt Institute for Botanical Documentation?
# A: The Hunt Institute for Botanical Documentation focuses on the extensive study and preservation of significant botanical literature and art from around the world. It houses one of the largest and most significant collections of botanical paintings, drawings, and printed materials in North America, specifically concentrating on botanical illustration, florilegia (collections of illustrated plants), and related documentary materials. The institute is located at Carnegie Mellon University in Pittsburgh, Pennsylvania.
#
# Q: What is the Information Networking Institute (INI) known for?
# A: The Information Networking Institute (INI) is a well-known graduate program at Carnegie Mellon University in Pittsburgh, Pennsylvania, USA. It's renowned for offering advanced degrees in areas such as software engineering, cybersecurity, and computer networking, with a strong focus on practical, hands-on experience and industry connections. The INI is particularly recognized for its CyLab, which is one of the largest university-based cybersecurity laboratories in the world. The
#
# Q: What is the Carnegie Science Center known for?
# A: The Carnegie Science Center is located in Pittsburgh, Pennsylvania, and is a popular destination for both locals and tourists alike. The center is known for its interactive and educational exhibits that explore various scientific topics such as robotics, technology, energy, and the human body. Some of its most noteworthy attractions include the Buhl Planetarium, the Henry Ford II Exhibition: High Performance Vehicles, and the SportsWorks exhibit, which allows visitors to participate in sports
#
# Q: When was the Language Technologies Institute (LTI) founded?
# A: The Language Technologies Institute (LTI) at Carnegie Mellon University was founded in the year 1991. This institute is dedicated to conducting research in areas such as artificial intelligence, linguistics, computer science, and engineering, all with the goal of advancing the understanding and processing of human language.
#
# Q: What historic baseball park was home to the Pittsburgh Pirates from 1909 to 1970?
# A: The historic baseball park that was home to the Pittsburgh Pirates from 1909 to 1970 is Forbes Field. This legendary stadium, located in Pittsburgh, Pennsylvania, was not only where the Pirates played but also hosted numerous significant events such as college football games and concerts. Forbes Field replaced Exposition Park as the Pirates' home field and was replaced by Three Rivers Stadium. Renowned for its beautiful shadows and
#
# Q: Why is Pittsburgh referred to as "The City of Bridges"?
# A: Pittsburgh, Pennsylvania, often called "The City of Bridges," holds this nickname due to a unique and high concentration of bridges that span its waterways. With over 446 bridges, Pittsburgh has more bridges per capita than any other city in the United States. The city sits at the junction of three major rivers: the Allegheny River, the Monongahela River, and the Ohio River, which merge to form the Ohio River downstream
#
# Q: What is the oldest fraternity at Carnegie Mellon University?
# A: The oldest fraternity at Carnegie Mellon University is Phi Kappa Sigma (PKS), also known as "PK". The chapter was installed on October 20, 1929. Other fraternities with a long history at Carnegie Mellon University include Phi Kappa Tau, Phi Sigma Kappa, Sigma Phi Epsilon, and Delta Chi. However, Phi Kappa Sigma holds the distinction of
#
# Q: Who is a notable Nobel laureate alumnus from Carnegie Mellon University?
# A: A prominent Nobel laureate who attended Carnegie Mellon University is Richard Thaler. He earned his Ph.D. in economics from CMU in 1974 and was awarded the Nobel Memorial Prize in Economic Sciences in 2017 for his contributions to behavioral economics, including the "nudge" theory that governments and institutions can influence people's behaviors in a predictable way without limiting their freedom of choice.
#
# Q: What is a historic district in Pittsburgh?
# A: One of the well-known historic districts in Pittsburgh is the Shadyside neighborhood, which is recognized for its beautiful Victorian architecture. Another notable historic district is the Oakland neighborhood, home to many educational institutions, museums, and historic landmarks, such as the Carnegie Museums of Pittsburgh and Phipps Conservatory. The Strip District, though not officially a historic district, is also historically significant, as it once served as a hub for commerce and industry in the city.
#
# Q: When was Carnegie Mellon University Founded?
# A: Carnegie Mellon University was founded on August 19, 1900, in Pittsburgh, Pennsylvania, USA. The university was established through the merger of the Carnegie Technical Schools and the Mellon Institute for Industrial Research.
#
# Q: How many Fortune 500 companies are headquartered in Pittsburgh?
# A: As of 2021, there are two Fortune 500 companies headquartered in Pittsburgh: The Home Depot and U.S. Steel. However, it's important to note that these rankings can change from year to year.
#
# Q: Which football team does Duquesne University represent in NCAA competitions?
# A: Duquesne University represents the Duquesne Dukes in NCAA competitions. The Dukes compete in the National Collegiate Athletic Association (NCAA) Division I as members of the Atlantic 10 Conference for most sports. They have teams in football, men's and women's basketball, soccer, cross country, golf, track & field, tennis, lacrosse, and many other sports. For football, Duquesne plays in the NCAA'
#
# Q: What notable novel is set in Pittsburgh?
# A: The "Brideshead Revisited" is not set in Pittsburgh. Instead, the novel you might be referring to is "The Perks of Being a Wallflower" by Stephen Chbosky. This epistolary novel is set primarily in the Pittsburgh area and follows the life of a freshman, named Charlie, as he navigates high school and begins to come to terms with his mental health and sexuality.
#
# Q: Which popular film was shot in Pittsburgh?
# A: The popular film "The Dark Knight" (2008), featuring Batman, was partly shot in Pittsburgh. Some of the city's landmarks such as the David L. Lawrence Convention Center and the Benedum Center were utilized as Gotham City locations.
#
# Q: What are the two remaining operating inclines in Pittsburgh?
# A: In Pittsburgh, the two remaining operating incline railways, often referred to as funicular railways, are the Duquesne Incline and the Monongahela Incline.  1) Duquesne Incline: Located in the barrio (neighborhood) of Swissvale, the Duquesne Incline overlooks the city from Mount Washington. Constructed in 1877, it is one of the oldest major inclines still in operation.
#
# Q: Who is the current mayor of Pittsburgh?
# A: As of my last update, the current mayor of Pittsburgh is Bill Peduto. He has been in office since January 2014. However, it's always a good idea to double-check the current information, as mayoral terms and positions can change.
#
# Q: What is a famous museum in Pittsburgh dedicated to the works of a single artist?
# A: The museum you're referring to is the Andy Warhol Museum. It is located in Pittsburgh, Pennsylvania, and it is dedicated to the works of artist Andy Warhol. It houses an extensive collection of artworks, films, photos, sketchbooks, drawings, and sculptures spanning over three decades of his
#
# Q: What is the largest park in Pittsburgh?
# A: The largest park in Pittsburgh is Frick Park, covering approximately 644 acres. It was founded by industrialist Henry Clay Frick and donated to the city in 1919. Frick Park features beautiful valleys, mixed-growth woodlands, gardens, sports facilities, and nature trails. Other notable parks in Pittsburgh include Schenley Park, Highland Park, and Riverview Park, each offering unique attractions and amenities.
#
# Q: Who is a famous author born in Pittsburgh?
# A: One famous author born in Pittsburgh is John Edgar Wideman. He is known for his novels, short stories, and essays that explore themes of race, identity, and injustice. Some of his notable works include "Brothers and Keepers," "Damballah," and "Fever." However, if you were asking about a more widely recognized author, another option would be August Wilson, best known for his Pulitzer Prize-winning Pittsburgh Cycle plays like "Fences
#
# Q: What is one of the historic neighborhoods in Pittsburgh?
# A: One of the historic neighborhoods in Pittsburgh is the North Side. Specifically, the neighborhoods of Allegheny Center, Deutschtown (also known as East Allegheny), and Marshall-Shadeland make up a large part of the North Side.  Allegheny Center, in particular, has a rich history dating back to the 18th century when it served as the original site for Fort Allegheny. The area was later developed as a center
#
# Q: How many Stanley Cup championships have the Pittsburgh Penguins won?
# A: The Pittsburgh Penguins have won the Stanley Cup, the championship trophy of the National Hockey League (NHL), five times. They claimed their first title in 1991, followed by consecutive wins in 1992 and 1994 as part of their first dynasty. After a 17-year drought, they won their fourth championship in 2009, and their most recent title was in 2016, making Sid
#
# Q: Who is a notable broadcaster for the Pittsburgh Penguins?
# A: A notable broadcaster for the Pittsburgh Penguins is Mike Lange. He has been the radio play-by-play announcer for the team since the 1975-1976 season. Lange is known for his unique style and enthusiastic commentary, and he has won several awards for his work, including the Foster Hewitt Memorial Award from the Hockey Hall of Fame. He is widely regarded as one of the best hockey broadcasters of all time
#
# Q: Who is the current play-by-play broadcaster for the Pittsburgh Penguins?
# A: The current play-by-play broadcaster for the Pittsburgh Penguins is Mike Cherestic. He has been the voice of the Penguins since the 2019-2020 season. Prior to that, longtime broadcaster Phil Bourque shared the role in a dual play-by-play role during the 2018-2019 season after longtime Penguins broadcaster Mike Lange was placed on leave. L
#
# Q: Who is the current captain of the Pittsburgh Penguins?
# A: As of the 2021-2022 NHL season, the captain of the Pittsburgh Penguins is Sidney Crosby. He has been wearing the 'C' since 2007. Crosby, often referred to as 'Sid the Kid', is one of the best players in the NHL and has led the team to three Stanley Cup championships.
#
# Q: Who is the current general manager of the Pittsburgh Penguins?
# A: As of my last update, the current General Manager of the Pittsburgh Penguins is Ron Hextall, who took over the position in May 2021. However, I would recommend confirming this information as front office roles can change.
#
# Q: What is the name of the Penguins’ AHL affiliate team?
# A: The Wilkes-Barre/Scranton Penguins are the American Hockey League (AHL) affiliate team of the Pittsburgh Penguins. Officially named "Wilkes-Barre/Scranton Penguins," they play their home games at the Mohegan Sun Arena at Casey Plaza in Wilkes-Barre, Pennsylvania. Despite the dual-city name, most of their games have traditionally taken place in Wilkes-Barre.
#
# Q: Which Penguins player holds the record for most goals scored in a season?
# A: The Pittsburgh Penguins player who holds the record for most goals scored in a single season is Mario Lemieux, with 85 goals during the 1988-1989 season. This incredible feat further cemented his legendary status in the NHL.
#
# Q: In what season did the Penguins win their first Stanley Cup?
# A: The Pittsburgh Penguins won their first Stanley Cup in the 1991-1992 season, which is classified as spring, as the Stanley Cup Playoffs typically run from April through early June each year.
#
# Q: Who was the last Pittsburgh Pirates player to win the MVP award?
# A: The last Pittsburgh Pirates player to win the National League Most Valuable Player (MVP) award was Andrew McCutchen in 2013. Known as "Cutch," he was a center fielder who spent his entire career with the Pirates from 2009 to 2017. During that 2013 season, McCutchen hit .317 with 27 home runs, 96 RBI, 2
#
# Q: Who was the first voice of the Pittsburgh Pirates on the radio?
# A: The first voice of the Pittsburgh Pirates on radio was Harold "Pete" publication Koerner. He began broadcasting Pirate games on KDKA radio in Pittsburgh on August 11, 1921, making it the first-ever broadcast of a live sporting event in the United States. Koerner continued to work as the Pirates' radio announcer until 1956, incorporating his unique style and memorable phrases like "Ground rule
#
# Q: Who is the Pirates' Triple-A minor league affiliate?
# A: As of the 2023 season, the Pittsburgh Pirates' Triple-A minor league affiliate is the Indianapolis Indians. They play their home games at Victory Field in Indianapolis, Indiana. However, affiliations can change over time, so it's always a good idea to double-check the current affiliate.
#
# Q: Who is the Pirates’ Double-A minor league affiliate?
# A: As of the 2021 season, the Pittsburgh Pirates' Double-A affiliate is the Altoona Curve, which is based in Altoona, Pennsylvania, and plays in the Eastern League. However, affiliate teams can change, so it's a good idea to confirm the current affiliation on a season-by-season basis.
#
# Q: What is the admission cost at The Frick Pittsburgh?
# A: As of my last update, the admission cost for The Frick Pittsburgh in 2021 is as follows:  - General admission: $18 for adults, $10 for seniors (65+), $5 for students and youth (ages 3-17), free for children under 3 and Frick members. - Special exhibitions: Additional fee for visitors attending special exhibitions. Prices vary depending on the show.  I recommend checking
#
# Q: What events are happening at The Frick on November 16?
# A: I don't have real-time data, but as of my last update, The Frick Collection, a museum in New York City, typically does not provide specific event listings for individual dates without prior reservation or membership information. To find out about events happening at The Frick Collection on November 16, I recommend checking their official website (thefrick.org) or contacting their visitor services directly. You can reach them at (212) 288
#
# Q: When was the Heinz History Center established?
# A: The Heinz History Center was established on October 28, 1991, in Pittsburgh, Pennsylvania. The center is dedicated to collecting, preserving, and interpreting the history of western Pennsylvania, and it is affiliated with the Smithsonian Institution. The center is located in the historic Fort Pitt Block House and houses several exhibits, including the Western Pennsylvania Sports Museum, the Detre Library & Archives, and the presented by Citizens Bank Hall of Warriors
#
# Q: Where is the Hometown-Homegrown event happening?
# A: I don't have real-time data or the ability to browse the internet to give you the current location of an event like Hometown-Homegrown. I would recommend checking the official website or social media pages for Hometown-Homegrown to find the most accurate and up-to-date information about their events and locations.
#
# Q: What types of programs are available for children at The Frick Pittsburgh?
# A: The Frick Pittsburgh offers a variety of educational programs for children tailored to different age groups and interests. Here are some examples:  1. FrickStART Studio: This program is designed for children ages 3-10, and their families. It allows them to explore art through hands-on activities, crafts, and projects inspired by the permanent collection and special exhibitions at The Frick Pittsburgh.  2. School Programs: The Frick Pittsburgh offers school programs
#
# Q: Where is Shaggy performing with the Pittsburgh Symphony Orchestra in a reggae-themed event on February 26, 2025?
# A: I'm sorry for any confusion, but as of the time this model was last trained (2021), I don't have real-time updates regarding future events or performances. Scooby-Doo's human character, Shaggy, is typically voice-acted by celebrities and is not known to perform live concerts. Collaboration between a celebrity like Shaggy and an orchestra such as the Pittsburgh Symphony Orchestra for a regga
#
# Q: When was the Pittsburgh Symphony Orchestra founded?
# A: The Pittsburgh Symphony Orchestra was founded on March 25, 1845, making it one of the oldest orchestras in the United States. However, it should be noted that the present-day Pittsburgh Symphony Orchestra was reorganized in 1900, marking a significant point in its development. The orchestra has since been recognized for its international acclaim and is considered one of the "Big Five" orchestras in the U.S.
#
# Q: Who is the current Music Director of Pittsburgh Opera?
# A: As of my last update, the Music Director of Pittsburgh Opera is Antony Walker. He started his tenure in the 2015–2016 season. However, I recommend checking the most recent sources to confirm, as leadership positions can change.
#
# Q: Where is the Madama Butterfly opera scheduled to be performed in 2025?
# A: I don't have real-time or predictive capabilities to provide specific schedule details for future performances. For the most accurate and up-to-date information, I recommend checking the official websites of prominent opera houses, such as the Metropolitan Opera, San Francisco Opera, or English National Opera. You can also use a search engine to find performance schedules for specific cities or regions.
#
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration happening?
# A: I don't have real-time updates or specific event details, but I can tell you that the 17th International Exhibition of Botanical Art & Illustration is typically hosted by the Society of Botanical Artists, which is based in the United Kingdom. The exact location for each exhibition varies and is usually held at a different venue within the UK. For the most accurate and up-to-date information, I recommend visiting the Society of Botanical Artists
#
# Q: When are the final exams in CMU?
# A: The final exam schedule at Carnegie Mellon University (CMU) is typically released about a month before the start of the exam period. The exact date for final exams can vary depending on the academic term. For the Fall 2022 semester, the final exam period was from Tuesday, December 13 to Friday, December 16.  It's always a good idea to check the CMU academic calendar or reach out to your academic advisor
#
# Q: Where is the annual Maecenas Gala by Pittsburgh Opera happening on May 17, 2025?
# A: As of the time this question was generated (2022), the location for the Maecenas Gala by Pittsburgh Opera on May 17, 2025, has not been announced. It is advised to visit the Pittsburgh Opera's official website or contact them directly for the most accurate and up-to-date information regarding the location of their events.
#
# Q: When and where will Madama Butterfly by Pittsburgh Opera be performed?
# A: "Madama Butterfly" by Pittsburgh Opera will be performed at the Benedum Center for the Arts, located at 237 7th Street, Pittsburgh, PA 15222, USA. Please check the Pittsburgh Opera's official website for the exact dates and times of the performances. Tickets can usually be purchased online through their website or at the box office. I recommend visiting their website or contacting them for the most updated information.
#
# Q: What venue will host the WYEP Hellbender Ball in 2025?
# A: As of the time this model was trained, I don't have real-time data or the ability to predict future events. I can't tell you what venue will host the WYEP Hellbender Ball in 2025 as that information hasn't been announced yet. I recommend checking WYEP's official website or social media channels for updates.
#
# Q: Where and when is Spider-Man: Into the Spider-Verse Live in Concert?
# A: As of my last update, there isn't a specific "Spider-Man: Into the Spider-Verse Live in Concert" event scheduled. However, in the past, similar animated films have been presented with live orchestral performances. You can check the official website of the movie or your local cinema for updates. If a concert event is planned, it will likely be announced through these channels.  For the latest updates, you can also visit the sonyclassic
#
# Q: Where will Pittsburgh Vintage Mixer be held on May 11, 2025?
# A: I don't have accurate, real-time data. The Pittsburgh Vintage Mixer's location changes with each event, and as of now, I don't have the information about the event on May 11, 2025. I would recommend checking the Pittsburgh Vintage Mixer's official website or social media pages for the most up-to-date information.
#
# Q: Where is Funny Girl showing in Pittsburgh in 2025?
# A: I cannot provide the information you're seeking as I don't have the ability to predict or give real-time information about upcoming productions that far in advance. I suggest checking local Pittsburgh theaters' websites or season announcement announcements for information about shows in 2025.
#
# Q: Where is the KAWS + Warhol exhibition running in 2025?
# A: I don't have the ability to predict future events or exhibitions with certainty. As of my last update, KAWS and Warhol's works are frequently exhibited in popular museums and galleries around the world, including the Museum of Modern Art (MoMA) and the Gagosian Gallery in New York, the Modern Art Museum of Fort Worth, and the Royal Academy of Arts in London. To get the most accurate and up-to-date information
#
# Q: Where and when can visitors enjoy the Holiday Lights Tour in Downtown Pittsburgh?
# A: The Holiday Lights Tour in Downtown Pittsburgh is an annual event organized by Duquesne University's Beta Alpha Psi, a business professional organization. The exact dates for the tour may vary each year, but it typically takes place in December, during the holiday season.  The tour usually starts at the A.J. Palumbo Center, located at 3700 Forbes Avenue, Pittsburgh, PA 15260. To confirm the exact
#
# Q: What venue hosts the Disney on Ice event from April 3-6, 2025?
# A: To provide an accurate answer, I would need the city or specific area where the Disney on Ice event takes place in April 2025. Disney on Ice events happen all around the world, so the venue can vary depending on the location. For example, in the United States, it might take place at venues like Amway Center (Orlando), Barclays Center (Brooklyn), or United Center (Chicago). To get the exact venue for your location, I recommend
#
# Q: When and where is Tina: The Tina Turner Musical?
# A: "Tina: The Tina Turner Musical" is a biographical musical based on the life of Tina Turner, an American-born singer and actress. The musical premiered at the Aldwych Theatre in London in April 2018. As of its latest run in London, it's being staged at the Tina Turner Musical Theatre at Aldwych.  In October 2019, the musical started its first North American tour at the
#
# Q: Where will the Chicago Symphony Orchestra perform in 2025?
# A: I don't have the ability to predict future performances of the Chicago Symphony Orchestra. However, as of now, the Chicago Symphony Orchestra performs primarily at the Symphony Center, located in the heart of Chicago's Loop district. They may also perform at other venues for special events. For an updated schedule, it's best to visit their official website or contact them directly.
#
# Q: What date is Paw Patrol Live! happening at Petersen Events Center?
# A: I don't have real-time data, so I can't provide the exact current date for an event like Paw Patrol Live! at the Petersen Events Center. To find out the date, I recommend checking the official website for the venue, such as the Petersen Events Center, or the official Paw Patrol Live! website. They have the most accurate and up-to-date information on event schedules.
#
# Q: What significant change occurred at Carnegie Mellon in 1967?
# A: In 1967, Carnegie Institute of Technology (CIT) merged with the Carnegie Institute of Technology's School of Army Engineering to create Carnegie Mellon University (CMU). This merger combined CIT's strong base in engineering and computer science with the Army Engineering School's Army Research Office and research programs in aerospace, materials, and manufacturing. The resulting university is known today for its research and education excellence in those areas,
#
# Q: What is the annual “Buggy” race tradition at CMU?
# A: The annual Buggy race at Carnegie Mellon University (CMU) is a tradition that predates the founding of the university itself. It is the world's oldest and largest collegiate off-road race, with both alumni and current students participating.  Inspired by Tom Sawyer's Roman-style chariot driven by a mule, the first buggy race was organized in 1887, back when CMU was known as the
#
# Q: What type of tax is applied to events in Pittsburgh?
# A: In Pittsburgh, events may be subject to several types of taxes depending on the nature of the event. Here are some common taxes that might apply:  1. Sales and use tax: If you charge admission or sell goods and services at your event, you'll likely have to collect Pennsylvania's 6% sales tax (as of 2022) from your attendees.  2. Hotel occupancy tax: If you're hosting an event in a hotel
#
# Q: What is the maximum percentage rate for Pittsburgh's amusement tax?
# A: As of my last update, the maximum rate for Pittsburgh's Amusement Tax is 5%. However, for specific, current, or location-dependent information, please refer to the official Pittsburgh City Revenue website or consult with a tax professional. Laws and rates are subject to change.
#
# Q: What is the current maximum percentage rate for Pittsburgh's parking tax?
# A: As of my last update, Pittsburgh does not have a city-level parking tax. However, certain areas within Pittsburgh, such as the downtown district, may be subject to a parking tax as part of the Pittsburgh Downtown Partnership's Clean & Safe program. The rate for this specific tax can vary, but it is typically around 10-12%. For the most accurate and current information, I recommend checking the official city or partnership websites.
#
# Q: Which sector does the ISP tax primarily target?
# A: The ISP (Internet Service Provider) tax primarily targets the internet service sector. It is a tax on the provision of internet services, including both fixed (wired) and mobile internet connections. This tax revenue is often used to fund digital infrastructure developments and government programs that support digital inclusivity or digital services. However, the exact allocation of these tax revenues can vary significantly depending on the specific policies and regulations of the respective countries implementing such taxes.
#
# Q: Which types of revenues are subject to Pittsburgh's ISP tax?
# A: Pittsburgh's Internet Service Provider (ISP) tax applies to the following types of revenues generated by telecommunications companies that provide internet services within the city limits:  1. Revenue from providing internet service on a subscription basis: This includes monthly or annual charges for providing internet access to residential and commercial customers.  2. Revenue from charging for data usage: This may include fees for exceeding a monthly data cap, flat fees for unlimited data, or charges for
#
# Q: What is the due date for annual ISP tax filings in Pittsburgh?
# A: The due date for annual ISP (Internet Service Provider) tax filings can vary depending on the jurisdiction. For Pittsburgh, Pennsylvania, the due date for Business Privilege and Earned Income taxes (which might apply to ISPs) is typically March 15th for calendar year filers. However, it's essential to consult the current rules from the Allegheny County Treasurer's office or the Internal Revenue Service (if it'
#
# Q: When are quarterly payroll tax returns due for employers in Pittsburgh?
# A: In the United States, the due date for quarterly payroll tax returns (Form 941) is typically April 30, July 31, October 31, and January 31, for the tax quarters ending respectively in March, June, September, and December. However, these due dates may vary depending on the particular state's regulations.  For employers in Pittsburgh, Pennsylvania, the Pennsylvania Department of Revenue follows these federal deadlines for the submission
#
# Answers generated and saved to: generator_only_answers.txt

# %%
# !python NLP-System-From-Scratch/evaluate/evaluation.py generator_only_answers.txt NLP-System-From-Scratch/test_data/reference_answers.txt
# Out:
# Precision: 0.0371
# Recall: 0.4142
# F1 Score: 0.0654
# Exact Match: 0.0000

# %%
## Now running on the main test_data
run_everything(vector_store_dir="drive/MyDrive/Annanya_ANLP/chroma_stella_1024_50", chunk_size=1025, chunk_overlap=50,  k=8, questions_file="test_questions.txt", output_file="drive/MyDrive/system_output_bm25.txt", rerank= False, use_hybrid = False, use_only_bm_25=True)
# Out:
# 8
# 8
# Q: "What bank, which is the 5th largest in the US, is based in Pittsburgh?"
# A: PNC Bank
#
# 8
# Q: How many bridges does Pittsburgh have?
# A: 446 bridges
#
# 8
# Q: Who named the city of Pittsburgh?
# A: The city of Pittsburgh was not named by anyone specifically. Its name is derived from a portage path called "Kikihtentick" which was given by the local Allegheny people, which in time became "Pitts town" and eventually Pittsburgh.
#
# 8
# Q: At what park do the three rivers converge in Pittsburgh?
# A: Point State Park
#
# 8
# Q: How many neighborhoods does Pittsburgh have?
# A: 90 neighborhoods
#
# 8
# Q: What Pittsburgh neighborhood is also known as Little Italy?
# A: Little Italy, Pittsburgh.
#
# 8
# Q: What is the largest employer in Pittsburgh?
# A: University of Pittsburgh Medical Center (UPMC)
#
# 8
# Q: What Pittsburgh rapper has an album title referencing Frick Park?
# A: Mac Miller
#
# 8
# Q: What famous vaccine was developed at University of Pittsburgh in 1955?
# A: Jonas Salk vaccine (1955)
#
# 8
# Q: What Pittsburgh bridge was the first lenticular truss bridge?
# A: Homestead Grays Bridge
#
# 8
# Q: What city in China is a sister city of Pittsburgh?
# A: Chengdu
#
# 8
# Q: What day was Pittsburgh founded?
# A: Pittsburgh
#
# 8
# Q: Who is Pittsburgh named after?
# A: Pittsburgh is named after William Penn, who founded the colony in
#
# 8
# Q: Who was Pittsburgh's first mayor?
# A: Frederick W. Crawford (1816)
#
# 8
# Q: Who was Pittsburgh's first (and only) female mayor?
# A: Sophie Masloff (1994-2006)
#
# 8
# Q: What day were the Pittsburgh Steelers founded?
# A: Carnegie Mellon University was founded in 1900, not the Pittsburgh Steelers. There's no information about the foundation day of the Pittsburgh Steelers in the contexts you've provided.
#
# 8
# Q: Which sports team is the oldest professional sports team in Pittsburgh?
# A: Pittsburgh Pirates (baseball, established in 1882)
#
# 8
# Q: What famous American artist has a museum dedicated to his work in Pittsburgh?
# A: Andy Warhol
#
# 8
# Q: What is the name of the dinosaur statue outside the Carnegie Museums in Oakland?
# A: Dippy, Diplodocus carnegii.
#
# 8
# Q: What Pittsburgh neighborhood is home to the steepest street in the US?
# A: Canton Avenue (Pittsburgh)
#
# 8
# Q: What is the amusement tax rate in Pittsburgh?
# A: 5%
#
# 8
# Q: "Based on the definition of a Performing Art in the Pittsburgh tax code, is admissions to a movie theater considered a Performing Art?"
# A: No. Admissions to a movie theater are not considered a Performing Art because it is not a live performance, and nor would they be considered an Exempt Performing Arts Production.
#
# 8
# Q: Where should tax-related petitions to the Treasurer of Pittsburgh be mailed to?
# A: TREASURER HEARINGS TREASURER – C
#
# 8
# Q: Within what time frame shall the Treasurer of Pittsburgh respond to a tax-related petition?
# A: 30 calendar days
#
# 8
# Q: "After 2016, when is the payroll tax for the first quarter due?"
# A: January 31st for the payroll tax for the first quarter (of each year).
#
# 8
# Q: "Under the Pittsburgh payroll expense tax regulations, how long does a Taxpayer have to respond to audit notices?"
# A: 30 calendar days, with potential for an extension upon showing good cause.
#
# 8
# Q: What is the maximum fine for making a false statement on a tax return in Pittsburgh?
# A: 500 dollars for summary conviction, or 2000 dollars for a conviction under the Local Tax Enabling Act.
#
# 8
# Q: "Except for new businesses, when are both the tax return and payment due in Pittsburgh?"
# A: April 15th of every year.
#
# 8
# Q: At what address can forms for tax returns be obtained in the city of Pittsburgh?
# A: TREASURER, CITY OF PITTSBURGH DEPARTMENT OF FINANCE, 414 GRANT ST RM 206 PITTSBURGH PA 15219
#
# 8
# Q: How much is the Local Services Tax in Pittsburgh?
# A: .0055 or 0.55% (of Payroll Expense)
#
# 8
# Q: What is the parking tax rate in the city of Pittsburgh?
# A: 37.5% (as of 2024)
#
# 8
# Q: Who is the current chief of staff of the mayor of the city of Pittsburgh?
# A: Data not provided. There was no information in the provided contexts about the current chief of staff of the mayor of the city of Pittsburgh.
#
# 8
# Q: Who is the current director of finance of the city of Pittsburgh?
# A: Current information is not provided for the query, but in the context provided, there is no clear indication of a current director of finance for the city of Pittsburgh mentioned.
#
# 8
# Q: What is the projected total revenue for the city of Pittsburgh in 2025?
# A: $714,214,923 (for Fiscal year 2024). The query asked for 2025, but the data provided is for 2024. There's no data given for 2025.
#
# 8
# Q: What was Pittsburgh's total revenue in 2021?
# A: Pittsburgh's total revenue in 202
#
# 8
# Q: "In 2024, what percentage of the projected total revenue will be non-tax revenue?"
# A: 24.1%
#
# 8
# Q: "In 2022, how much did the city of Pittsburgh spend on the Bureau of Police?"
# A: $230,000 (in FY2024 budget)
#
# 8
# Q: "In 2022, how much did the city of Pittsburgh spend on Parks and Recreation?"
# A: The city of Pittsburgh spent $5,000,000 on Parks and Recreation in Fiscal Year 2024, according to the City of Pittsburgh Operating Budget Departments. However, for Fiscal Year 2022, specific budget details were not provided in the contexts provided.
#
# 8
# Q: How often is the City Clerk elected by members of the Pittsburgh City Council?
# A: Every three years
#
# 8
# Q: How much did the Fire Chief in Pittsburgh make in 2023?
# A: $141,397 (assuming no changes in salary from 2024 budget)
#
# 8
# Q: Who is the concertmaster of the Pittsburgh Symphony Orchestra?
# A: Noah Bendix-Balgley (formerly) / Not specified (currently)
#
# 8
# Q: Who is the acting principal violist of the Pittsburgh Symphony Orchestra
# A: There is no specific mention of an acting principal violist in the provided contexts.
#
# 8
# Q: Who is the principal bassist of the Pittsburgh Symphony Orchestra
# A: John Moore
#
# 8
# Q: Who is the assistant librarian of the Pittsburgh Symphony Orchestra
# A: There is no information provided about an assistant librarian for the Pittsburgh Symphony Orchestra.
#
# 8
# Q: When do doors open before performances for concerts at the Pittsburgh Symphony for classical concerts?
# A: One hour prior to classical concerts.
#
# 8
# Q: Is there an official dress code for Heinz Hall?
# A: No, there is no official dress code for Heinz Hall. Wear whatever makes you feel more comfortable.
#
# 8
# Q: "What two operas are being performed at the Benedum Center on Nov 9, 12, 15, and 17?"
# A: Cavalleria Rusticana and Pagliacci
#
# 8
# Q: What opera is being performed by an all-Japanese and Japanese American creative team at the Benedum Center in March 2025?
# A: Madama Butterfly (Pittsburgh Opera, March 2025)
#
# 8
# Q: Who is the current leader of the Pittsburgh Opera?
# A: Christopher Hahn
#
# 8
# Q: Who is the current music director of the Pittsburgh Opera?
# A: Manfred Honeck (Pittsburgh Symphony Orchestra)
#
# 8
# Q: Who is the current resident pianist for the Pittsburgh Opera?
# A: Not specified in the provided contexts. The job announcement is for 2024-25 Resident Program.
#
# 8
# Q: Where does the Pittsburgh Opera perform?
# A: Benedum Center in Pittsburgh
#
# 8
# Q: What is the suggested time to arrive before a show at the Pittsburgh Opera?
# A: Please arrive at least 30 - 45 minutes before the show at Pittsburgh Opera.
#
# 8
# Q: "What dates is ""Peter Pan"" by the Pittsburgh Ballet Theater playing at the Benedum Center?"
# A: Oct 25, 26, and 27, 2024 (7:30 pm, 2 pm, 2:00 pm - 5:00 pm respectively)
#
# 8
# Q: When was the Pittsburgh Cultural Trust founded?
# A: 1984
#
# 8
# Q: How many square blocks is the Pittsburgh Cultural District?
# A: 14 square blocks
#
# 8
# Q: What are the gallery hours for The Galleries at the Pittsburgh Cultural Trust?
# A: 11 AM - 6 PM, Wednesday - Sunday
#
# 8
# Q: What are the dates for Monument Eternal: Le’Andra LeSeur at the Wood Street Gallery?
# A: Oct 25, 2024 - Jan 5, 2025
#
# 8
# Q: What number can you call to purchase Cultural Trust event tickets?
# A: 412.456.6666
#
# 8
# Q: What is the reprint fee per ticket for Cultural Trust event tickets?
# A: The reprint fee per ticket for Cultural Trust event tickets is not explicitly mentioned in the context provided. It might be necessary to contact the Box Office for clarification.
#
# 8
# Q: What year did Little Italy Days start?
# A: 2002
#
# 8
# Q: On what date does Pittsburgh Restaurant Week Winter 2025 begin?
# A: January 13, 2025
#
# 8
# Q: When does Pittsburgh Restaurant Week Winter 2025 end?
# A: Sunday, January 19th
#
# 8
# Q: What is the location of The UPMC Rink at PPG Place?
# A: Downtown Pittsburgh
#
# 8
# Q: In what year did the UPMC Rink at PPG Place become a staple holiday attraction in Downtown Pittsburgh?
# A: 2001
#
# 8
# Q: What type of celebration is the Pittsburgh Irish Festival?
# A: Only in Pittsburgh celebration
#
# 8
# Q: "Besides live music and dance, what activities are offered for children at the Pittsburgh Irish Festival?"
# A: Gluten free, vegan and vegetarian food options, Sensory bags available at the front gate, Baby Care Tent available.
#
# 8
# Q: What year was the Pennsylvania Railroad Station opened?
# A: 1842
#
# 8
# Q: Where is St. Stanislaus Kostka Church located?
# A: St. Stanislaus Kostka Church is located in Pittsburgh.
#
# 8
# Q: What architectural styles are reflected in St. Stanislaus Kostka Church?
# A: Gothic Revival
#
# 8
# Q: What is the name of the bridge connecting the Allegheny County Courthouse to the prison?
# A: Smithfield Street Bridge
#
# 8
# Q: How tall are the columns at the Mellon Institute of Industrial Research?
# A: Information about the height of the columns at the Mellon Institute of Industrial Research was not provided in the contexts.
#
# 8
# Q: In what year did the original Allegheny County Courthouse burn down?
# A: 1895
#
# 8
# Q: In what year was Carnegie Mellon University founded?
# A: 1900
#
# 8
# Q: How many faculty members are there at Carnegie Mellon University?
# A: Not specified in the contexts provided.
#
# 8
# Q: What programming language was invented by CMU alumnus James Gosling?
# A: Java
#
# 8
# Q: In what year was the first U.S. degree in drama awarded by CMU?
# A: 1914
#
# 8
# Q: What neighborhood in Pittsburgh is known for having the best view of the city?
# A: South Side Flats, West End Overlook, Mt. Washington (Emerald Park), Point State Park (river view), Mt. Washington Overlook (West End)
#
# 8
# Q: Which Pittsburgh neighborhood is recognized for its historical black culture and change?
# A: Homewood
#
# 8
# Q: Where is Pittsburgh’s largest Episcopal church located?
# A: The largest Episcopal church in Pittsburgh is Cathedral of Saint Paul.
#
# 8
# Q: What neighborhood has a reimagined industrial mill town with breweries and local shopping?
# A: Millvale
#
# 8
# Q: What Pittsburgh neighborhood features both world-class hospitals and museums?
# A: Oakland
#
# 8
# Q: What nickname was given to Pittsburgh due to its strategic location?
# A: Golden Triangle (Reference: context at the end related to Pittsburgh Downtown Partnership and Picklesburgh)
#
# 8
# Q: What Pittsburgh-based food manufacturer is known for their philanthropy?
# A: H.J. Heinz
#
# 8
# Q: What was Pittsburgh’s rank in size among U.S. cities during the mid-1950s?
# A: 4th largest (1950 census)
#
# 8
# Q: What pittsburgh neighborhood is Dr. Tumblety’s Apothecary and Tasting Lounge located in?
# A: Squirrel Hill
#
# 8
# Q: What unique collection is housed in the Bayernof Museum in pittsburgh?
# A: The Andy Warhol Museum houses the largest collection of a single artist.
#
# 8
# Q: What is Pittsburgh's oldest vegan restaurant?
# A: Square Cafe
#
# 8
# Q: What abandoned state correctional facility is located at the end of one of Pittsburgh’s bike trails?
# A: Northern State Correctional Institution (NSCI)
#
# 8
# Q: "What is the name of the museum in Garfield that explores the relationship between culture, nature, and biotechnology?"
# A: The Center for PostNatural History
#
# 8
# Q: Where is the 17th International Exhibition of Botanical Art & Illustration held?
# A: Hunt Institute for Botanical Documentation, 5th Floor, Hunt Library
#
# 8
# Q: How many artists and countries are represented in the 17th International Exhibition of Botanical Art & Illustration?
# A: 43 artists from 19 countries
#
# 8
# Q: What medium is used for the artwork 'Arisaema ringens' by Marianne Hazlewood featured in the 17th International Exhibition of Botanical Art & Illustration?
# A: Watercolor
#
# 8
# Q: How many botanical artists are recorded in the Catalogue of the International Exhibition of Botanical Art & Illustration database?
# A: 43 artists
#
# 8
# Q: What anniversary does the 'Here to Stay: Celebrating 40 Years at the Architecture Archives' exhibition celebrate?
# A: 40 years
#
# 8
# Q: Who is the head paleontologist that guest-starred on Daniel Tiger’s Neighborhood?
# A: Matt Lamanna
#
# 8
# Q: How many specimens are displayed in Hillman Hall at the Carnegie Museum of Natural History
# A: 20,000+ specimens (approx.)
#
# 8
# Q: How many objects from ancient Egypt does the Carnegie Museum of Natural History have in its collection?
# A: Around 5,000 objects from ancient Egypt
#
# 8
# Q: How many objects are highlighted in The Stories We Keep: Conserving Objects from Ancient Egypt exhibit?
# A: More than 80 objects
#
# 8
# Q: When does The Stories We Keep: Conserving Objects from Ancient Egypt exhibit run until?
# A: Until March 9, 2025
#
# 8
# Q: Which Pittsburgh jazz club is located in the Strip District?
# A: CJs in the Strip District
#
# 8
# Q: Which jazz pianist from Pittsburgh is known for their contributions to the jazz scene?
# A: Ahmad Jamal
#
# 8
# Q: Who is a famous Pittsburgh-born jazz drummer mentioned in the 'jazz heaven' band?
# A: Ahmad Jamal
#
# 8
# Q: Which jazz composer from Pittsburgh is known for writing for the greats?
# A: Ahmad Jamal
#
# 8
# Q: What annual jazz festival takes place in downtown Pittsburgh every June?
# A: Pittsburgh JazzLive International Festival
#
# 8
# Q: How much did Andrew Carnegie donate to establish a technical institute in Pittsburgh in 1900?
# A: $1,000,000
#
# 8
# Q: "Who was the first student to receive a doctorate from Carnegie Tech, and in what year?"
# A: Mao Yisheng, 1919
#
# 8
# Q: What significant technological advancement arrived at Carnegie Tech in 1956?
# A: IBM computer
#
# 8
# Q: When did Carnegie Mellon celebrate the 50th anniversary of the Carnegie Tech-Mellon Institute merger?
# A: 2017
#
# 8
# Q: What major event in the mid-20th century marked a shift in gender inclusion at Carnegie Tech?
# A: Carnegie Tech did not have a major event in the mid-20th century specifically dealing with gender inclusion as it is now known as Carnegie Mellon University and the timeline provided does not mention any such event.
#
# 8
# Q: "What significant curriculum reform, launched in 1938, combined technical education with a broader understanding of society?"
# A: Carnegie Plan (
#
# 8
# Q: On what date is Mitchell Tenpenny performing in Pittsburgh?
# A: Oct 24, 2024.
#
# 8
# Q: Which hall is the Harry Potter and the Order of Phoenix Concert taking place?
# A: Heinz Hall
#
# 8
# Q: On what date is the Harry Potter and the Order of Phoenix Concert taking place?
# A: October 26, 2024 (7:00PM)
#
# 8
# Q: Where is the Lindenwood Lions vs Robert Morris Colonial's men's hockey match taking place?
# A: Clearview Arena (Formerly RMU Island Sports Center), Pittsburgh, Pennsylvania, US
#
# 8
# Q: When on November 2024 are Montreal Canadiens facing Pittsburgh Penguins?
# A: November 2
#
# 8
# Q: What time does the Montreal Canadiens vs Pittsburgh Penguins match start on November the 2nd?
# A: 7:00 pm - 10:00 pm (Nov 2, 2024)
#
# 8
# Q: Which theater is the Beauty and Beast being performed in November?
# A: Byham Theater
#
# 8
# Q: Where are Dallas Stars playing Pittsburgh Penguins ?
# A: 1001 Fifth Ave , Pittsburgh, PA 15219
#
# 8
# Q: When are Dallas Stars playing Pittsburgh Penguins
# A: Nov 11, 2024
#
# 8
# Q: Where is Matteo Bocelli performing?
# A: Carnegie of Homestead Music Hall, Pittsburgh, Pennsylvania, US
#
# 8
# Q: What dates in December is the Highmark Holiday Pops this year?
# A: Dec 13, 2024 - Dec 22, 2024
#
# 8
# Q: When is the Dandy Andy Warhol’s Queer History event?
# A: Oct 26, 2024
#
# 8
# Q: When is the Coffee + connect event in October?
# A: Oct 25, 2024 | 10:00 am - 11:00 am
#
# 8
# Q: Which venue is the Taekwondo 2024 Fall Nationals taking place?
# A: David L. Lawrence Convention Center
#
# 8
# Q: When is the Taekwondo 2024 Fall Nationals 2024?
# A: Oct 23, 2024 - Oct 26, 2024
#
# 8
# Q: When is Billie Eilish's concert in Pittsburgh?
# A: Oct 13, 2024 | 7:00 pm - 11:00 pm
#
# 8
# Q: When is Justin Timberlake performing in Pittsburgh?
# A: December 14, 2024 | 7:30 pm - 11:00 pm at 1001 Fifth Ave , Pittsburgh, PA 15219.
#
# 8
# Q: What time of the day does the Haunted Pittsburgh Ghost Tour take place?
# A: 7:00 pm - 9:00 pm
#
# 8
# Q: What is the venue for the Steelers Tailgate?
# A: Acrisure Stadium (North Shore)
#
# 8
# Q: Where is the Georgia Tech Yellow Jackets vs Panthers game taking place?
# A: Pittsburgh, Pennsylvania, US (Petersen Events Center)
#
# 8
# Q: When is the Georgia Tech Yellow Jackets vs Panthers game taking place?
# A: January 07, 2025, 1:00 PM (ET)
#
# 8
# Q: When is the Goose concert in Pittsburgh?
# A: BNY Mellon Grand Classics (Goose concert) is at 7:30pm on Friday or 2:30pm on Sunday.
#
# 8
# Q: What day of the week is the  Goose concert?
# A: The day of the week for the Goose concert is not provided in the contexts.
#
# 8
# Q: When are the Steelers playing the Chiefs?
# A: December 25, 1 p.m. (Regular Season)
#
# 8
# Q: Who is moderating December's Lit Friday?
# A: The moderator for December's Lit Friday is not specified in the given context.
#
# 8
# Q: Who is the director of Strauss and Puccini?
# A: Manfred Honeck
#
# 8
# Q: Where can i watch Strauss and Puccini?
# A: 600 Penn Ave, Pittsburgh, PA 15222
#
# 8
# Q: "At which venue is ""Kim Bond: We Are Not Alone"" being held?"
# A: 707 Penn Avenue, Pittsburgh, PA 15222
#
# 8
# Q: Who are the directors of MJ the musical?
# A: Multi Tony Award-winning directors, Christopher Wheeldon and Lyn Paras-Gravander
#
# 8
# Q: Which event is happening at the Benedum Center from November 19 to December 1?
# A: Opera Performance: Cavalleria Rusticana/Pagliacci, November 19 to December 1
#
# 8
# Q: When is Chris Knight performing in Pittsburgh?
# A: Sat., March 25, 2023 or Sun., April 2, 2023 (assuming the query is about a person named Chris Knight, but no specific individual was mentioned in the context)
#
# 8
# Q: Where is Chris Knight performing?
# A: Chris Knight's performance information was not found in the provided context.
#
# 8
# Q: Which bands are performing with Surfer Girl in Pittsburgh?
# A:
#
# 8
# Q: Where is the Surfer Girl concert taking place?
# A: Club Cafe, Dec. 8
#
# 8
# Q: Which game is scheduled at UPMC Cooper Fieldhouse at 1 pm on December 21st?
# A: No event is scheduled at UPMC Cooper Fieldhouse at 1 pm on December 21st, according to the provided contexts.
#
# 8
# Q: When are the Duquesne Dukes playing against the UC Irvine Anteaters?
# A: Answer: Date not specified in provided contexts.
#
# 8
# Q: When is the remaining Ducks vs. Penguins match in 2024?
# A: Oct 31, 2024
#
# 8
# Q: When is the Elvis Christmas show happening?
# A: December 10, 2024
#
# 8
# Q: What is the date of the Thanksgiving Dinner Cruise?
# A: Nov 28, 2024
#
# 8
# Q: When is Amy Sedaris’s comedy show?
# A: Nov 14, 2024 (7:30
#
# 8
# Q: "How long is the ""An Evening with Amy Sedaris"" show?"
# A: Approximately 2 hours (from 7:30 pm - 9:30 pm)
#
# 8
# Q: What day of the week is the Steelers vs. Chiefs game taking place?
# A: Sunday
#
# 8
# Q: Who was the philanthropist who facilitated the opening of Pittsburgh's zoo and aquarium through his donations?
# A: Andrew Carnegie
#
# 8
# Q: Henry W. Phipps donated which conservatory to the city of Pittsburgh?
# A:  Phipps Conservatory & Botanical Gardens
#
# 8
# Q: What is the name of America's only independent bird sanctuary?
# A: Pittsburgh Center for the Arts (not a bird sanctuary)  For the second query, there is no specific mention of a bird sanctuary in the contexts provided. The closest is the Carnegie Museum of Natural History, but it is a museum, not a sanctuary. If this is the question, the answer would be "Carnegie Museum of Natural History".
#
# 8
# Q: How many Carnegie Museums are there in Pittsburgh?
# A: 4 Carnegie Museums in Pittsburgh
#
# 8
# Q: What is the largest musuem dedicated to a single artist?
# A: The Andy Warhol Museum.
#
# 8
# Q: How far is the BayernHof Music Museum from downtown Pittsburgh?
# A: Approximately 6.5 miles from downtown Pittsburgh. (Google Maps estimate)
#
# 8
# Q: Which science center in Pittsburgh has interactive technology and science exhibits?
# A: Carnegie Science Center
#
# 8
# Q: Where is the Smithsonian affilliated regional history museum in Pittsbugh?
# A: Heinz History Center, Strip District, Pittsburgh
#
# 8
# Q: In what year were both the museum for fine arts and natural history founded?
# A: 1895
#
# 8
# Q: Where does the Pittsburgh Symphony Orchestra perform?
# A: Heinz Hall
#
# 8
# Q: Carnegie Museum of Natural History has more than how many objects from Ancient Egypt?
# A: 4000 (4,000-year-old Dahshur boat, one of only four in the world)
#
# 8
# Q: How many original fossils are on display in the Dinosaurs in their Time exhibit at Carnegie Museum of Natural History?
# A: About 75 percent of the objects on display in Dinosaurs in Their Time are original fossils, not casts.
#
# 8
# Q: Who is the third base coach for the Pittsburgh Pirates?
# A: Drasdale Johnson (as of 2021)
#
# 8
# Q: How many minutes after game time does the Pirates Main Ticket Office close on gameday Saturday and Sundays?
# A: Not provided. The context does
#
# 8
# Q: When did PNC park open?
# A: 2001
#
# 8
# Q: Who is the quarterbacks coach for the Pittsburgh Steelers?
# A: Not provided in contexts.
#
# 8
# Q: In which week are the Pittsburgh Steelers playing the New York Giants this season?
# A: Week 7
#
# 8
# Q: Where is the Pittsburgh Steelers Hall of Honor dinner this year?
# A: The location for the Pittsburgh Steelers Hall of Honor dinner hasn't been specifically mentioned in the provided contexts. For the most current and accurate information, it is recommended to visit the official Steelers website or contact the team directly.
#
# 8
# Q: What position does Sydney Crosby play?
# A: Forward Sidney Crosby plays as a Center
#
# 8
# Q: When are the Pittsburgh Penguins playing Edmonton in October?
# A: October date unavailable. Please check the schedule at Pittsburgh Penguins official website.
#
# 8
# Q: What is the name of the Pittsburgh Steelers' rally towel?
# A: Terrible Towel
#
# 8
# Q: What was the Pirates' first home called?
# A: Homewood
#
# 8
# Q: Who holds the Pirates' franchise record for the most bases
# A: Honus Wagner
#
# 8
# Q: In which year did the Pirates achive 100 wins for the first time?
# A: 1935
#
# 8
# Q: Who do the Pirates play for their 2025 season opener on March 27?
# A: No 2025 schedule is provided in the contexts.
#
# 8
# Q: Apart from the MLB wide retired number 42 how many Pirates jerseys have been retired?
# A: 3 Pirates jerseys have been retired.
#
# 8
# Q: Which is the only team to have won a World Series with a Game 7 walk-off home run?
# A: Pittsburgh Pirates (1909)
#
# 8
# Q: How many consecutive seasons did the Pirates post a losing record to set a record?
# A: 20
#
# 8
# Q: Who are the Steelers playing in the last week of the season?
# A: Cincinnati Bengals (Week 18, January)
#
# 8
# Q: When is the Steelers' spooktacular event?
# A: Steelers' Spooktacular event date is not provided in the contexts.
#
# 8
# Q: What is the name of the Pittsburgh Steelers mascot?
# A: Steely McBeam
#
# 8
# Q: Which is the oldest franchise in the American Football Conference?
# A: The Pittsburgh Americans of the second American Football League is the oldest franchise in the American Football Conference (1937).
#
# 8
# Q: How many Super Bowls have the Steelers won?
# A: The Steelers have won 6 Super Bowls.
#
# 8
# Q: How many primary rivals do the Steelers have?
# A:
#
# 8
# Q: What was the name of the Steelers cheerleading squad?
# A: Steelers Dance Team
#
# 8
# Q: Who won the first NFL MVP from the Steelers?
# A: Terry Bradshaw, 1978
#
# 8
# Q: Against which team this season are the Penguins giving out rally towels?
# A: No information provided in the contexts indicates which team the Penguins are giving out rally towels against in the current season.
#
# 8
# Q: Which is the first team to win back to back Stanley Cups in the salary cap era of the NHL?
# A: Pittsburgh Penguins (2016-2017)
#
# 8
# Q: Who was awarded the Foster Hewitt Memorial Award by the NHL Hall of Fame in 2001?
# A: Mike Lange
#
# 8
# Q: Who has scored the most points in Penguins Franchise history?
# A: Sidney Crosby (1426 in total points)
#
# 8
# Q: When was Picklesburgh 2024?
# A: July 2024
#
# 8
# Q: On which plaza was Picklesburgh 2024 held?
# A: On the Andy Warhol Bridge.
#
# 8
# Q: Name the new competition starting from Picklesburgh 2024.
# A: PGH Roll Challenge
#
# 8
# Q: On which category does Picklesburgh rank as the number one?
# A: #1 Specialty Food Festival (USA Today readers' choice for 3 consecutive years)
#
# 8
# Q: On which avenue does Pittsburgh's Little Italy Days take place in 2024?
# A: Bloomfield
#
# 8
# Q: Two free parking garages are available in the Little Italy Days. One is the parking garage at Liberty & Aspen. What is the other one?
# A: Sixth & Penn garage (across from Heinz Hall)
#
# 8
# Q: "In Little Italy Days 2024, what entertainment was scheduled from 6 p.m. onThursday, Aug. 15?"
# A: Music, food, games
#
# 8
# Q: When did the Miss Little Italy Pageant 2024 start?
# A: July 28, 2024
#
# 8
# Q: How many hours earlier was the gold ticket holder able to enter the Pittsburgh Taco Festival 2024?
# A: Gold ticket holder may enter the Pittsburgh Taco Festival 2024 2 hours earlier.
#
# 8
# Q: Did Yelp sponsor the Pittsburgh Taco Festival 2024?
# A: Yes, Yelp is a sponsor of the Pittsburgh Taco Festival 2024.
#
# 8
# Q: Which email address can you contact about the Pittsburgh Taco Festival?
# A: [PR@pghtacofest.com](mailto:PR@pghtacofest.com)
#
# 8
# Q: Where was the Pittsburgh Taco Festival held?
# A: The Stacks at 3 Crossings, 2875 Railroad Street, Pittsburgh, PA 15222
#
# 8
# Q: "What is the event held in Latrobe, PA in August?"
# A: Iron City Brewing Company relocation (August)
#
# 8
# Q: Which agricultural company sponsors the Great American Banana Split Celebration?
# A: Unknown, not provided in the contexts.
#
# 8
# Q: Can you enjoy a bingo game in the Great American Banana Split Celebration in 2024?
# A: No, Bingo game is not mentioned in the context provided for the Great American Banana Split Celebration in 2024.
#
# 8
# Q: What distance do you run in one of the events in the Great American Banana Split Celebration?
# A: 5k (5 kilometers)
#
# 8
# Q: When does the soul food festival end each day in 2024?
# A: 10 p.m. daily (August 30 - September 1, 2024)
#
# 8
# Q: "In 2024, the soul food festival is held on Market Square and Boulevard of the Allies between what and what streets?"
# A: Stanwix and Wood streets
#
# 8
# Q: "In Soul Food Festival 2024, who plays in the main stage from 6 pm on Aug. 30?"
# A: Dr. James Johnson & Pittsburgh Jazz Allstars on Aug. 30 Main Stage.
#
# 8
# Q: "On Sunday during the Soul Food Festival 2024, who plays on the DJ stage from 2 pm?"
# A: DJ Tee Jay
#
# 8
# Q: "In which place is Vegetarian and Vegan Food Festivals being held on Sept. 29, 2024?"
# A: Velum Fermentation
#
# 8
# Q: More than how many businesses participated Lawrenceville Cookie Tour 2024?
# A: More than 30 businesses
#
# 8
# Q: In which seasons can you join Pittsburgh Restaurant Week?
# A: Pittsburgh Restaurant Week takes place during a week-long celebration. The specific dates vary each year. (No season reference as it's a week-long event happening throughout the year)
#
# 8
# Q: "In Picklesburgh 2024, where can you find Millie's Homemade Ice Cream?"
# A: Map 25 Millie’s Homemade Ice Cream
#
# 8
# Q: "In Picklesburgh 2024, where can you find Cute as a Dumpling?"
# A: Section 133, Picklesburgh 2024.
#
# 8
# Q: "There were three Gherkin Games in Picklesburgh 2024: Pickle Juice Drinking, Pickle Eating, and what?"
# A: Pickle
#
# 8
# Q: Can you join a contest in Picklesburgh 2024 if you are 16?
# A: "16-year-olds can participate in Picklesburgh contests, details TBA."
#
# 8
# Q: For how many consecutive years is Picklesburgh voted as the number 1 food festival in America?
# A: 3
#
# 8
# Q: Who founded the original Pittsburgh Taco Festival?
# A: Craig McCloud
#
# 8
# Q: Can you get any refund for 2024 Pittsburgh Taco Festival tickets?
# A: Refunds will not be issued for 2024 Pittsburgh Taco Festival tickets.
#
# 8
# Q: Can you go to 2024 Pittsburgh Taco Festival with your pets?
# A: No, pets are not allowed at the 2024 Pittsburgh Taco Festival.
#
# 8
# Q: Can you use credit cards at all vendors in 2024 Pittsburgh Taco Festival?
# A: Not specified in the provided contexts. Check the specific vendor details for credit card acceptance information.
#
# 8
# Q: When did the early access of summer 2024 Pittsburgh Restaurant Week start?
# A: August 9, 2024
#
# 8
# Q: In which year did Little Italy Days start?
# A: 2002
#
# 8
# Q: Do you need a ticket to join Little Italy Days 2024?
# A: No,
#
# 8
# Q: "If a high school student participates 5K Banana Run 2024, which age bracket will they be in?"
# A: High school age bracket
#
# 8
# Q: Who performed from 1pm to 2pm at Dollar Bank Stage in Banana Split Celebration 2024?
# A: Unspecified performer at Dollar Bank Stage, Banana Split Celebration 2024.
#
# 8
# Q: What is the name of the kids activity area in Picklesburgh 2024?
# A: Li'l Gherkins KidsPlay Area.
#
# 8
# Q: What is the size of Dill Pickle Flavored Peanuts at 306 Forbes Boutique in Picklesburgh 2024?
# A: 10 ounce cans
#
# 8
# Q: What is the base alchol of Pickle Sour at Barcadia in Picklesburgh 2024?
# A: Gin
#
# 8
# Q: What type of specialized nights does the Carnegie Museum of Natural History offer for adults?
# A: Exhibition previews, exclusive tours, lectures. (Refer to the context provided under "What member events are offered?")
#
# 8
# Q: "Which famous paleontologist from Carnegie Museum of Natural History guest starred on ""Daniel Tiger’s Neighborhood""?"
# A: Matt Lamanna
#
# 8
# Q: What is the name of the predator dinosaur that was discovered in Patagonia by the Carnegie Museum of Natural History team?
# A: Megar
#
# 8
# Q: What is the special event designed for children ages 5-12 at Carnegie Museum of Natural History called?
# A: Dino Days
#
# 8
# Q: What unique feature does the Cafe Carnegie offer alongside regular dining options?
# A: Online store with 10% member discount
#
# 8
# Q: "What can visitors do in the new exhibit ""The Stories We Keep: Conserving Objects from Ancient Egypt"" at the Carnegie Museum of Natural History?"
# A: Visitors can interact with ancient Egyptian objects, observe conservation work, ask questions, and attempt conservation techniques with microscopes and black lights at the visible lab in The Stories We Keep exhibit.
#
# 8
# Q: "How many objects from Ancient Egypt does the Carnegie Museum of Natural History possess, as highlighted in their exhibit?"
# A: Over 80 objects
#
# 8
# Q: What exclusive gallery in the Carnegie Museum of Natural History features a large collection of gems and jewelry?
# A: Hillman Hall of Minerals and Gems
#
# 8
# Q: Who does the Carnegie Museum of Natural History encourage to 'learn even more' during Super Science Saturdays with hands-on activities and craft stations?
# A: Children and
#
# 8
# Q: "Until what date is ""The Stories We Keep: Conserving Objects from Ancient Egypt"" exhibit scheduled to continue?"
# A: March 9, 2025
#
# 8
# Q: What types of sightseeing options are available in Pittsburgh based on the mode of transportation?
# A: Walking: Frick Pittsburgh, Shadyside neighborhood shops, Moonlit Burgers & Pizza Milano (near stadium), Heinz Hall Public Transit: Pittsburgh's Port Authority bus and light rail network Boat: Duquesne inclusion kayaking, Gateway Clippers Bike: Bike Pittsburgh bike maps, city-wide bike share system (Healthy Ride) Trolley: Duquesne Incline, PPG Place indoor t
#
# 8
# Q: What kind of guided tour is offered for free in Pittsburgh?
# A: Car and Carriage Museum Guided Tour (Free)
#
# 8
# Q: Which riverboat options are mentioned for sightseeing in Pittsburgh?
# A: Gateway Clipper, Riverboat Shuttles.
#
# 8
# Q: What alternative types of tours are available in Pittsburgh besides walking and boat tours?
# A: Kayak, Bike (or Walk!), 'Burgh Bits and Bites Food Tour
#
# 8
# Q: What can one explore with the free walking tours in Pittsburgh?
# A: Pittsburgh'
#
# 8
# Q: What feature does Rivers of Steel Riverboat share with Gateway Clipper in Pittsburgh?
# A: Both Rivers of Steel Riverboat and Gateway Clipper offer sightseeing tours in Pittsburgh.
#
# 8
# Q: What is one of the prominent neighborhood features mentioned for exploring in Pittsburgh?
# A: The Homewood Arts Walk
#
# 8
# Q: What geographic feature does Pittsburgh uniquely offer for outdoor activities involving water?
# A: Three Rivers (Allegheny, Monongahela, Ohio)
#
# 8
# Q: What type of tours can be enjoyed along Pittsburgh's riverfront trails?
# A: Group Heinz Hall tours, guided hikes, kayak rentals, Pittsburgh riverfront trail tours with USS Requin.
#
# 8
# Q: On what trail can you travel from Pittsburgh to Washington D.C.?
# A: Great Allegheny Passage and C&O Canal Towpath (joined in Cumberland, MD)
#
# 8
# Q: "Apart from golf, what other water sports can be enjoyed in Pittsburgh?"
# A: No specific water sport is mentioned to be enjoyed in Pittsburgh. However, the Martian farm at Carnegie Science Center showcases a hydroponic system, suggesting the possibility of indoor gardening or small-scale urban farming.
#
# 8
# Q: What is the starting point of the Great Allegheny Passage in Pittsburgh?
# A: Point State Park, Downtown Pittsburgh
#
# 8
# Q: Where does the Montour Trail connect from and to?
# A: From Coraopolis, PA to Clairton, PA. The Montour Trail connects Pittsburgh International Airport to the GAP Trail.
#
# 8
# Q: What app is recommended to download before visiting state parks and forests near Pittsburgh?
# A: Official Guide for Pennsylvania State Parks & Forests App (iOS and Android)
#
# 8
# Q: For what type of sightseeing is Pittsburgh recognized?
# A: Pittsburgh is recognized for River Cruises & Boat Tours.
#
# 8
# Q: How can one explore Pittsburgh trails?
# A: Visit [Visit Pittsburgh](http://visitpittsburgh.com/) for information on Pittsburgh trails.
#
# 8
# Q: What type of rentals are available along the riverfront trails in Pittsburgh?
# A: Bicycle rentals
#
# 8
# Q: What historical nickname was given to Pittsburgh reflecting its early significance?
# A: Steel City
#
# 8
# Q: What type of arts and culture events are suggested by the Visit Pittsburgh site to explore in the city?
# A: EQT Children's Theater Festival, D Bank Three Rivers Arts Festival, Picklesburgh, Pittsburgh Symphony Orchestra, Pittsburgh Cultural District, The Mattress Factory, Andy Warhol Museum, Carnegie Science Center, Pittsburgh sports events, I Made it Market, City of Asylum, St. Anthony's Chapel.
#
# 8
# Q: What specific museum is emphasized in promoting insight on a famous artist in Pittsburgh?
# A: Andy Warhol Museum
#
# 8
# Q: What guide is suggested for tourists who want a comprehensive understanding of Pittsburgh's offerings?
# A: Pittsburgh Bike Maps by BikePGH or the guide to Market Square.
#
# 8
# Q: "For those interested in Pittsburgh's architectural developments, what transition is noted?"
# A: America's transition from carriage to car.
#
# 8
# Q: Which musical heritage of Pittsburgh is noted to have information available in the section on related blogs?
# A: Pittsburgh blogs have information about the Post-Gazette's #LOVEPGH.
#
# 8
# Q: What type of promoting strategy is suggested for event planners looking to host meetings in Pittsburgh?
# A: Offer reading materials, videos, and interactive activities to engage audiences. Use social media platforms to maintain a connection with community.
#
# 8
# Q: What is Bicycle Heaven recognized as worldwide?
# A: Largest transportation museum in the world dedicated to bicycles.
#
# 8
# Q: Where can one find free entertainment in downtown Pittsburgh on the first or third Monday from February to October?
# A: Old Allegheny County Jail Museum
#
# 8
# Q: What type of tours does the Pittsburgh History & Landmarks Foundation offer for free?
# A: Free tours: Not specified in the contexts provided. Please refer to their website for the most accurate information.
#
# 8
# Q: "When visiting The Allegheny Observatory, what is included in the free evening tour?"
# A: A short presentation
#
# 8
# Q: Which Pittsburgh museum focuses on the gilded age and offers free admissions?
# A: The Frick Art & Historical Center
#
# 8
# Q: What is housed in the University of Pittsburgh's Cathedral of Learning building?
# A: Nationality Rooms and classrooms
#
# 8
# Q: What unique collection can be seen at St. Anthony's Chapel?
# A: St. Anthony's Chapel has a unique collection of over 5,000 Catholic relics.
#
# 8
# Q: Which Pittsburgh event offers a chance to see local parks transformed into movie theaters?
# A: Outdoor Movie Nights in Pittsburgh's Parks
#
# 8
# Q: Where in Pittsburgh can you enjoy free professional jazz performances weekly?
# A: Liberty Magic Theatre (JazzLive)
#
# 8
# Q: Who does Josh Gibson Heritage Park honor besides Josh Gibson?
# A: Satchel Paige and Cool Papa Bell, along
#
# 8
# Q: What architectural feature is Troy Hill Art Houses known for incorporating into a house?
# A: Lighthouse built within a house
#
# 8
# Q: Which gallery on Wood Street hosts exhibitions by multi-disciplinary media artists from around the globe?
# A: Wood Street Galleries
#
# 8
# Q: What are visitors allowed to do for free within the Golden Triangle using Pittsburgh's subway system?
# A: Visitors can use Pittsburgh's subway system (Port Authority) to explore the Golden Triangle for free by using the bike friendly transit options.
#
# 8
# Q: What is the architectural significance of Pittsburgh's Fort Pitt Block House?
# A: Oldest architectural landmark in Pittsburgh, built in 1764.
#
# 8
# Q: On what day is street parking free in downtown Pittsburgh?
# A: Sundays and holidays
#
# 8
# Q: What language do the Seneca people speak?
# A: Seneca language (Athabaskan)
#
# 8
# Q: What were the names of the two founders of the city of Pittsburgh’s Renaissance projects mentioned in the text?
# A: Richard K. Mellon and John P. Robin
#
# 8
# Q: What two entities clashed for control of Pittsburgh area in the 1750s?
# A: France and Great Britain
#
# 8
# Q: What is the Pittsburgh Academy known as today?
# A: University of Pittsburgh
#
# 8
# Q: Which Pittsburgh industry benefited from the American Civil War?
# A: Steel industry
#
# 8
# Q: In what year did the Fort Pitt Blockhouse become a United States fort?
# A: 1777
#
# 8
# Q: "What is the name of the oldest structure in Pittsburgh, dating back to 1764?"
# A: Fort Pitt Block House
#
# 8
# Q: What natural disaster hit Pittsburgh in March 1936?
# A: No natural disaster happened in Pittsburgh in March 1936 (According to the provided contexts)
#
# 8
# Q: Who was the key political figure responsible for enforcing the Smoke Control Ordinance in Pittsburgh?
# A: Postwar David Lawrence
#
# 8
# Q: When did Pittsburgh first begin producing steel?
# A: 1875
#
# 8
# Q: What major structural feature is Pittsburgh known for?
# A: The City of Bridges
#
# 8
# Q: Which university is mentioned as evolving in response to the needs of heavy industries in the mid-20th century Pittsburgh?
# A: Carnegie Mellon University.
#
# 8
# Q: What key event in 1946 further changed the industrial base of Pittsburgh?
# A: 1946: Steelworkers' Strike
#
# 8
# Q: When did the Whiskey Rebellion take place?
# A: The Whiskey Rebellion took place in 1794.
#
# 8
# Q: What major social reform event is associated with Pittsburgh in 1877?
# A: The Pittsburgh Survey (1907-1908)
#
# 8
# Q: Who were some of the new immigrants that arrived in Pittsburgh between 1870 and 1920?
# A: Italians, Poles, Russians, Balkans, Austro-Hungarian Empire.
#
# 8
# Q: What catastrophic workplace event occurred in Pittsburgh in 1892 involving the Carnegie Steel Company?
# A: Homestead Steel Strike
#
# 8
# Q: Which notable historical baseball stadium was mentioned as being part of the cultural scene of Pittsburgh?
# A: Pittsburgh Crawfords' Home Field (Hill District)
#
# 8
# Q: What term synonymous with illegal drinking establishments during Prohibition was purportedly coined in nearby McKeesport?
# A: Speakeasy
#
# 8
# Q: What is the estimated time period Native Americans started inhabiting the region around Pittsburgh according to archaeological evidence?
# A: 19,000 years ago according to archaeological evidence at Meadowcroft Rockshelter.
#
# 8
# Q: What type of facility is the Inglis Innovation Center planning to include in its Bellevue location?
# A: Institutional Service
#
# 8
# Q: What is the focus of the entrepreneurship program at the Inglis Innovation Center?
# A: Entrepreneurship development
#
# 8
# Q: Which new sports team is mentioned as completing the pipeline from the Riverhounds Academy to professional women's soccer?
# A: USL W League team of Riverhounds ownership group
#
# 8
# Q: What inspired the recreation of the Zucchini Casserole recipe?
# A: The Picklesburgh festival inspired the recreation of the Zucchini Casserole recipe.
#
# 8
# Q: Which organization's groundbreaking is significant for offering a suite of services including healthcare?
# A: Carnegie Museum of Natural History
#
# 8
# Q: What kind of shows combined dance and theater at the Peirce Studio event?
# A: Dance and theater shows at the Peirce Studio event are combined live theater and science education.
#
# 8
# Q: What did Amanda Waltz report about Pittsburgh's Mixtape events inspired by?
# A: Pittsburgh's Mixtape events were inspired by local music and cultural heritage.
#
# 8
# Q: Which TV genre does Jessie Sage discuss in relation to relationship insights?
# A: Entertainment, performing arts, or comedy routines
#
# 8
# Q: What are Pittsburgh City Paper's staff suggesting to do between October 16-23?
# A: Pittsburgh City Paper's staff is suggesting to do the following between October 16-23: 1. The top events: Oct. 18-24 2. Cool Picks - Events not specified 3. What to do this week: Oct. 13-15 (mentioned in a later week) 4. GO! List 3-25-22 (mentioned in a different week)
#
# 8
# Q: What organization is monitoring neo-Nazi activities in Pittsburgh?
# A: Voices Against Violence
#
# 8
# Q: What does the Wilkinsburg’s Home Rule charter aim to increase for the borough’s residents?
# A: Increase City's capacity to compete for grants and improve the efficiency and impact of programs.
#
# 8
# Q: What role does the Pennsylvania treasurer play in state government?
# A: The Pennsylvania treasurer does not play a specific role in state government as mentioned in the context. The role of the treasurer that is mentioned is in relation to Carnegie Fine Arts and Museum Collection Fund, where the treasurer was Andrew W. Frick.
#
# 8
# Q: What was one focus of Eugene DePasquale's campaign for Attorney General?
# A: One focus of Eugene DePasquale's campaign for Attorney General was fighting public corruption and protecting consumers.
#
# 8
# Q: Which show is scheduled for multiple performances at The Lamp Theatre?
# A: Evil Dead The Musical
#
# 8
# Q: What significant event is taking place on October 25?
# A: Entertainment event "Miguel Muñoz in What is Magic for You?" happening in Pittsburgh on October 25, 2024.
#
# 8
# Q: What year did Stacy Rounds recreate the Zucchini Casserole recipe from the QED Cooks collection?
# A: 2020 (March 6)
#
# 8
# Q: What city does PA district 12 encompass?
# A: Pittsburgh
#
# 8
# Q: What areas does PA district 17 cover?
# A: Pittsburgh City
#
# 8
# Q: What is the role of Pittsburgh in the history of the National Football League?
# A: Pittsburgh played a significant role in the History of the National Football League, with the Pittsburgh Pirates being one of the inaugural teams and winners of the first National Football League's championship in 1929. Additionally, the Pittsburgh Steelers have won several Super Bowls and multiple Hall of Fame Inductees.
#
# 8
# Q: What title related to sports cities did Pittsburgh win in 2009 according to Sporting News?
# A: 2009 "Best Sports City" by Sports Illustrated, according to the given contexts.
#
# 8
# Q: Which university in Pittsburgh is noted for its medical and health-related sciences?
# A: University of Pittsburgh Medical Center (UPMC)
#
# 8
# Q: What significant award has the Pittsburgh Symphony Orchestra received?
# A: Best Orchestral Performance (2018)
#
# 8
# Q: Which Pittsburgh-based medical institute has been a pioneer in organ transplants?
# A: UPMC
#
# 8
# Q: What global event did Pittsburgh host in September 2009?
# A: G20 Summit (September 2009).
#
# 8
# Q: What is the historical significance of the Pittsburgh area in terms of industrial manufacturing during World War II?
# A: Pittsburgh'
#
# 8
# Q: How does Pittsburgh's public transportation rank in size within the United States?
# A: Pittsburgh's public transportation (Port Authority's buses and light rail system) ranks within the size of public transit systems in the U.S.
#
# 8
# Q: What is one major economic transition that Pittsburgh has undergone from the late 20th century to the 21st century?
# A: Steel industry decline and shift towards technology, healthcare, and education.
#
# 8
# Q: "In what sector is Pittsburgh considered to continue having a global impact, as evidenced by contributions to projects like the Boeing 787 Dreamliner?"
# A: Technology
#
# 8
# Q: What accolade was Pittsburgh given by Metropolis magazine in 2015?
# A: 2015 - Pittsburgh was named "Best City of the Future" by Metropolis magazine.
#
# 8
# Q: Which Pittsburgh museum is dedicated to an iconic artist and features extensive collections of his work?
# A: The Andy Warhol Museum
#
# 8
# Q: Which Pittsburgh sports team plays professional soccer and what is their home stadium?
# A: Pittsburgh Riverhounds. Consol Energy Center.
#
# 8
# Q: What nickname has been attributed to Pittsburgh reflecting its industrial past?
# A: Steel City
#
# 8
# Q: Which river in Pittsburgh is known for connecting to the Great Allegheny Passage trail system?
# A: Allegheny
#
# 8
# Q: In what year did the University of Pittsburgh host the first public cross-species marrow transplant?
# A: 1992
#
# 8
# Q: What is the name of the historic area in Pittsburgh that was key during the French and Indian War?
# A: Point State Park
#
# 8
# Q: What prestigious health-related institution in Pittsburgh is known for groundbreaking medical research and care?
# A: Allegheny Health Network / UPMC
#
# 8
# Q: Which annual Pittsburgh cultural event celebrates the city's ethnic diversity through its culinary tradition?
# A: Pittsburgh Irish Festival
#
# 8
# Q: What is the name of the jazz series held by Manchester Craftsmen's Guild in Pittsburgh?
# A: MCG Jazz Series (in Pittsburgh)
#
# 8
# Q: "In which neighborhood of Pittsburgh is CJs, a venue noted for jazz music, located?"
# A: Point Breeze (East End)
#
# 8
# Q: During which month is the annual Pittsburgh JazzLive International Festival held?
# A: June
#
# 8
# Q: In what part of Pittsburgh does the Pittsburgh JazzLive International Festival take place?
# A: Downtown Pittsburgh
#
# 8
# Q: Which type of musical instrument did Ray Brown play in the Pittsburgh jazz scene?
# A: Bass
#
# 8
# Q: "Which famous jazz keyboard player associated with Pittsburgh was known as ""Fatha""?"
# A: Art Tatum
#
# 8
# Q: What is the name of the jazz group led by Roger Humphries?
# A: The Jazz group led by Roger Humphries is F3ralcat.
#
# 8
# Q: Which Pittsburgh jazz musician is renowned for his contributions to both the drums and vocals?
# A: Jerry Betters (drums/vocals)
#
# 8
# Q: Can you name a jazz festival that is specifically mentioned as occurring in Pittsburgh?
# A: JazzLive International Pittsburgh Festival
#
# 8
# Q: What jazz ensemble includes George Benson and Joe Negri as guitar players?
# A: George Benson and Joe Negri Jazz Ensemble.
#
# 8
# Q: Who is the artist responsible for writing the content about the current jazz performers in Pittsburgh?
# A: Not specified in the provided contexts.
#
# 8
# Q: Which museum in Pittsburgh features exhibits related to the Underground Railroad and Mister Rogers?
# A: Heinz History Center
#
# 8
# Q: Which museum in Pittsburgh allows visitors to experience interactive simulations of lunar missions?
# A: Moonshot Museum
#
# 8
# Q: What type of artworks can one explore at The Andy Warhol Museum in Pittsburgh?
# A: Pop Art, Films, Classical Art, Modern Art, and Archival Materials
#
# 8
# Q: What is one of the activities that can be enjoyed at the Mattress Factory museum?
# A: Experience immersive art installations
#
# 8
# Q: Which museum in Pittsburgh specializes in materials related to bicycles and is noted as the world's largest bike museum and store?
# A: Bicycle Heaven Museum (largest bike museum and store in the world)
#
# 8
# Q: What specific historic event does the Fort Pitt Museum in Pittsburgh focus on illustrating?
# A: The Fort Pitt Museum in Pittsburgh focuses on illustrating the role of Western Pennsylvania during the French & Indian War, the American Revolution, and the birth of Pittsburgh.
#
# 8
# Q: "At the Children's Museum of Pittsburgh, what sort of play area is mentioned as encouraging creativity among visitors?"
# A: Waterplay area and "Makeshop".
#
# 8
# Q: Which museum in Pittsburgh is recognized for displaying one-of-a-kind specimens and gems relevant to dinosaur aficionados and geology buffs?
# ...
#
# 8
# Q: What type of content does pittsburghpenguins.com include aside from the team roster?
# A: Game scores, news, videos, game schedules, merchandise information, ticket purchases.
#
# 8
# Q: Where is the Hall of Honor Induction Ceremony held?
# A: Acrisure Stadium
#
# 8
# Q: Who are the presenting partners for the Hall of Honor Dinner Ceremony?
# A: Not provided in the contexts.
#
# 8
# Q: What is the purpose of the ticket proceeds from the Hall of Honor Dinner?
# A: Funds raised at the Hall of Honor Dinner go to support the Pittsburgh Steelers Alumni Charitable Foundation.
#
# 8
# Q: Who are some of the members of the Hall of Honor Class of 2024?
# A: No information provided about Hall of Honor Class of 2024.
#
# 8
# Q: When is the Hall of Honor Induction Ceremony scheduled for 2024?
# A: Induction Ceremony schedule for 2024 is not provided in the contexts.
#
# 8
# Q: What is the date and opponent for the Pittsburgh Steelers' first regular season game in 2024?
# A: September 22, 2024 (Los Angeles Chargers)
#
# 8
# Q: "On what network is the Pittsburgh Steelers vs. New York Jets game on October 20, 2024, being broadcast?"
# A: NBC
#
# 8
# Q: "What is the result of Pittsburgh Steelers' game against Indianapolis Colts on September 29, 2024?"
# A: 1 p.m. (Tentative)
#
# 8
# Q: What type of bag policy does Acrisure Stadium enforce?
# A: All Clear On Game Day policy with clear bags only, no backpacks or large tote bags exceeding 4.5” by 6.5”. Check security guidelines for full details.
#
# 8
# Q: Which team did Pittsburgh Steelers face in Week 16 of the year 2024?
# A: The query does not provide enough context to answer, as it refers to a future event (2024) and there is no information about the Pittsburgh Steelers' schedule for that year in the provided contexts.
#
# 8
# Q: "What platform will broadcast the Steelers vs. Chiefs game on December 25, 2024?"
# A: NBC
#
# 8
# Q: What date is the 2024 bye week for the Pittsburgh Steelers?
# A: I couldn't find specific details about the Pittsburgh Steelers' 2024 bye week in the provided contexts. For the most accurate information, please refer to updates from official NFL sources.
#
# 8
# Q: Who is the President of the Pittsburgh Steelers?
# A: The question is about the Pittsburgh Steelers, which is a football team, not an orchestra. The query asks for the President of the team, but the context provided does not have any information about the Pittsburgh Steelers. I'm unable to answer this query based on the provided contexts.
#
# 8
# Q: Who is the Head Coach of the Pittsburgh Steelers?
# A: Mike Tomlin
#
# 8
# Q: Who is the General Manager of the Pittsburgh Steelers?
# A: The query is asking for the General Manager of the Pittsburgh Steelers, which is not provided in the contexts. Hence, I cannot answer this query with the given information.
#
# 8
# Q: What is the role of Teryl Austin in the Pittsburgh Steelers coaching staff?
# A: Teryl Austin is a coach on the Pittsburgh Steelers staff.
#
# 8
# Q: Who is responsible for the Pittsburgh Steelers' strength and conditioning?
# A: Igor Burdusel, Head Strength and Conditioning Coach.
#
# 8
# Q: Who is the Vice President of Ticket Operations for the Pittsburgh Steelers?
# A: Not provided in the contexts.
#
# 8
# Q: Who is the Senior Director of Community Relations for the Pittsburgh Steelers?
# A: Teryl Austin
#
# 8
# Q: What is the address of PNC Park?
# A: PNC Park, 115 Federal St, Pittsburgh, PA 15212, USA
#
# 8
# Q: What is one of the main contact numbers for PNC Park?
# A: 412-321-PIRATES (747283) (General Information for PNC Park) 412-325-BEER (2337) (Craft Beer Information at PNC Park)
#
# 8
# Q: In what year did PNC Park open?
# A: 2001
#
# 8
# Q: What type of seating map is available for PNC Park?
# A: Best Available Seating, Select Your Own Seat
#
# 8
# Q: "What river is near PNC Park, enhancing its scenic views?"
# A: The Allegheny River is near PNC Park.
#
# 8
# Q: What are PNC Park's ticket office hours on weekdays?
# A: Monday to Friday: 10:00 AM – 6:00 PM Weekdays with performances: 10:00 AM - 30 minutes after scheduled showtime.
#
# 8
# Q: What MLB division do the Pittsburgh Pirates belong to?
# A: National League (NL)
#
# 8
# Q: Who is the Manager of the Pittsburgh Pirates?
# A: Dusty Baker (as of 2023)
#
# 8
# Q: Who is the Bench Coach for the Pittsburgh Pirates?
# A: Not provided in the contexts.
#
# 8
# Q: Who serves as the Pitching Coach for the Pittsburgh Pirates?
# A: Unknown (as of the provided context)
#
# 8
# Q: What is the role of Christian Marrero in the Pittsburgh Pirates coaching staff?
# A: Christian Marrero is a
#
# 8
# Q: What position does Tarrik Brock coach for the Pittsburgh Pirates?
# A: Tarrik Brock does not coach for the Pittsburgh Pirates. He is not currently affiliated with the Pirates as a coach.
#
# 8
# Q: Who is the General Manager of the Pittsburgh Pirates?
# A: The Pittsburgh Pirates do not have a General Manager listed in the provided contexts.
#
# 8
# Q: Who holds the position of Third Base Coach for the Pittsburgh Pirates?
# A: Unknown (Didn't find information about the specific third base coach in the given contexts.)
#
# 8
# Q: What is one of the must-see destinations in Pittsburgh?
# A: Carnegie Museum of Natural History
#
# 8
# Q: "How many original fossils are displayed in the ""Dinosaurs in Their Time"" exhibit at CMNH?"
# A: About 75% of the objects in Dinosaurs in Their Time exhibit at CMNH are real fossils.
#
# 8
# Q: Who is the head paleontologist at Carnegie Museum of Natural History?
# A: Matt Lamanna
#
# 8
# Q: What is featured in the Hillman Hall at CMNH?
# A: Hillman Hall of Minerals and Gems at CMNH features more than 1,300 minerals and gems from various locations worldwide, including minerals found locally.
#
# 8
# Q: "Until what date does the exhibit ""The Stories We Keep: Conserving Objects from Ancient Egypt"" run at CMNH?"
# A: March 9, 2025
#
# 8
# Q: What is the theme of the events during Super Science Saturdays at CMNH?
# A: Dinosaurs, DNA, and being a scientist
#
# 8
# Q: What unique event can you attend at CMNH during 21+ Nights?
# A: Community 21+ Night: Mythology on Oct 11, 2024 at 1 Allegheny Ave, Pittsburgh, PA.
#
# 8
# Q: What is the name of the exhibit that features dinosaurs in the Carnegie Museum of Natural History?
# A: Dino Hall at Carnegie Museum of Natural History
#
# 8
# Q: "How long will the exhibit ""The Stories We Keep: Conserving Objects from Ancient Egypt"" be shown at the CMNH?"
# A: March 9, 2025
#
# 8
# Q: Who is the head paleontologist at the Carnegie Museum of Natural History mentioned as a local celebrity?
# A: Matt Lamanna
#
# 8
# Q: What special event at CMNH is designed for children ages 5-12?
# A: No information about CMU (Carnegie Mellon University) in this context, but for the special event at CMNH (Carnegie Museum of Natural History), there is no specific event mentioned for children ages 5-12. However, they generally offer programs for families and kids of different ages. For detailed information, visit carnegiemuseums.org/nature/programs/family/.
#
# 8
# Q: What is one of the special night events at CMNH for adults over 21?
# A: 21+ Nights at CMNH
#
# 8
# Q: What special gallery at CMNH displays gems and jewelry?
# A: Carnegie Museum of Natural History's Gem and Mineral Hall
#
# 8
# Q: "What type of objects does the new exhibit ""The Stories We Keep"" at the CMNH focus on?"
# A: Ancient Egyptian objects
#
# 8
# Q: What rivers converge to form the Ohio River at Pittsburgh?
# A: Monongahela River and Allegheny River
#
# 8
# Q: What year was Pittsburgh officially recognized as a city?
# A: 1784
#
# 8
# Q: Who named Pittsburgh after the British statesman William Pitt the Elder?
# A: John Forbes
#
# 8
# Q: What was Pittsburgh known as in 1850 due to its industry?
# A: Iron City
#
# 8
# Q: Which former steel town was mentioned as having faced significant unemployment due to industrial decline?
# A: Pittsburgh
#
# 8
# Q: What high-technology industries did Pittsburgh diversify into after the decline of the steel industry?
# A: computer software, industrial automation (robotics), and biomedical and environmental technologies
#
# 8
# Q: Which university in Pittsburgh was chartered in 1787?
# A: The University of Pittsburgh was chartered in 1787.
#
# 8
# Q: What is the second-most populous city in Pennsylvania?
# A: Philadelphia
#
# 8
# Q: Which river does not flow through Pittsburgh?
# A: Allegheny River does not flow through Pittsburgh.
#
# 8
# Q: What year was Pittsburgh founded?
# A: Pittsburgh was not founded, it became an incorporated city in 1816.
#
# 8
# Q: Who named Pittsburgh?
# A: Pittsburgh was named after the Penn family's Scottish estate, Pittsburgh, located within the current-day city of Glasgow.
#
# 8
# Q: What is the nickname for Pittsburgh due to its manufacturing of steel?
# A: Steel City
#
# 8
# Q: What is Pittsburgh's highest elevation point in feet?
# A: 1,000 feet (Mt. Washington)
#
# 8
# Q: What major award is mentioned that the University of Pittsburgh Medical Center has consistently earned since 2000?
# A: Malcolm Baldrige National Quality Award (since 2000)
#
# 8
# Q: What year did the Pittsburgh Zoo & PPG Aquarium originally open?
# A: 1961
#
# 8
# Q: Who donated the funds to build the Phipps Conservatory and Botanical Gardens?
# A: Carnegie (Andrew Carnegie)
#
# 8
# Q: What unique status does the National Aviary hold in America?
# A: Premier bird zoo in America
#
# 8
# Q: What does the Carnegie Library of Pittsburgh offer across its 19 branches?
# A: Across its 19 branches, Carnegie Library of Pittsburgh offers books, digital resources, and various programs for the community.
#
# 8
# Q: "Which museum is the largest in America dedicated to a single artist, and which artist is it dedicated to?"
# A: The Andy Warhol Museum is the largest museum in America dedicated to a single artist.
#
# 8
# Q: Where does the Pittsburgh Symphony Orchestra perform?
# A: Heinz Hall
#
# 8
# Q: What is the estimated launch date for the new City of Pittsburgh website?
# A: There is no information available about the estimated launch date for the new City of Pittsburgh website.
#
# 8
# Q: What year did the Pittsburgh Zoo & PPG Aquarium originally open?
# A: 1961
#
# 8
# Q: Who donated to the City of Pittsburgh for the construction of the Phipps Conservatory and Botanical Gardens?
# A: Henry Phipps Jr.
#
# 8
# Q: What unique status does the National Aviary hold in America?
# A: Premier bird zoo in America
#
# 8
# Q: How many branches does the Carnegie Library of Pittsburgh have?
# A: 48 branches
#
# 8
# Q: How many museums are included in the Carnegie Museums of Pittsburgh?
# A: 4 museums
#
# 8
# Q: Where is the Pittsburgh Symphony Orchestra based?
# A: Pittsburgh
#
# 8
# Q: What is the scheduled launch date for the new City of Pittsburgh website?
# A: The new City of Pittsburgh website launch date is not provided in the contexts.
#
# 8
# Q: What are the dates for Picklesburgh in 2024?
# A: July 18-21, 2024
#
# 8
# Q: Where is Picklesburgh 2024 being held?
# A: Downtown Pittsburgh
#
# 8
# Q: How many years has Picklesburgh been named the #1 Specialty Food Festival by USA Today?
# A: 3 (years)
#
# 8
# Q: What new competition is being introduced at Picklesburgh in 2024?
# A: Mobot competition (for CMU students) in 2024.
#
# 8
# Q: What types of contests are included in the Olympickle Games?
# A: "Competitive pickle games, creative pickle menu items, and pickle-themed merchandise"
#
# 8
# Q: What quirky food items can you find at Picklesburgh?
# A: At Picklesburgh, you can find pickle-on-a-stick, pickle pizza, pickle wings, and pickle ice cream.
#
# 8
# Q: Where is the Pittsburgh Downtown Partnership located?
# A: The Pittsburgh Downtown Partnership is located in Pittsburgh, Pennsylvania.
#
# 8
# Q: What is the name of the festival held in the Bloomfield neighborhood of Pittsburgh?
# A: Little Italy Days
#
# 8
# Q: On which dates will Pittsburgh's Little Italy Days take place in 2024?
# A: Aug. 15-18, 202
#
# 8
# Q: What is the location for Pittsburgh's Little Italy Days festival in 2024?
# A: On Liberty Ave in the Bloomfield, Pittsburgh PA.
#
# 8
# Q: Is there an admission fee to attend Pittsburgh's Little Italy Days?
# A: Yes, there is an admission fee for Pittsburgh's Little Italy Days. However, a specific amount was not given in the provided contexts. It is suggested to check the official Little Italy Days website for updated information.
#
# 8
# Q: Where is free parking available during the Little Italy Days?
# A: Parking options are listed in the Parking & Street Closures section of the Little Italy Days website.
#
# 8
# Q: What type of entertainment can attendees expect at the Little Italy Days festival?
# A: Italian-themed entertainment, music, games, and bocce.
#
# 8
# Q: Which service is provided to assist with accessibility to the Little Italy Days festival?
# A: Portable restrooms are located at every intersection throughout the festival. (This also answers "
#
# 8
# Q: What is the date of the Pittsburgh Taco Festival in 2024?
# A: September 14, 2024
#
# 8
# Q: What are the general event hours for the Pittsburgh Taco Festival?
# A: 12:30pm - 7:00pm September 14, 2024
#
# 8
# Q: What special access do Gold Ticket holders receive at the Pittsburgh Taco Festival?
# A: Early Entry at 11:30 AM. Information available at: https://www.pghtacofest.com/
#
# 8
# Q: Which organizations benefit from the proceeds of the Pittsburgh Taco Festival?
# A: Pittsburgh Hispanic Development Corporation and Casa San Jose
#
# 8
# Q: Where is the Pittsburgh Taco Festival held?
# A: 2875 Railroad St, Pittsburgh, PA 15222.
#
# 8
# Q: What is the official email address for the Pittsburgh Taco Festival?
# A: PR@pghtacofest.com
#
# 8
# Q: Who is the website provider for the Pittsburgh Taco Festival's website?
# A: CookieScript is the website provider for the Pittsburgh Taco Festival's website.
#
# 8
# Q: What is the name of the event celebrating the American dessert in Latrobe?
# A: No event celebrating American desserts in Latrobe was provided in the contexts.
#
# 8
# Q: When is the Great American Banana Split Celebration scheduled to take place in 2025?
# A: 2023 (since the event has been a staple in Westmoreland County since 2013)
#
# 8
# Q: Which city contributes financially and supports the Banana Split Celebration?
# A: Latrobe
#
# 8
# Q: What is one of the athletic events featured at The Great American Banana Split Festival?
# A: Pie-Eating Contest
#
# 8
# Q: Who was the inventor of the banana split?
# A: David Strickler, 1904
#
# 8
# Q: What is the official dessert of Pennsylvania?
# A: Pennsylvania doesn't have an official state dessert.
#
# 8
# Q: Where is the Soul Food Festival 2024 located?
# A: Pittsburgh, Pennsylvania
#
# 8
# Q: What is the admission fee for the Soul Food Festival in Pittsburgh 2024?
# A: Admission fee information for Pittsburgh Soul Food Festival 2024 is not provided in the contexts. You may need to check their official website for more details.
#
# 8
# Q: What is the recommended dress theme for the Soul Food Fest After Party?
# A: All-white theme (recommended, but not required)
#
# 8
# Q: What hours is the Soul Food Festival open each day?
# A: 3PM-10PM (Sat), 2PM-6PM (DJ Stage, Sat), 6PM-10PM (DJ Stage, Sun), 3PM-10PM (Sun), & 10PM-2AM (After Party)
#
# 8
# Q: What type of businesses does the Soul Food Festival honor?
# A: Black culinary, butchery, and food businesses.
#
# 8
# Q: What is the main attraction of the South Side Soup Contest?
# A: Annual Soup Contest (South Side Soup Contest)
#
# 8
# Q: When does Fish Fry Season start in 2024?
# A: February 14, 2024
#
# 8
# Q: What festival features over 20 restaurants showcasing international foods?
# A: Pittsburgh Restaurant Week (January and August)
#
# 8
# Q: When is the Big Nosh Jewish Food Festival in 2024?
# A: April 7-9, 2024
#
# 8
# Q: "What is the primary focus of the event at the David L. Lawrence Convention Center on April 27, 2024?"
# A: Dessert Wars
#
# 8
# Q: Where and when is the Pittsburgh Veg Fair held in 2024?
# A: May 4, Rockwell Park
#
# 8
# Q: How can restaurants get involved with Pittsburgh Restaurant Week?
# A: Complete the restaurant nomination form on the Pittsburgh Restaurant Week website.
#
# 8
# Q: What are the benefits of sponsoring the Pittsburgh Restaurant Week?
# A: Community Exposure, Kickoff Party or Blogger Dinner sponsorships, Restaurateur Media Kit special distribution, Exposure at the Wrap Party, Logo and link in sponsors section of the Pittsburgh Restaurant Week Official Website.
#
# 8
# Q: What is the recommended action for attendees when they are seated during restaurant week?
# A: Mention Restaurant Week to the waitstaff.
#
# Answers generated and saved to: drive/MyDrive/system_output_bm25.txt
